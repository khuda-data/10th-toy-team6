# %% [markdown]
# # 데이터 수집
# 사용법 : 1~9은 건들지 않고 항목 **10. 데이터 수집 실행**만 사용.

# %%
import pandas as pd
import numpy as np
import requests, time, re, os, random
from bs4 import BeautifulSoup

# %% [markdown]
# # 1-1. API 주소 및 요청 설정

# %%
API_KEY = "B1FC36C7D790B5F17DCD8E33F5C33DF2"

# TEST ID
TEST_APP_ID = 1245620 # 게임 엘든링
TEST_STEAM_ID = 76561199824606664

API_URL = {
    "OWNED_GAMES" : "https://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/",
    "RECENT_GAMES" : " https://api.steampowered.com/IPlayerService/GetRecentlyPlayedGames/v0001/",
    "APP_DETAILS" : "https://store.steampowered.com/api/appdetails",
    "STORE_PAGE" : "https://store.steampowered.com/app/",
    "REVIEWS" : "https://store.steampowered.com/appreviews/"
}

session = requests.Session()

def change_user_agent() :
    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/151.0.0.0 Safari/537.36"
        )
    })

change_user_agent()

# %% [markdown]
# # 1-2. API 요청 지연 및 재시도

# %%
def rate_limited_request(url, params=None, timeout=15, max_retries=5, base_delay=1.5):
    for attempt in range(max_retries):
        response = session.get(url, params=params)
        if response.status_code == 429:
            wait = base_delay * (2 ** attempt) + random.uniform(0, 0.5)
            print(f"429 발생으로 {wait:.1f}초 대기 후 재시도 ({attempt+1}/{max_retries})")
            time.sleep(wait)
            continue
        response.raise_for_status()
        time.sleep(base_delay) # 기본 딜레이
        return response
    raise RuntimeError(f"최대 재시도 초과: {url}")

# %% [markdown]
# # 2. 게임 정보 데이터 수집
# - 장르
# - 카테고리
# - (게임 페이지 기준) 추천 개수, 메타크리틱 점수, 출시일, 가격

# %%
game_info_cache = {}

def get_game_info(appid):
    if appid in game_info_cache:
        cache = game_info_cache[appid]
        return cache["genre"], cache["categories"], cache["info_tup"]

    params = {"appids": appid, "l": "english"}

    try:
        response = rate_limited_request(API_URL["APP_DETAILS"], params=params) #session.get(API_URL["APP_DETAILS"], params=params, timeout=15)
        response_status = response.status_code
        if response_status != 200: 
            print("failed", response_status)
            return [],[],(0, "Unknown","Unknown","Unknown")

        data = response.json()
        
        app_data = data.get(str(appid), {})
        if not app_data.get("success"): return [],[],(0, "Unknown","Unknown","Unknown")
        game_info = app_data.get("data", {})
        """
        print(game_info.keys())
        print("recommendations", game_info.get("recommendations"))
        print("release_date", game_info.get("release_date"))
        print("price_overview", game_info.get("price_overview"))
        print("metacritic", game_info.get("metacritic"))
        """

        # 장르 정보
        genres = game_info.get("genres", [])
        genre_list = [genre.get("description") for genre in genres]

        # 카테고리 정보
        categories = game_info.get("categories", [])
        category_list = [category.get("description") for category in categories]

        # 기타 정보 종합
        recommendations = game_info.get("recommendations", {}).get("total", 0)
        release_date = game_info.get("release_date", {}).get("date", "Unknown")
        metacritic = game_info.get("metacritic", {}).get("score", "Unknown")

        # 가격 정보
        if game_info.get("is_free"): price = 0 
        else: price = game_info.get("price_overview", {}).get("final", "Unknown")
        if price != "Unknown" : price /= 100
        info_tup = (recommendations, metacritic, release_date, price)

        #print(game_info.get("price_overview"))
        
        game_info_cache[appid] = {"genre":genre_list, "categories":category_list, "info_tup":info_tup}
        return genre_list, category_list, info_tup
        

    except Exception as e:
        print(f"AppID {appid} 상세정보오류:", e)
        return [],[],(0, "Unknown","Unknown","Unknown")

print(get_game_info(TEST_APP_ID))
# Out:
# (['Action', 'RPG'], ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'Co-op', 'Online Co-op', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Camera Comfort', 'Custom Volume Controls', 'Playable without Timed Input', 'Save Anytime', 'Stereo Sound', 'Surround Sound', 'Steam Cloud', 'Family Sharing'], (827611, 94, '24 Feb, 2022', 64800.0))

# %% [markdown]
# # 3. 게임 리뷰 데이터 수집
# - 전체 리뷰 수, 긍정 리뷰 수, 긍정 리뷰 수, 리뷰 수 비율 레이팅

# %%
game_review_info_cache = {}

def get_game_review_info(appid):
    if appid in game_review_info_cache:
        cache = game_review_info_cache[appid]
        return cache
        
    URL = API_URL["REVIEWS"] + str(appid)
    params = {"json":1, "language":"all", "filter":"all", "review_type":"all","purchase_type":"all"}
    try:
        response = rate_limited_request(URL, params=params) # session.get(URL, params=params, timeout=15)
        response.raise_for_status()
        data = response.json()
        
    except Exception as e:
        print(f"AppID {appid} 리뷰 오류:", e)
        game_review_info_cache[appid] = ("Unknown", "Unknown", "Unknown", "Unknown")
        return ("Unknown", "Unknown", "Unknown", "Unknown")
        
    summary = data.get("query_summary", {})
    total_reviews = summary.get("total_reviews", "Unknown")
    positive_reviews = summary.get("total_positive", "Unknown")
    negative_reviews = summary.get("total_negative", "Unknown")
    if positive_reviews == "Unknown" or negative_reviews == "Unknown" or positive_reviews == None or negative_reviews == None : 
        rating_by_reviews = "Unknown"
    if total_reviews == 0 : rating_by_reviews = 0
    else : rating_by_reviews = round(positive_reviews / (positive_reviews + negative_reviews) * 100, 2)

    game_review_info_cache[appid] = (total_reviews, positive_reviews, negative_reviews, rating_by_reviews)
    return (total_reviews, positive_reviews, negative_reviews, rating_by_reviews)

print(get_game_review_info(TEST_APP_ID))
# Out:
# (1149209, 1069685, 79524, 93.08)

# %% [markdown]
# # 4. Steam Store 사용자 태그 데이터 수집

# %%
TAG_PATTERNS = [r'class="app_tag"[^>]*>\s*([^<]+)',  \
                r'class="app_tag[^"]*"[^>]*>\s*([^<]+)', \
                r'data-tagid="[^"]+"[^>]*>\s*([^<]+)']

game_tags_cache = {}

def get_steam_tags(appid):
    if appid in game_tags_cache:
        return game_tags_cache[appid]
    
    URL = f"{API_URL['STORE_PAGE']}{appid}/"

    try:
        response = rate_limited_request(URL) # session.get(URL, timeout=15)

        response.raise_for_status()
        html = response.text

    except Exception as e:
        print(f"AppID {appid} 태그 오류:", e)
        game_tags_cache[appid] = []
        return []

    # 방법 1 : 태그가 들어어있는 요소들 우선 탐색
    soup = BeautifulSoup(html, "html.parser")
    tags = []
    tag_elements = soup.select(".app_tag")

    for element in tag_elements:
        tag = element.get_text(strip=True)
            
        if not tag: continue
        if tag == "+": continue

        if tag not in tags: tags.append(tag)

    # 방법 2 (방법 1 실패 시) : 보조 탐색
    if not tags:
        for pattern in TAG_PATTERNS:
            matches = re.findall(pattern, html, flags=re.IGNORECASE)
            
            for match in matches:
                tag = (match.replace("&amp;", "&").strip())
                if tag and tag != "+" and tag not in tags :
                    tags.append(tag)

    # 태그 정리
    cleaned_tags = []

    for tag in tags:
        tag = tag.replace("\n", "").replace("\r", "").strip()
        if tag and tag != "+" and tag not in cleaned_tags :
            cleaned_tags.append(tag)

    game_tags_cache[appid] = cleaned_tags
    return cleaned_tags

print(get_steam_tags(TEST_APP_ID))
# Out:
# ['Souls-like', 'Open World', 'Dark Fantasy', 'RPG', 'Difficult', 'Action RPG', 'Multiplayer', 'Third Person', 'Fantasy', 'Singleplayer', 'Online Co-Op', 'Action', 'Co-op', 'Atmospheric', 'Great Soundtrack', 'PvP', 'Violent', '3D', 'Character Customization', 'Family Friendly']

# %% [markdown]
# # 5. 사용자 보유 게임 데이터 수집

# %%
def get_owned_games_of_user(steam_id, max_games=False) :
    params = {"key":API_KEY, "steamid":steam_id, "include_appinfo":True, \
              "include_played_free_games":True, "format":"json"}

    try:
        response = rate_limited_request(API_URL["OWNED_GAMES"], params=params) # session.get(API_URL["OWNED_GAMES"], params=params, timeout=15)
        
        response.raise_for_status()
        data = response.json()

        games_count = data.get("response", {}).get("game_count", [])
        games = data.get("response", {}).get("games", [])
        # print(games[0].keys())

    except Exception as e:
        print(f"steam_id {steam_id} 보유 게임 오류:", e)
        return []

    if not games :
        print(f"steam_id {steam_id} 보유 게임 없음")
        return []

    # 상위 max_games 개 게임만 수집
    if max_games and games_count > max_games:
        games = sorted(games, key=lambda g: g.get("playtime_forever", 0), reverse=True)[:max_games]
    
    res = []
    for game in games :
        appid = game.get("appid")
        game_name = game.get("name", "Unknown")
        playtime_mins = game.get("playtime_forever", 0)
        res.append((appid, game_name, playtime_mins))
    return res

print(get_owned_games_of_user(TEST_STEAM_ID))
# Out:
# [(578080, 'PUBG: BATTLEGROUNDS', 139), (977950, 'A Dance of Fire and Ice', 459), (1245620, 'ELDEN RING', 575), (2250500, 'Rhythia', 378)]

# %% [markdown]
# # 6. 사용자 최근 2주 플레이 데이터 수집

# %%
def get_recent_games_of_user(steam_id) :
    params = {"key": API_KEY, "steamid":steam_id, "foramt":"json"}

    try :
        response = rate_limited_request(API_URL["RECENT_GAMES"], params=params) # session.get(API_URL["RECENT_GAMES"], params=params, timeout=15)

        response.raise_for_status()
        data = response.json()
        games = data.get("response", {}).get("games", [])

    except Exception as e:
        print(f"steam_id {steam_id} 최근 게임 오류:", e)
        return []

    if not games:
        print(f"steam_id {steam_id} 최근 게임 없음")
        return []

    res = []
    for game in games :
        appid = game.get("appid")
        game_name = game.get("name", "Unknown")
        playtime_mins = game.get("playtime_2weeks", 0)
        res.append((appid, game_name, playtime_mins))
    return res

print(get_recent_games_of_user(TEST_STEAM_ID))
# Out:
# [(1245620, 'ELDEN RING', 153), (977950, 'A Dance of Fire and Ice', 33)]

# %% [markdown]
# # 7. Steam Store 게임 리뷰에서 사용자 ID 데이터 수집

# %%
def get_reviews(appid, cursor="*", num_per_page=100, only_positive=True):
    URL = API_URL["REVIEWS"] + str(appid)
    review_type = "positive" if only_positive else "all"
    params = {"json":1, "filter":"updated", "language":"all", "cursor":cursor, "num_per_page":num_per_page, \
        "review_type":review_type, "purchase_type":"steam"}

    try:
        response = rate_limited_request(URL, params=params) # session.get(URL, params=params, timeout=15)
        response.raise_for_status()
        data = response.json()

    except Exception as e:
        print(f"AppId {appid} 리뷰 오류:", e)
        return []

    if not data :
        print(f"AppId {appid} 리뷰 없음")

    return data

def get_user_ids_from_app(appid, id_nums, only_positive=True, minimum_playtime_mins=0, minimum_games=0, max_games=False):
    id_set = set()
    cursor = "*"
    while len(id_set) < id_nums :
        # 리뷰 데이터 100개 수집
        data = get_reviews(appid, cursor=cursor, num_per_page=100, only_positive=only_positive)
        if not data :
            print("리뷰 로딩 중 오류")
            break
        
        reviews = data.get("reviews", [])
        if not reviews : break

        for review in reviews:
            if len(id_set) >= id_nums : break
            
            user = review.get("author", {})
            if user.get("playtime_forever", 0) < minimum_playtime_mins : continue
            elif user.get("num_games_owned", 0) < minimum_games : continue
            elif max_games and user.get("num_games_owned", 0) > max_games : continue

            id = user.get("steamid")
            if id : id_set.add(id)

        cursor = data.get("cursor")
        if not cursor: break

        time.sleep(3)
    return list(id_set)

print("return example : get_user_ids_from_app()")
TEST_APP_ID = 1245620 # 게임 엘든링
test_ids_list = get_user_ids_from_app(TEST_APP_ID, 15, minimum_playtime_mins=600, minimum_games=15)
print(test_ids_list)
# Out:
# return example : get_user_ids_from_app()
# ['76561199110612232', '76561198123681703', '76561199015330455', '76561198984355584', '76561198073067799', '76561199835282867', '76561198724802455', '76561198166226287', '76561199194402331', '76561198885046549', '76561198079488752', '76561198725405351', '76561199177732895', '76561198272738490', '76561198091122227']

# %% [markdown]
# # 8. 앱ID 리스트에서 DataFrame 생성

# %%
def create_df_from_appid_list(appid_list, ids_per_game, minimum_playtime_mins=600, minimum_games=15, max_search_games=False, max_filter_games=30) :

    data = [] # DataFrame으로 만들 데이터
    
    # 게임 목록 순회
    for app_idx, appid in enumerate(appid_list) :
        user_ids = get_user_ids_from_app(appid, ids_per_game, minimum_playtime_mins=minimum_playtime_mins, \
                                          minimum_games=minimum_games, max_games=max_search_games)
        # 게임에서 찾은 유저 순회
        for id_idx, user_id in enumerate(user_ids) :
            owned_games = get_owned_games_of_user(user_id, max_games=max_filter_games)
            print(f"- {app_idx}번 게임의 {id_idx}번 유저의 보유 게임 {len(owned_games)}개 데이터 수집")

            # 유저의 최근(2주) 게임 순회
            recent_games = get_recent_games_of_user(user_id)
            recent_games_dict = {game_id : playtime for game_id, game_name, playtime in recent_games}
            
            # 유저의 보유 게임 순회
            for game_idx, game_info in enumerate(owned_games):
                game_id, game_name, game_playtime_mins = game_info
                game_playtime_hours = round(game_playtime_mins / 60, 2)

                # 게임 장르, 카테고리, 기타 정보
                genre_list, category_list, info_tup = get_game_info(game_id)
                recommendations, metacritic, release_date, price = info_tup

                # 태그 정보 수집
                tag_list = get_steam_tags(game_id)

                # 리뷰 정보 수집
                tot_rev, pos_rev, neg_rev, rating_by_rev = get_game_review_info(game_id)

                # 해당 게임 최근 플레이 이력 확인
                recent_playtime_mins = recent_games_dict.get(game_id, 0)
                recent_playtime_hours = round(recent_playtime_mins / 60, 2)
                
                print(f"- - {game_idx}. : {game_name}")
                data.append({"steamid":user_id, "appid":game_id, "game_name":game_name, "playtime_hours":game_playtime_hours, \
                             "recent_playtime_hours":recent_playtime_hours, \
                            "genre":", ".join(genre_list) if genre_list else "Unknown", \
                            "tags":", ".join(tag_list) if tag_list else "Unknown", \
                            "steam_categories":", ".join(category_list) if category_list else "Unknown", \
                             "total_reviews":tot_rev, "positive_reviews":pos_rev, "negative_reviews":neg_rev, "rating_by_reviews":rating_by_rev, \
                           "recommendations":recommendations, "metacritic":metacritic, "release_date":release_date, "price(원)":price})
            
    data_df = pd.DataFrame(data)
    data_df.head(10)
    return data_df

TEST_APPID_LIST = ["1245620", "1091500"] # 게임 2개 : 엘든링, 사이버펑크
test_df = create_df_from_appid_list(TEST_APPID_LIST, 3, max_filter_games=5)
test_df.head(5)
# Out:
# - 0번 게임의 0번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Overwatch®
# - - 1. : Apex Legends
# - - 2. : ELDEN RING
# - - 3. : TEKKEN 7
# - - 4. : Aimlabs
# - 0번 게임의 1번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Path of Exile
# - - 1. : PUBG: BATTLEGROUNDS
# - - 2. : Tom Clancy's Rainbow Six Siege
# - - 3. : Counter-Strike 2
# - - 4. : Apex Legends
# - 0번 게임의 2번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Among Us
# - - 1. : Persona 3 Reload
# - - 2. : Stardew Valley
# - - 3. : Fields of Mistria
# - - 4. : DELTARUNE
# - 1번 게임의 0번 유저의 보유 게임 5개 데이터 수집
# steam_id 76561199588348201 최근 게임 없음
# - - 0. : Portal 2
# - - 1. : Dying Light
# - - 2. : The Forest
# - - 3. : Cities: Skylines
# - - 4. : Grand Theft Auto V Legacy
# - 1번 게임의 1번 유저의 보유 게임 5개 데이터 수집
# steam_id 76561199476865533 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Half-Life 2: Deathmatch
# - - 2. : Half-Life Deathmatch: Source
# - - 3. : Left 4 Dead 2
# - - 4. : Counter-Strike 2
# - 1번 게임의 2번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : People Playground
# - - 2. : Geometry Dash
# - - 3. : BeamNG.drive
# - - 4. : War Thunder
#              steamid    appid     game_name  playtime_hours  \
# 0  76561199015330455  2357570    Overwatch®          350.70
# 1  76561199015330455  1172470  Apex Legends          232.67
# 2  76561199015330455  1245620    ELDEN RING          224.67
# 3  76561199015330455   389730      TEKKEN 7          144.52
# 4  76561199015330455   714010       Aimlabs          136.13
#
#    recent_playtime_hours                                              genre  \
# 0                  12.08                               Action, Free To Play
# 1                   0.00                    Action, Adventure, Free To Play
# 2                   0.00                                        Action, RPG
# 3                   0.00                                     Action, Sports
# 4                   0.00  Action, Adventure, Casual, Indie, Simulation, ...
#
#                                                 tags  \
# 0                                            Unknown
# 1  Free to Play, Multiplayer, Battle Royale, FPS,...
# 2  Souls-like, Open World, Dark Fantasy, RPG, Dif...
# 3  Fighting, Action, Multiplayer, Competitive, Ar...
# 4  FPS, Free to Play, Shooter, Simulation, Action...
#
#                                     steam_categories  total_reviews  \
# 0  Multi-player, PvP, Online PvP, Co-op, Online C...         418444
# 1  Multi-player, PvP, Online PvP, Co-op, Online C...        1064622
# 2  Single-player, Multi-player, PvP, Online PvP, ...        1149209
# 3  Single-player, Multi-player, PvP, Online PvP, ...          95313
# 4  Single-player, Steam Achievements, Full contro...         136884
#
#    positive_reviews  negative_reviews  rating_by_reviews  recommendations  \
# 0            131325            287119              31.38              275
# 1            721198            343424              67.74             1578
# 2           1069685             79524              93.08           827611
# 3             79656             15657              83.57            67915
# 4            124640             12244              91.06              264
#
#   metacritic  release_date price(원)
# 0    Unknown  Aug 10, 2023      0.0
# 1         88   4 Nov, 2020      0.0
# 2         94  24 Feb, 2022  64800.0
# 3         82   1 Jun, 2017  43800.0
# 4    Unknown  16 Jun, 2023      0.0

# %% [markdown]
# # 9. DataFrame을 CSV로 저장

# %%
FILE_NAME = "steam_user_games_"

def make_csv(data_df, file_num) :
    file_name = FILE_NAME + str(file_num) + ".csv"
    data_df.to_csv(file_name, index=False, encoding="utf-8-sig")

# %% [markdown]
# # 10. 데이터 수집 실행

# %%
# 사용자 정보를 수집할 게임의 id 목록 입력
# 예시) APPID_LIST = ["1245620", "1091500"] # 게임 2개 : 엘든링, 사이버펑크
APPID_LIST = ["105600", "252490", "381210", "550", "553850", "4000", "2358720", "218620", "346110", "367520"]

# 게임 하나 당 수집할 id 개수 입력
IDS_PER_GAME = 15

# CSV 파일 번호 입력
FILE_NUM = 1

# DataFrame 생성
data_df = create_df_from_appid_list(APPID_LIST, IDS_PER_GAME, minimum_playtime_mins=600, \
                                    minimum_games=50, max_search_games=False, max_filter_games=30)
# 파라미터
# minimum_playtime_mins : 어떤 게임에서 사용자 id를 수집할 때, 그 게임의 최소 플레이 시간(분)
# minimum_games : 사용자 id를 수집할 때, 최소 보유 게임 개수
# max_search_games : 사용자 id를 수집할 때, 최대 보유 게임 개수. False로 지정시 상한 지정 안 함
# max_filter_games : 어떤 사용자의 게임 정보를 수집할 때, 보유 게임 중 플레이타임 상위 n개의 데이터만 가져옴. 이때의 n을 지정.

make_csv(data_df, FILE_NUM)
# Out:
# - 0번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Terraria
# - - 1. : tModLoader
# - - 2. : Monster Hunter: World
# - - 3. : Palworld
# - - 4. : Celeste
# - - 5. : Soundpad
# - - 6. : Darkest Dungeon®
# - - 7. : Wallpaper Engine
# - - 8. : BlazBlue Entropy Effect
# - - 9. : Granblue Fantasy: Relink
# - - 10. : Slay the Spire 2
# - - 11. : The Binding of Isaac: Rebirth
# - - 12. : Titanfall® 2
# - - 13. : Undertale
# - - 14. : Threefold Recital
# - - 15. : MECCHA CHAMELEON
# - - 16. : Ori and the Blind Forest
# - - 17. : Subnautica
# - - 18. : ELDEN RING
# - - 19. : Hollow Knight: Silksong
# - - 20. : Draw & Guess
# - - 21. : Craft The World
# - - 22. : The Forest
# - - 23. : Neva
# - - 24. : ENDER LILIES: Quietus of the Knights
# - - 25. : Dead Cells
# - - 26. : MONSTER HUNTER RISE
# - - 27. : GRIS
# - - 28. : DEATH STRANDING DIRECTOR'S CUT
# - - 29. : Halo: The Master Chief Collection
# - 0번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Left 4 Dead 2
# - - 2. : Terraria
# - - 3. : Strinova
# - - 4. : Bloons TD 6
# - - 5. : Don't Starve Together
# - - 6. : GrandChase
# - - 7. : GTFO
# - - 8. : Phasmophobia
# - - 9. : tModLoader
# - - 10. : Deep Rock Galactic
# - - 11. : Monster Hunter Wilds
# - - 12. : MONSTER HUNTER RISE
# - - 13. : The Binding of Isaac: Rebirth
# - - 14. : Balatro
# - - 15. : Lethal Company
# - - 16. : Deadlock
# - - 17. : Soda Dungeon
# - - 18. : Wuthering Waves
# - - 19. : Darkest Dungeon®
# - - 20. : Risk of Rain 2
# - - 21. : DOOM Eternal
# - - 22. : BlazBlue Centralfiction
# - - 23. : HonkaiImpact 3rd
# - - 24. : Devil May Cry 5
# - - 25. : Garry's Mod
# - - 26. : PEAK
# - - 27. : Brawlhalla
# - - 28. : Plants vs. Zombies: Game of the Year
# - - 29. : Paladins
# - 0번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : FINAL FANTASY XIV Online
# - - 1. : ELDEN RING
# - - 2. : The Elder Scrolls Online
# - - 3. : Monster Hunter: World
# - - 4. : Lost Ark
# - - 5. : The Elder Scrolls V: Skyrim
# - - 6. : Kingdom Come: Deliverance II
# - - 7. : The Elder Scrolls III: Morrowind
# - - 8. : New World: Aeternum
# - - 9. : The Witcher 3: Wild Hunt
# - - 10. : Baldur's Gate 3
# - - 11. : Cyberpunk 2077
# - - 12. : Palworld
# - - 13. : Kingdom Come: Deliverance
# - - 14. : DARK SOULS™ II: Scholar of the First Sin
# - - 15. : Fallout: New Vegas
# - - 16. : Path of Exile
# - - 17. : Terraria
# - - 18. : DARK SOULS™ III
# - - 19. : Crimson Desert
# - - 20. : Yakuza 0
# - - 21. : Monster Hunter Wilds
# - - 22. : Lies of P
# - - 23. : MONSTER HUNTER RISE
# - - 24. : Valheim
# - - 25. : Wasteland 3
# - - 26. : V Rising
# - - 27. : DayZ
# - - 28. : WUCHANG: Fallen Feathers
# - - 29. : The Elder Scrolls IV: Oblivion Remastered
# - 0번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : 7 Days to Die
# - - 1. : Terraria
# - - 2. : Don't Starve Together
# - - 3. : tModLoader
# - - 4. : Bloons TD 6
# - - 5. : Caveblazers
# - - 6. : Cyberpunk 2077
# - - 7. : Palworld
# - - 8. : Wallpaper Engine
# - - 9. : Night Raider
# - - 10. : Slay the Spire
# - - 11. : Left 4 Dead 2
# - - 12. : Subnautica
# - - 13. : Mad Island
# - - 14. : Senren＊Banka
# - - 15. : 魔女的夜宴
# - - 16. : Bongo Cat
# - - 17. : Dead Cells
# - - 18. : Celeste
# - - 19. : Forager
# - - 20. : Plants vs. Zombies: Game of the Year
# - - 21. : Clicker Heroes
# - - 22. : Block Story
# - - 23. : DAVE THE DIVER
# - - 24. : Kingdom Rush Vengeance
# - - 25. : Broforce
# - - 26. : Slime Rancher
# - - 27. : Otome * Domain
# - - 28. : The Wife Next Door
# - - 29. : Neon Abyss
# - 0번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Pixel Puzzles Ultimate Jigsaw Puzzles
# - - 1. : Bejeweled 3
# - - 2. : Gems of War
# - - 3. : Realm Grinder
# - - 4. : Path of Exile
# - - 5. : Path of Exile 2
# - - 6. : Dungeon Defenders
# - - 7. : Pixel Puzzles Illustrations & Anime Jigsaw Puzzles
# - - 8. : Bloons TD 6
# - - 9. : Pixel Puzzles Traditional Jigsaw Puzzles
# - - 10. : Last Epoch
# - - 11. : Gnomoria
# - - 12. : Palworld
# - - 13. : Counter-Strike
# - - 14. : The Witcher 3: Wild Hunt
# - - 15. : The Elder Scrolls V: Skyrim
# - - 16. : Terraria
# - - 17. : Borderlands 2
# - - 18. : Oxygen Not Included
# - - 19. : Torchlight II
# - - 20. : Borderlands 3
# - - 21. : Fallout 4
# - - 22. : Dragon Age: Origins - Ultimate Edition
# - - 23. : EVERSPACE™ 2
# - - 24. : Sins of a Solar Empire: Rebellion
# - - 25. : Jagged Alliance - Back in Action
# - - 26. : Soulstone Survivors
# - - 27. : Dungeon Defenders II
# - - 28. : Starbound
# - - 29. : SYNTHETIK
# - 0번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Palworld
# - - 1. : Garry's Mod
# - - 2. : ULTRAKILL
# - - 3. : Team Fortress 2
# - - 4. : Call of Duty: Black Ops III
# - - 5. : Half-Life 2
# - - 6. : Terraria
# - - 7. : Fallout: New Vegas
# - - 8. : Blender
# - - 9. : Left 4 Dead 2
# - - 10. : Cookie Clicker
# - - 11. : Dying Light
# - - 12. : Half-Life
# - - 13. : The Binding of Isaac: Rebirth
# - - 14. : Gamble With Your Friends
# - - 15. : People Playground
# - - 16. : Combat Master
# - - 17. : The Binding of Isaac
# - - 18. : Tom Clancy's Rainbow Six Siege
# - - 19. : Portal 2
# - - 20. : Berry Bury Berry
# - - 21. : Subnautica
# - - 22. : ATLYSS
# - - 23. : tModLoader
# - - 24. : RPG Maker VX Ace
# - - 25. : Day of Defeat: Source
# - - 26. : Metro 2033 Redux
# - - 27. : Ninja Kiwi Archive
# - - 28. : Ready or Not
# - - 29. : Subnautica 2
# - 0번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Hearts of Iron IV
# - - 1. : Counter-Strike 2
# - - 2. : Terraria
# - - 3. : Garry's Mod
# - - 4. : People Playground
# - - 5. : Hotline Miami 2: Wrong Number
# - - 6. : Half-Life 2
# - - 7. : Wallpaper Engine
# - - 8. : tModLoader
# - - 9. : War Thunder
# - - 10. : Ages of Conflict: World War Simulator
# - - 11. : Valheim
# - - 12. : POSTAL 2
# - - 13. : Crysis Remastered
# - - 14. : Entropy : Zero 2
# - - 15. : Hotline Miami
# - - 16. : Warframe
# - - 17. : Black Mesa
# - - 18. : Darksiders Warmastered Edition
# - - 19. : Undertale
# - - 20. : METAL GEAR RISING: REVENGEANCE
# - - 21. : Left 4 Dead 2
# - - 22. : Phasmophobia
# - - 23. : Totally Accurate Battle Simulator
# - - 24. : Teardown
# - - 25. : Hitman: Absolution
# - - 26. : Portal
# - - 27. : Half-Life 2: Update
# - - 28. : Entropy : Zero
# - - 29. : GameMaker
# - 0번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198070682954 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Team Fortress Classic
# - - 2. : Day of Defeat
# - - 3. : Deathmatch Classic
# - - 4. : Half-Life: Opposing Force
# - - 5. : Ricochet
# - - 6. : Half-Life
# - - 7. : Counter-Strike: Condition Zero
# - - 8. : Counter-Strike: Condition Zero Deleted Scenes
# - - 9. : Half-Life: Blue Shift
# - - 10. : Half-Life 2
# - - 11. : Counter-Strike: Source
# - - 12. : Half-Life: Source
# - - 13. : Day of Defeat: Source
# - - 14. : Half-Life 2: Deathmatch
# - - 15. : Half-Life Deathmatch: Source
# - - 16. : Portal
# - - 17. : Team Fortress 2
# - - 18. : Left 4 Dead
# - - 19. : Left 4 Dead 2
# - - 20. : Dota 2
# - - 21. : Portal 2
# - - 22. : Counter-Strike 2
# - - 23. : Killing Floor
# - - 24. : Vampire: The Masquerade - Bloodlines
# - - 25. : RollerCoaster Tycoon 3: Platinum!
# - - 26. : Garry's Mod
# - - 27. : Hitman: Blood Money
# - - 28. : Just Cause 2
# - - 29. : BioShock Infinite
# - 0번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199214007024 최근 게임 없음
# - - 0. : Team Fortress Classic
# - - 1. : Half-Life: Opposing Force
# - - 2. : Half-Life
# - - 3. : Half-Life: Blue Shift
# - - 4. : Half-Life 2
# - - 5. : Half-Life: Source
# - - 6. : Half-Life 2: Deathmatch
# - - 7. : Half-Life Deathmatch: Source
# - - 8. : Portal
# - - 9. : Left 4 Dead 2
# - - 10. : Portal 2
# - - 11. : Counter-Strike 2
# - - 12. : Garry's Mod
# - - 13. : Super Meat Boy
# - - 14. : Portal 2 - The Final Hours
# - - 15. : Terraria
# - - 16. : The Binding of Isaac
# - - 17. : Castle Crashers
# - - 18. : Starbound
# - - 19. : Don't Starve
# - - 20. : RPG Maker VX Ace
# - - 21. : The Forest
# - - 22. : Kingdom Rush
# - - 23. : The Binding of Isaac: Rebirth
# - - 24. : Goat Simulator
# - - 25. : 100% Orange Juice
# - - 26. : Metro 2033 Redux
# - - 27. : Enter the Gungeon
# - - 28. : Geometry Dash
# - - 29. : Don't Starve Together
# - 0번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : The Binding of Isaac: Rebirth
# - - 1. : Terraria
# - - 2. : Factorio
# - - 3. : ELDEN RING
# - - 4. : GUILTY GEAR -STRIVE-
# - - 5. : NGU IDLE
# - - 6. : Slay the Spire 2
# - - 7. : Yakuza 0
# - - 8. : Trimps
# - - 9. : Grand Theft Auto V Legacy
# - - 10. : Tom Clancy's Rainbow Six Siege
# - - 11. : Garry's Mod
# - - 12. : Geometry Dash
# - - 13. : Grim Dawn
# - - 14. : Left 4 Dead 2
# - - 15. : Lobotomy Corporation
# - - 16. : Warframe
# - - 17. : Sekiro™: Shadows Die Twice
# - - 18. : HITMAN™ 2
# - - 19. : FINAL FANTASY XIV Online Free Trial
# - - 20. : Lost Ark
# - - 21. : Path of Exile
# - - 22. : The Witcher 3: Wild Hunt
# - - 23. : Limbus Company
# - - 24. : Your Only Move Is HUSTLE
# - - 25. : Vampire Survivors
# - - 26. : Project Zomboid
# - - 27. : Slay the Spire
# - - 28. : Cookie Clicker
# - - 29. : Yakuza Kiwami (Legacy)
# - 0번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Terraria
# - - 1. : Warframe
# - - 2. : tModLoader
# - - 3. : Left 4 Dead 2
# - - 4. : Garry's Mod
# - - 5. : Phasmophobia
# - - 6. : Palworld
# - - 7. : Killing Floor 2
# - - 8. : Counter-Strike 2
# - - 9. : Sons Of The Forest
# - - 10. : Unturned
# - - 11. : SMITE
# - - 12. : War Thunder
# - - 13. : PUBG: BATTLEGROUNDS
# - - 14. : STALZONE
# - - 15. : R.E.P.O.
# - - 16. : Warhammer: Vermintide 2
# - - 17. : Farlight 84
# - - 18. : Supermarket Together
# - - 19. : Where Winds Meet
# - - 20. : Portal Knights
# - - 21. : Deadlock
# - - 22. : Don't Starve Together
# - - 23. : Stardew Valley
# - - 24. : Infinity Nikki
# - - 25. : TBH: Task Bar Hero
# - - 26. : No Man's Sky
# - - 27. : Ready or Not
# - - 28. : Once Human
# - - 29. : Wallpaper Engine
# - 0번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198845916760 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Counter-Strike: Source
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Left 4 Dead 2
# - - 5. : Counter-Strike 2
# - - 6. : Grand Theft Auto IV: The Complete Edition
# - - 7. : Overgrowth
# - - 8. : Assassin's Creed Brotherhood
# - - 9. : Borderlands 2
# - - 10. : Terraria
# - - 11. : Tomb Raider
# - - 12. : Castle Crashers
# - - 13. : Call of Juarez Gunslinger
# - - 14. : RPG Maker VX Ace
# - - 15. : Receiver
# - - 16. : Turbo Dismount
# - - 17. : Dead Rising 3
# - - 18. : Grand Theft Auto V Legacy
# - - 19. : This War of Mine
# - - 20. : Gang Beasts
# - - 21. : Assassin's Creed Unity
# - - 22. : The Witcher 3: Wild Hunt
# - - 23. : Rain World
# - - 24. : Don't Starve Together
# - - 25. : Besiege
# - - 26. : ARK: Survival Evolved
# - - 27. : Polyball
# - - 28. : Dead Island Riptide Definitive Edition
# - - 29. : Ultimate Chicken Horse
# - 0번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Squad
# - - 1. : SCUM
# - - 2. : PUBG: BATTLEGROUNDS
# - - 3. : Counter-Strike 2
# - - 4. : your wife
# - - 5. : Smart Game Booster
# - - 6. : Terraria
# - - 7. : Apex Legends
# - - 8. : tModLoader
# - - 9. : Sea of Thieves
# - - 10. : Palworld
# - - 11. : Ready or Not
# - - 12. : Hunt: Showdown 1896
# - - 13. : Monster Hunter Wilds
# - - 14. : Inside the Backrooms
# - - 15. : Stardew Valley
# - - 16. : Monster Hunter: World
# - - 17. : Project Zomboid
# - - 18. : Wallpaper Engine
# - - 19. : Lethal Company
# - - 20. : Bongo Cat
# - - 21. : NARAKA: BLADEPOINT
# - - 22. : Battlefield™ V
# - - 23. : HELLDIVERS™ 2
# - - 24. : Muse Dash
# - - 25. : ELDEN RING
# - - 26. : Subnautica
# - - 27. : Black Myth: Wukong
# - - 28. : BattleBit Remastered
# - - 29. : Party Animals
# - 0번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Team Fortress 2
# - - 2. : DayZ
# - - 3. : Geometry Dash
# - - 4. : Terraria
# - - 5. : tModLoader
# - - 6. : Garry's Mod
# - - 7. : Project Zomboid
# - - 8. : The Binding of Isaac: Rebirth
# - - 9. : Cyberpunk 2077
# - - 10. : Grand Theft Auto IV: The Complete Edition
# - - 11. : Red Dead Redemption 2
# - - 12. : DARK SOULS™ II: Scholar of the First Sin
# - - 13. : The Elder Scrolls V: Skyrim
# - - 14. : Metro Exodus
# - - 15. : Nether
# - - 16. : Dead by Daylight
# - - 17. : Left 4 Dead 2
# - - 18. : Celeste
# - - 19. : Mewgenics
# - - 20. : PAYDAY 2
# - - 21. : God of War
# - - 22. : The Last of Us™ Part II Remastered
# - - 23. : Lethal Company
# - - 24. : Metro: Last Light Complete Edition
# - - 25. : METAL GEAR RISING: REVENGEANCE
# - - 26. : SILENT HILL 2
# - - 27. : OMORI
# - - 28. : HELLDIVERS™ 2
# - - 29. : DEATH STRANDING DIRECTOR'S CUT
# - 0번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Fallout: New Vegas PCR
# - - 1. : The Elder Scrolls V: Skyrim
# - - 2. : Fallout 4
# - - 3. : Terraria
# - - 4. : Starbound
# - - 5. : Cyberpunk 2077
# - - 6. : Don't Starve
# - - 7. : ELDEN RING
# - - 8. : Devil Slayer - Raksasi
# - - 9. : No Man's Sky
# - - 10. : Dying Light
# - - 11. : Fallout 76
# - - 12. : Middle-earth™: Shadow of War™
# - - 13. : Orcs Must Die! Deathtrap
# - - 14. : Valheim
# - - 15. : Dying Light 2: Reloaded Edition
# - - 16. : Cult of the Lamb
# - - 17. : Grand Theft Auto V Legacy
# - - 18. : Grim Dawn
# - - 19. : Fallout 3 - Game of the Year Edition
# - - 20. : Risk of Rain 2
# - - 21. : Dark Messiah of Might & Magic Single Player
# - - 22. : Hogwarts Legacy
# - - 23. : Sons Of The Forest
# - - 24. : Abiotic Factor
# - - 25. : The Forest
# - - 26. : Magicraft
# - - 27. : Timberborn
# - - 28. : Grand Theft Auto: San Andreas
# - - 29. : STAR WARS™ Knights of the Old Republic™
# - 1번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Lethal Company
# - - 2. : Rust
# - - 3. : Microsoft Flight Simulator (2020)
# - - 4. : The Last of Us™ Part II Remastered
# - - 5. : The Last of Us™ Part I
# - - 6. : Red Dead Redemption 2
# - - 7. : Portal 2
# - - 8. : Crosshair V2
# - - 9. : Wallpaper Engine
# - - 10. : Totally Accurate Battlegrounds
# - - 11. : Detroit: Become Human
# - - 12. : Batman™: Arkham Knight
# - - 13. : Marvel Rivals
# - - 14. : HELLDIVERS™ 2
# - - 15. : Assassin's Creed Odyssey
# - - 16. : Marvel’s Spider-Man Remastered
# - - 17. : Beyond: Two Souls
# - - 18. : Terraria
# - - 19. : Still Wakes the Deep
# - - 20. : ROUNDS
# - - 21. : Deep Rock Galactic
# - - 22. : TCG Card Shop Simulator: Prologue
# - - 23. : MECCHA CHAMELEON
# - - 24. : Heavy Rain
# - - 25. : One-armed cook
# - - 26. : Rustangelo
# - - 27. : Buckshot Roulette
# - - 28. : Call of Duty®
# - - 29. : Half-Life
# - 1번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : Grand Theft Auto V Legacy
# - - 2. : Dead by Daylight
# - - 3. : Counter-Strike 2
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : Infestation: The New Z
# - - 6. : PUBG: BATTLEGROUNDS
# - - 7. : Far Cry 5
# - - 8. : Hero's Land
# - - 9. : Days Gone
# - - 10. : Far Cry 6
# - - 11. : Monster Hunter Wilds
# - - 12. : Palworld
# - - 13. : The Forest
# - - 14. : Green Hell
# - - 15. : Saints Row IV
# - - 16. : Call of Duty®
# - - 17. : The Outlast Trials
# - - 18. : Back 4 Blood
# - - 19. : CRSED: Cuisine Royale
# - - 20. : Brawlhalla
# - - 21. : Don't Starve Together
# - - 22. : Destiny 2
# - - 23. : Terraria
# - - 24. : Hotline Miami 2: Wrong Number
# - - 25. : Sleeping Dogs: Definitive Edition
# - - 26. : FOR HONOR
# - - 27. : Phasmophobia
# - - 28. : Unturned
# - - 29. : SurrounDead
# - 1번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Ravenfield
# - - 2. : Rust
# - - 3. : Garry's Mod
# - - 4. : Lost Light
# - - 5. : Euro Truck Simulator 2
# - - 6. : PUBG: BATTLEGROUNDS
# - - 7. : Construction-Simulator 2015
# - - 8. : PAYDAY 2
# - - 9. : Arma 3
# - - 10. : World of Tanks Blitz
# - - 11. : City Car Driving
# - - 12. : War Thunder
# - - 13. : Metro: Last Light Complete Edition
# - - 14. : Soundpad Demo
# - - 15. : Need for Speed™ Most Wanted
# - - 16. : Warface: Clutch
# - - 17. : 7 Days to Die
# - - 18. : Far Cry® 3
# - - 19. : Counter-Strike
# - - 20. : Counter-Strike: Source
# - - 21. : Apex Legends
# - - 22. : JudgeSim
# - - 23. : Left 4 Dead 2
# - - 24. : Half-Life 2
# - - 25. : Squad
# - - 26. : Thief Simulator
# - - 27. : Wallpaper Engine
# - - 28. : Supermarket Simulator
# - - 29. : Portal 2
# - 1번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199080871410 최근 게임 없음
# - - 0. : Half-Life
# - - 1. : Half-Life 2
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Left 4 Dead 2
# - - 5. : Counter-Strike 2
# - - 6. : Dark Sector
# - - 7. : Samorost 2
# - - 8. : Borderlands 2
# - - 9. : Arma 3
# - - 10. : RPG Maker VX Ace
# - - 11. : DayZ
# - - 12. : Euro Truck Simulator 2
# - - 13. : Assetto Corsa
# - - 14. : SteamWorld Dig
# - - 15. : Rust
# - - 16. : American Truck Simulator
# - - 17. : Grand Theft Auto V Legacy
# - - 18. : Metro 2033 Redux
# - - 19. : Amerzone: The Explorer’s Legacy (1999)
# - - 20. : FOR HONOR
# - - 21. : UNLOVED
# - - 22. : CRYPTARK
# - - 23. : Far Cry Primal
# - - 24. : Weapon of Choice
# - - 25. : Pankapu
# - - 26. : Space Pilgrim Episode II: Epsilon Indi
# - - 27. : Wallpaper Engine
# - - 28. : Drawful 2
# - - 29. : Mini Thief
# - 1번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199223661728 최근 게임 없음
# - - 0. : Portal
# - - 1. : Team Fortress 2
# - - 2. : Left 4 Dead 2
# - - 3. : Portal 2
# - - 4. : Counter-Strike 2
# - - 5. : Dark Messiah of Might & Magic Single Player
# - - 6. : Dark Messiah of Might & Magic Multi-Player
# - - 7. : Plants vs. Zombies: Game of the Year
# - - 8. : Garry's Mod
# - - 9. : Terraria
# - - 10. : Batman™: Arkham Knight
# - - 11. : Starbound
# - - 12. : The Stanley Parable
# - - 13. : Getting Over It with Bennett Foddy
# - - 14. : Rust
# - - 15. : Subnautica
# - - 16. : Gang Beasts
# - - 17. : SUPERHOT
# - - 18. : Cat Goes Fishing
# - - 19. : Tom Clancy's Rainbow Six Siege
# - - 20. : Hollow Knight
# - - 21. : Starbound - Unstable
# - - 22. : Undertale
# - - 23. : Metro Exodus
# - - 24. : Wallpaper Engine
# - - 25. : Slime Rancher
# - - 26. : Night in the Woods
# - - 27. : Celeste
# - - 28. : Totally Accurate Battle Simulator
# - - 29. : Half-Life: Alyx
# - 1번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : Valheim
# - - 2. : Phasmophobia
# - - 3. : RISK: Global Domination
# - - 4. : Windrose
# - - 5. : RuneScape: Dragonwilds
# - - 6. : PEAK
# - - 7. : Schedule I
# - - 8. : STAR WARS™ Battlefront™ II
# - - 9. : R.E.P.O.
# - - 10. : Subnautica 2
# - - 11. : Subnautica
# - - 12. : Poppy Playtime
# - - 13. : Subnautica: Below Zero
# - - 14. : One-armed robber
# - - 15. : Marvel Rivals
# - - 16. : Far Far West
# - - 17. : Emissary Zero
# - - 18. : Backrooms: Escape Together
# - - 19. : March of Empires
# - - 20. : Murky Divers
# - - 21. : Roadside Research
# - - 22. : GONE Fishing
# - - 23. : Goofy Gorillas
# - - 24. : RV There Yet?
# - - 25. : LOCKDOWN Protocol
# - - 26. : Green Hell
# - - 27. : Escape the Backrooms
# - - 28. : Project: Doors Demo
# - - 29. : Inside the Backrooms
# - 1번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Rust
# - - 2. : Teardown
# - - 3. : R.E.P.O.
# - - 4. : People Playground
# - - 5. : Assetto Corsa
# - - 6. : Blender
# - - 7. : The Forest
# - - 8. : Portal 2
# - - 9. : Half-Life 2
# - - 10. : HITMAN World of Assassination
# - - 11. : Crysis Remastered
# - - 12. : Hitman: Absolution
# - - 13. : Left 4 Dead 2
# - - 14. : Banana Shooter
# - - 15. : Squad
# - - 16. : Sons Of The Forest
# - - 17. : Deceit
# - - 18. : Brick Rigs
# - - 19. : Arma 3
# - - 20. : PEAK
# - - 21. : Crysis 2 Remastered
# - - 22. : Half-Life
# - - 23. : Brainrot Online
# - - 24. : Supermarket Together
# - - 25. : Portal
# - - 26. : Aragami
# - - 27. : Hitman: Blood Money
# - - 28. : Zup! S
# - - 29. : LIZARDS MUST DIE
# - 1번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Rust
# - - 2. : ARC Raiders
# - - 3. : Being a DIK
# - - 4. : Satisfactory
# - - 5. : Cities: Skylines
# - - 6. : Garry's Mod
# - - 7. : Euro Truck Simulator 2
# - - 8. : Schedule I
# - - 9. : Grand Theft Auto V Legacy
# - - 10. : Hearts of Iron IV
# - - 11. : Red Dead Redemption 2
# - - 12. : Town of Salem
# - - 13. : Golf With Your Friends
# - - 14. : Transport Fever 2
# - - 15. : TBH: Task Bar Hero
# - - 16. : SimAirport
# - - 17. : Football Manager 2022
# - - 18. : The Walking Dead
# - - 19. : Yakuza 0
# - - 20. : Marvel’s Spider-Man Remastered
# - - 21. : NARUTO SHIPPUDEN: Ultimate Ninja STORM 2
# - - 22. : Hades
# - - 23. : 911 Operator
# - - 24. : The Last of Us™ Part II Remastered
# - - 25. : Detroit: Become Human
# - - 26. : Deadlock
# - - 27. : Batman - The Telltale Series
# - - 28. : NARUTO SHIPPUDEN: Ultimate Ninja STORM 4
# - - 29. : Counter-Strike: Source
# - 1번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : GoreBox
# - - 2. : Crosshair V2
# - - 3. : EZ-Crosshair
# - - 4. : Soundpad
# - - 5. : Among Us
# - - 6. : Five Nights at Freddy's: Security Breach
# - - 7. : Counter-Strike 2
# - - 8. : Far Cry 4
# - - 9. : Far Cry 6
# - - 10. : DELTARUNE
# - - 11. : Detroit: Become Human
# - - 12. : Terraria
# - - 13. : Half-Life 2
# - - 14. : Far Cry 5
# - - 15. : Teardown
# - - 16. : Undertale
# - - 17. : One-armed robber
# - - 18. : Dead by Daylight
# - - 19. : MiSide
# - - 20. : Far Cry® 3
# - - 21. : Portal 2
# - - 22. : Portal
# - - 23. : Poppy Playtime
# - - 24. : Geometry Dash
# - - 25. : Hotline Miami 2: Wrong Number
# - - 26. : Stumble Guys
# - - 27. : One-armed cook
# - - 28. : Metro 2033 Redux
# - - 29. : People Playground
# - 1번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199040500135 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Half-Life 2: Deathmatch
# - - 2. : Half-Life Deathmatch: Source
# - - 3. : Left 4 Dead
# - - 4. : Left 4 Dead 2
# - - 5. : Portal 2
# - - 6. : Counter-Strike 2
# - - 7. : Killing Floor
# - - 8. : Garry's Mod
# - - 9. : Spore
# - - 10. : The Witcher: Enhanced Edition
# - - 11. : Sniper Ghost Warrior 2
# - - 12. : Metro 2033
# - - 13. : LIMBO
# - - 14. : Borderlands 2
# - - 15. : Borderlands 2 RU
# - - 16. : Planets Under Attack
# - - 17. : PAYDAY 2
# - - 18. : RPG Maker VX Ace
# - - 19. : Just Cause 3
# - - 20. : Killing Floor 2
# - - 21. : Dying Light
# - - 22. : The Forest
# - - 23. : Plague Inc: Evolved
# - - 24. : 7 Days to Die
# - - 25. : Rust
# - - 26. : World War III: Black Gold
# - - 27. : XCOM 2
# - - 28. : Metro 2033 Redux
# - - 29. : Metro: Last Light Redux
# - 1번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Grand Theft Auto V Legacy
# - - 1. : Counter-Strike 2
# - - 2. : Rust
# - - 3. : Crosshair X
# - - 4. : Unturned
# - - 5. : Sons Of The Forest
# - - 6. : Farming Simulator 25
# - - 7. : Soundpad
# - - 8. : BeamNG.drive
# - - 9. : Call of Duty®
# - - 10. : Castle Story
# - - 11. : Banana
# - - 12. : Arena Breakout: Infinite
# - - 13. : WorldBox - God Simulator
# - - 14. : PixARK
# - - 15. : Delta Force
# - - 16. : Dying Light 2: Reloaded Edition
# - - 17. : Bloons TD Battles 2
# - - 18. : 7 Days to Die
# - - 19. : The Crew 2
# - - 20. : Raft
# - - 21. : PAYDAY 2
# - - 22. : Stumble Guys
# - - 23. : Schedule I: Free Sample
# - - 24. : Watch_Dogs 2
# - - 25. : Wallpaper Alive
# - - 26. : Days Gone
# - - 27. : War Thunder
# - - 28. : Dead by Daylight
# - - 29. : Muck
# - 1번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike
# - - 1. : Rust
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : Counter-Strike: Source
# - - 4. : Dying Light 2: Reloaded Edition
# - - 5. : Black Squad
# - - 6. : Drive Beyond Horizons
# - - 7. : Paladins
# - - 8. : Dying Light
# - - 9. : Destiny 2
# - - 10. : Banana
# - - 11. : Garry's Mod
# - - 12. : Swordsman
# - - 13. : Remnant II
# - - 14. : Cyber Hunter
# - - 15. : Medieval Dynasty
# - - 16. : PUBG: BATTLEGROUNDS
# - - 17. : Icarus
# - - 18. : Dying Light: The Beast
# - - 19. : RV There Yet?
# - - 20. : Line of Sight
# - - 21. : Warface: Clutch
# - - 22. : CRSED: Cuisine Royale
# - - 23. : Green Hell
# - - 24. : Lost Light
# - - 25. : Escape the Backrooms
# - - 26. : PAYDAY 2
# - - 27. : Ring of Elysium
# - - 28. : Damned
# - - 29. : Once Human
# - 1번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : Counter-Strike 2
# - - 2. : Apex Legends
# - - 3. : Rocket League
# - - 4. : Terraria
# - - 5. : Dead by Daylight
# - - 6. : Grand Theft Auto V Legacy
# - - 7. : tModLoader
# - - 8. : Tom Clancy's Rainbow Six Siege
# - - 9. : PAYDAY 2
# - - 10. : Shakes and Fidget
# - - 11. : The Witcher 3: Wild Hunt
# - - 12. : Warframe
# - - 13. : Bloons TD 6
# - - 14. : Team Fortress 2
# - - 15. : Cookie Clicker
# - - 16. : Wallpaper Engine
# - - 17. : Euro Truck Simulator 2
# - - 18. : Cyberpunk 2077
# - - 19. : Forza Horizon 4
# - - 20. : Paladins
# - - 21. : Aimlabs
# - - 22. : Geometry Dash
# - - 23. : DSX
# - - 24. : Cuphead
# - - 25. : God of War
# - - 26. : Marvel Rivals
# - - 27. : SpeedRunners
# - - 28. : Transformice
# - - 29. : Saints Row: The Third
# - 1번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Grand Theft Auto V Legacy
# - - 2. : Red Dead Online
# - - 3. : Rust
# - - 4. : Call of Duty®: Modern Warfare® II
# - - 5. : Garry's Mod
# - - 6. : Red Dead Redemption 2
# - - 7. : Wallpaper Engine
# - - 8. : Ready or Not
# - - 9. : Contraband Police
# - - 10. : Call of Duty®: Modern Warfare®
# - - 11. : Resident Evil 4
# - - 12. : HITMAN World of Assassination
# - - 13. : Life is Strange: Before the Storm Remastered
# - - 14. : Life is Strange Remastered
# - - 15. : Grand Theft Auto V Enhanced
# - - 16. : Life is Strange 2
# - - 17. : Call of Duty®: Modern Warfare® III
# - - 18. : PAYDAY 2
# - - 19. : Cyberpunk 2077
# - - 20. : People Playground
# - - 21. : Life is Strange™
# - - 22. : Your Mother
# - - 23. : DR LIVESEY ROM AND DEATH EDITION
# - - 24. : RUSSIA BATTLEGROUNDS
# - - 25. : Counter-Strike:Global Offensive
# - - 26. : Left 4 Dead 2
# - - 27. : Counter-Strike
# - - 28. : Call of Duty®
# - - 29. : Kingdom Come: Deliverance
# - 1번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199279081053 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Counter-Strike: Condition Zero
# - - 2. : Counter-Strike: Condition Zero Deleted Scenes
# - - 3. : Half-Life 2
# - - 4. : Counter-Strike: Source
# - - 5. : Half-Life 2: Deathmatch
# - - 6. : Half-Life Deathmatch: Source
# - - 7. : Portal
# - - 8. : Left 4 Dead 2
# - - 9. : Portal 2
# - - 10. : Counter-Strike 2
# - - 11. : Garry's Mod
# - - 12. : Eets
# - - 13. : Assassin's Creed II
# - - 14. : Metro: Last Light Complete Edition
# - - 15. : Borderlands 2
# - - 16. : Terraria
# - - 17. : Deponia
# - - 18. : Borderlands 2 RU
# - - 19. : The Forest
# - - 20. : Dungeon of the ENDLESS™
# - - 21. : Rust
# - - 22. : Serena
# - - 23. : Metro 2033 Redux
# - - 24. : UNLOVED
# - - 25. : HuniePop
# - - 26. : Weapon of Choice
# - - 27. : Undertale
# - - 28. : Pankapu
# - - 29. : Blackwake
# - 2번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Apex Legends
# - - 2. : Dead by Daylight
# - - 3. : Rocket League
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : Call of Duty®
# - - 6. : Left 4 Dead 2
# - - 7. : GUILTY GEAR -STRIVE-
# - - 8. : Wallpaper Engine
# - - 9. : ELDEN RING NIGHTREIGN
# - - 10. : Garry's Mod
# - - 11. : Tom Clancy's The Division 2
# - - 12. : Sword Art Online: Fatal Bullet
# - - 13. : Tom Clancy's The Division
# - - 14. : VRChat
# - - 15. : Tom Clancy's Ghost Recon® Wildlands
# - - 16. : ELDEN RING
# - - 17. : Bongo Cat
# - - 18. : Unturned
# - - 19. : Grand Theft Auto V Legacy
# - - 20. : Persona 3 Reload
# - - 21. : Mini Cozy Room: Lo-Fi
# - - 22. : Call of Duty: Black Ops II - Multiplayer
# - - 23. : Black Squad
# - - 24. : ARMORED CORE™ VI FIRES OF RUBICON™
# - - 25. : Ready or Not
# - - 26. : Insurgency
# - - 27. : Strinova
# - - 28. : Insurgency: Sandstorm
# - - 29. : gogh: Focus with Your Avatar
# - 2번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : ELDEN RING
# - - 1. : Dead by Daylight
# - - 2. : Hollow Knight
# - - 3. : Yakuza 0
# - - 4. : Terraria
# - - 5. : Muse Dash
# - - 6. : Plants vs. Zombies: Game of the Year
# - - 7. : HITMAN World of Assassination
# - - 8. : Kingdom Rush Vengeance
# - - 9. : NieR:Automata™
# - - 10. : Castle Crashers
# - - 11. : Sifu
# - - 12. : NUKITASHI
# - - 13. : God of War
# - - 14. : OMORI
# - - 15. : The Forest
# - - 16. : Left 4 Dead 2
# - - 17. : Kingdom Rush
# - - 18. : Kingdom Rush 5: Alliance TD
# - - 19. : Summer Memories
# - - 20. : The Escapists 2
# - - 21. : Kingdom Rush Origins
# - - 22. : Content Warning
# - - 23. : Chill with You Lo-Fi Story
# - - 24. : Circle Empires
# - - 25. : Totally Accurate Battle Simulator
# - - 26. : ARK: Survival Evolved
# - - 27. : Undertale
# - - 28. : JoJo's Bizarre Adventure: All-Star Battle R
# - - 29. : Wallpaper Engine
# - 2번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198069752493 최근 게임 없음
# - - 0. : Team Fortress 2
# - - 1. : Left 4 Dead
# - - 2. : Left 4 Dead 2
# - - 3. : Portal 2
# - - 4. : Counter-Strike 2
# - - 5. : Killing Floor
# - - 6. : Dangerous Waters
# - - 7. : Two Worlds: Epic Edition
# - - 8. : The Ship
# - - 9. : The Ship Single Player
# - - 10. : The Ship Tutorial
# - - 11. : X2: The Threat
# - - 12. : X3: Reunion
# - - 13. : X3: Terran Conflict
# - - 14. : X: Beyond the Frontier
# - - 15. : X-Tension
# - - 16. : FlatOut 2
# - - 17. : Men of War: Red Tide
# - - 18. : King's Bounty: Armored Princess
# - - 19. : Painkiller Overdose
# - - 20. : Peggle Deluxe
# - - 21. : Peggle Nights
# - - 22. : Psychonauts
# - - 23. : Sid Meier's Civilization IV
# - - 24. : Sid Meier's Civilization III: Complete
# - - 25. : Sid Meier's Pirates!
# - - 26. : Sid Meier's Civilization IV: Warlords
# - - 27. : Garry's Mod
# - - 28. : Warhammer 40,000: Dawn of War - Anniversary Edition
# - - 29. : Warhammer 40,000: Dawn of War - Dark Crusade
# - 2번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Dead by Daylight
# - - 1. : Counter-Strike 2
# - - 2. : Phasmophobia
# - - 3. : Bongo Cat
# - - 4. : The Binding of Isaac: Rebirth
# - - 5. : Garry's Mod
# - - 6. : ASTRONEER
# - - 7. : Euro Truck Simulator 2
# - - 8. : Microsoft Flight Simulator (2020)
# - - 9. : People Playground
# - - 10. : Geometry Dash
# - - 11. : Bloons TD 6
# - - 12. : PEAK
# - - 13. : Sea of Thieves
# - - 14. : Blender
# - - 15. : Deep Rock Galactic
# - - 16. : Content Warning
# - - 17. : Lethal Company
# - - 18. : Brick Rigs
# - - 19. : R.E.P.O.
# - - 20. : Don't Starve Together
# - - 21. : Age of History II
# - - 22. : No Man's Sky
# - - 23. : Terraria
# - - 24. : War Thunder
# - - 25. : The Sims™ 4
# - - 26. : WorldBox - God Simulator
# - - 27. : Cities: Skylines
# - - 28. : theHunter: Call of the Wild™
# - - 29. : Totally Accurate Battle Simulator
# - 2번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Arma 3
# - - 1. : Soundpad
# - - 2. : Rust
# - - 3. : War Thunder
# - - 4. : Squad
# - - 5. : Grand Theft Auto V Legacy
# - - 6. : DayZ
# - - 7. : Dead by Daylight
# - - 8. : DCS World Steam Edition
# - - 9. : Assetto Corsa
# - - 10. : Ready or Not
# - - 11. : Destiny 2
# - - 12. : Project Zomboid
# - - 13. : Call of Duty®
# - - 14. : Among Us
# - - 15. : Garry's Mod
# - - 16. : Phasmophobia
# - - 17. : SCP: Secret Laboratory
# - - 18. : Unturned
# - - 19. : Arma Reforger
# - - 20. : World of Warships
# - - 21. : Cyberpunk 2077
# - - 22. : World of Tanks
# - - 23. : Wallpaper Engine
# - - 24. : Battlefield 4™
# - - 25. : Red Dead Online
# - - 26. : ELDEN RING NIGHTREIGN
# - - 27. : Assetto Corsa Competizione
# - - 28. : Umamusume: Pretty Derby
# - - 29. : Apex Legends
# - 2번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Euro Truck Simulator 2
# - - 2. : Half-Life 2
# - - 3. : POSTAL 2
# - - 4. : Left 4 Dead 2
# - - 5. : The Binding of Isaac: Rebirth
# - - 6. : Hotline Miami
# - - 7. : Dead by Daylight
# - - 8. : Hotline Miami 2: Wrong Number
# - - 9. : DELTARUNE
# - - 10. : Portal 2
# - - 11. : Stumble Guys
# - - 12. : Resident Evil 4
# - - 13. : Undertale
# - - 14. : Ultimate Custom Night
# - - 15. : Among Us
# - - 16. : Soundpad Demo
# - - 17. : Garry's Mod
# - - 18. : Buckshot Roulette
# - - 19. : Left 4 Dead
# - - 20. : Hollow Knight
# - - 21. : Counter-Strike 2
# - - 22. : Metro 2033 Redux
# - - 23. : War Thunder
# - - 24. : DOOM Eternal
# - - 25. : Portal
# - - 26. : GeoGuessr Steam Edition
# - - 27. : Counter-Strike:Global Offensive
# - - 28. : CHUCHEL
# - - 29. : American Truck Simulator
# - 2번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : War Thunder
# - - 1. : Dota 2
# - - 2. : STALZONE
# - - 3. : Tom Clancy's Rainbow Six Siege
# - - 4. : Hearts of Iron IV
# - - 5. : Counter-Strike 2
# - - 6. : Dead by Daylight
# - - 7. : Red Dead Redemption 2
# - - 8. : Broken Arrow
# - - 9. : Team Fortress 2
# - - 10. : Fallout 76
# - - 11. : Stay Out
# - - 12. : Garry's Mod
# - - 13. : Warframe
# - - 14. : Battlefield™ 1
# - - 15. : HELLDIVERS™ 2
# - - 16. : Devil May Cry 5
# - - 17. : Terraria
# - - 18. : Battlefield 4™
# - - 19. : Project Zomboid
# - - 20. : PAYDAY 2
# - - 21. : Cyberpunk 2077
# - - 22. : Apex Legends
# - - 23. : Danganronpa V3: Killing Harmony
# - - 24. : Atomic Heart
# - - 25. : Persona 5 Royal
# - - 26. : Battlefield™ 6
# - - 27. : Battlefield™ 2042
# - - 28. : PUBG: BATTLEGROUNDS
# - - 29. : Call of Duty®: Black Ops Cold War
# - 2번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Marvel Rivals
# - - 2. : Banana
# - - 3. : PUBG: BATTLEGROUNDS
# - - 4. : Asphalt Legends
# - - 5. : Deadlock
# - - 6. : Call of Duty®
# - - 7. : Chill Corner
# - - 8. : Aimlabs
# - - 9. : The Crew 2
# - - 10. : THE FINALS
# - - 11. : Call of Duty®: Modern Warfare® II
# - - 12. : The Sims™ 4
# - - 13. : SpaceEngine
# - - 14. : VRChat
# - - 15. : Squad
# - - 16. : Forza Horizon 5
# - - 17. : Cyberpunk 2077
# - - 18. : Assassin's Creed Mirage
# - - 19. : Boti: Byteland Overclocked
# - - 20. : Saints Row IV
# - - 21. : VAIL
# - - 22. : Grand Theft Auto V Legacy
# - - 23. : Assassin's Creed Origins
# - - 24. : Marvel's Avengers - The Definitive Edition
# - - 25. : HackHub - Ultimate Hacker Simulator
# - - 26. : Grand Theft Auto V Enhanced
# - - 27. : EA SPORTS FC™ 25
# - - 28. : Ghost Recon Breakpoint
# - - 29. : Marvel's Guardians of the Galaxy
# - 2번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Dead by Daylight
# - - 1. : Counter-Strike 2
# - - 2. : ELDEN RING
# - - 3. : Resident Evil 4
# - - 4. : Monster Hunter: World
# - - 5. : 7 Days to Die
# - - 6. : Delta Force
# - - 7. : Grand Theft Auto V Legacy
# - - 8. : Blender
# - - 9. : ELDEN RING NIGHTREIGN
# - - 10. : ARK: Survival Evolved
# - - 11. : DARK SOULS™ III
# - - 12. : Resident Evil 6
# - - 13. : Albion Online
# - - 14. : Monster Hunter Wilds
# - - 15. : Resident Evil 2
# - - 16. : Left 4 Dead 2
# - - 17. : Counter-Strike: Condition Zero
# - - 18. : Green Hell
# - - 19. : Planet Coaster
# - - 20. : Supermarket Simulator
# - - 21. : Garry's Mod
# - - 22. : Resident Evil Requiem
# - - 23. : Resident Evil Village
# - - 24. : PUBG: BATTLEGROUNDS
# - - 25. : Unturned
# - - 26. : Resident Evil 3
# - - 27. : NARAKA: BLADEPOINT
# - - 28. : Resident Evil 7 Biohazard
# - - 29. : Serious Sam 2
# - 2번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199589647383 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Team Fortress Classic
# - - 2. : Half-Life: Opposing Force
# - - 3. : Half-Life
# - - 4. : Counter-Strike: Condition Zero
# - - 5. : Counter-Strike: Condition Zero Deleted Scenes
# - - 6. : Half-Life: Blue Shift
# - - 7. : Half-Life 2
# - - 8. : Counter-Strike: Source
# - - 9. : Half-Life: Source
# - - 10. : Half-Life 2: Deathmatch
# - - 11. : Half-Life Deathmatch: Source
# - - 12. : Portal
# - - 13. : Left 4 Dead
# - - 14. : Left 4 Dead 2
# - - 15. : Portal 2
# - - 16. : Garry's Mod
# - - 17. : Eets
# - - 18. : Resident Evil 5
# - - 19. : Deponia
# - - 20. : Alien: Isolation
# - - 21. : Hotline Miami
# - - 22. : Resident Evil 6
# - - 23. : Outlast
# - - 24. : Resident Evil 4 (2005)
# - - 25. : NEKOPARA Vol. 1
# - - 26. : Tom Clancy's Rainbow Six Siege
# - - 27. : Dead by Daylight
# - - 28. : NEKOPARA Vol. 0
# - - 29. : Rise of the Tomb Raider
# - 2번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Dead by Daylight
# - - 1. : Dying Light
# - - 2. : Soundpad
# - - 3. : Dishonored RHCP
# - - 4. : Counter-Strike 2
# - - 5. : People Playground
# - - 6. : Garry's Mod
# - - 7. : Subnautica
# - - 8. : Just Cause 2
# - - 9. : Just Cause 3
# - - 10. : Metro Exodus
# - - 11. : Sea of Thieves
# - - 12. : Dishonored 2
# - - 13. : METAL GEAR SOLID V: THE PHANTOM PAIN
# - - 14. : The Walking Dead: The Telltale Definitive Series
# - - 15. : SnowRunner
# - - 16. : Mad Max
# - - 17. : Far Cry 6
# - - 18. : Metro 2033 Redux
# - - 19. : The Forest
# - - 20. : Metro: Last Light Complete Edition
# - - 21. : Escape the Backrooms
# - - 22. : CASE 2: Animatronics Survival
# - - 23. : Maneater
# - - 24. : METAL GEAR RISING: REVENGEANCE
# - - 25. : Dying Light 2: Reloaded Edition
# - - 26. : Subnautica: Below Zero
# - - 27. : PROTOTYPE 2
# - - 28. : Days Gone
# - - 29. : Far Cry
# - 2번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# - - 0. : VRChat
# - - 1. : Call of Duty®
# - - 2. : OVR Toolkit
# - - 3. : OVR Advanced Settings
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : BeamNG.drive
# - - 6. : Dead by Daylight
# - - 7. : Escape from Tarkov
# - - 8. : Borderlands 3
# - - 9. : Borderlands® 4
# - - 10. : skate.
# - - 11. : Grand Theft Auto V Legacy
# - - 12. : Lethal Company
# - - 13. : Rust
# - - 14. : Terraria
# - - 15. : Wallpaper Engine
# - - 16. : The Elder Scrolls V: Skyrim Special Edition
# - - 17. : ARC Raiders
# - - 18. : Palworld
# - - 19. : Fallout 4
# - - 20. : CarX Drift Racing Online
# - - 21. : Call of Duty®: Black Ops Cold War
# - - 22. : Borderlands 2
# - - 23. : Session: Skate Sim
# - - 24. : Resident Evil 4
# - - 25. : Apex Legends
# - - 26. : PUBG: BATTLEGROUNDS
# - - 27. : Resident Evil Requiem
# - - 28. : American Truck Simulator
# - - 29. : Phasmophobia
# - 2번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Limbus Company
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : Dread Hunger
# - - 4. : ELDEN RING NIGHTREIGN
# - - 5. : Escape from Tarkov
# - - 6. : Goose Goose Duck
# - - 7. : Terraria
# - - 8. : tModLoader
# - - 9. : Cyberpunk 2077
# - - 10. : The Outlast Trials
# - - 11. : Stardew Valley
# - - 12. : Left 4 Dead 2
# - - 13. : Wallpaper Engine
# - - 14. : Dead by Daylight
# - - 15. : Grand Theft Auto V Enhanced
# - - 16. : Sid Meier's Civilization VI
# - - 17. : Sinister Night 2
# - - 18. : Hollow Knight
# - - 19. : Warhammer: Vermintide 2
# - - 20. : Lethal Company
# - - 21. : Resident Evil 6
# - - 22. : Subnautica
# - - 23. : Barotrauma
# - - 24. : Palworld
# - - 25. : Lobotomy Corporation
# - - 26. : No Man's Sky
# - - 27. : Lossless Scaling
# - - 28. : Project Zomboid
# - - 29. : Library Of Ruina
# - 2번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rocket League
# - - 1. : Dead by Daylight
# - - 2. : ARK: Survival Evolved
# - - 3. : Fall Guys
# - - 4. : Grand Theft Auto V Legacy
# - - 5. : Valheim
# - - 6. : Assassin's Creed Valhalla
# - - 7. : The Forest
# - - 8. : Assassin's Creed Origins
# - - 9. : Forza Horizon 5
# - - 10. : Forza Horizon 6
# - - 11. : Monster Hunter Wilds
# - - 12. : Red Dead Redemption 2
# - - 13. : FIFA 22
# - - 14. : Sons Of The Forest
# - - 15. : Assassin's Creed Odyssey
# - - 16. : Dying Light
# - - 17. : Attack on Titan 2 - A.O.T.2
# - - 18. : EA SPORTS™ FIFA 23
# - - 19. : Black Myth: Wukong
# - - 20. : DEVOUR
# - - 21. : Lethal Company
# - - 22. : Cookie Clicker
# - - 23. : EA SPORTS FC™ 24
# - - 24. : PEAK
# - - 25. : Plants vs. Zombies: Game of the Year
# - - 26. : EA SPORTS FC™ 25
# - - 27. : Megabonk
# - - 28. : Hogwarts Legacy
# - - 29. : Vampire Survivors
# - 2번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198124133723 최근 게임 없음
# - - 0. : Half-Life
# - - 1. : Half-Life 2
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Portal
# - - 5. : Team Fortress 2
# - - 6. : Portal 2
# - - 7. : DOOM + DOOM II
# - - 8. : Psychonauts
# - - 9. : Fallout 3 - Game of the Year Edition
# - - 10. : Fallout: New Vegas
# - - 11. : Fallout
# - - 12. : Metro 2033
# - - 13. : Metro: Last Light Complete Edition
# - - 14. : Borderlands 2
# - - 15. : Amnesia: The Dark Descent
# - - 16. : The Darkness II
# - - 17. : Sonic Adventure DX
# - - 18. : Sonic Generations
# - - 19. : Project Zomboid
# - - 20. : Quantum Conundrum
# - - 21. : Cave Story+
# - - 22. : Jet Set Radio
# - - 23. : Sonic Adventure™ 2
# - - 24. : DmC Devil May Cry
# - - 25. : The Stanley Parable
# - - 26. : System Shock® 2 (1999)
# - - 27. : Amnesia: A Machine for Pigs
# - - 28. : XCOM 2
# - - 29. : Devil May Cry 4 Special Edition
# - 3번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : War Thunder
# - - 2. : Counter-Strike 2
# - - 3. : The Elder Scrolls Online
# - - 4. : Lost Ark
# - - 5. : Last Epoch
# - - 6. : Dwarven Realms
# - - 7. : Cyberpunk 2077
# - - 8. : Satisfactory
# - - 9. : Call of Duty®
# - - 10. : Lethal Company
# - - 11. : The Elder Scrolls V: Skyrim Special Edition
# - - 12. : Factorio
# - - 13. : Dishonored
# - - 14. : Wallpaper Engine
# - - 15. : Schedule I
# - - 16. : Vampire Survivors
# - - 17. : Brotato
# - - 18. : Valheim
# - - 19. : 9 Kings
# - - 20. : Insurgency: Sandstorm
# - - 21. : Dishonored 2
# - - 22. : No Man's Sky
# - - 23. : Tom Clancy's Rainbow Six Siege
# - - 24. : Prey
# - - 25. : Shadow of the Tomb Raider
# - - 26. : Ultimate Chicken Horse
# - - 27. : Just Cause 3
# - - 28. : Cell to Singularity - Evolution Never Ends
# - - 29. : They Are Billions
# - 3번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Counter-Strike 2
# - - 2. : Yu-Gi-Oh!  Master Duel
# - - 3. : Counter-Strike: Source
# - - 4. : Warframe
# - - 5. : Left 4 Dead 2
# - - 6. : No More Room in Hell
# - - 7. : Delta Force
# - - 8. : Overwatch®
# - - 9. : Plants vs. Zombies: Game of the Year
# - - 10. : Tom Clancy's Rainbow Six Siege
# - - 11. : Fistful of Frags
# - - 12. : PAYDAY 3
# - - 13. : Fallout 4
# - - 14. : Tom Clancy's Ghost Recon Phantoms - NA
# - - 15. : Yu-Gi-Oh! Duel Links
# - - 16. : Blender
# - - 17. : Muse Dash
# - - 18. : Ultimate Custom Night
# - - 19. : Rise of the Tomb Raider
# - - 20. : Grand Theft Auto V Legacy
# - - 21. : NEKOPARA Vol. 1
# - - 22. : TERA
# - - 23. : Anomaly Zone
# - - 24. : War Thunder
# - - 25. : NEKOPARA Vol. 0
# - - 26. : Quake II
# - - 27. : Unturned
# - - 28. : Book of Yog Idle RPG
# - - 29. : The Elder Scrolls V: Skyrim Special Edition
# - 3번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Age of Empires III: Definitive Edition
# - - 1. : Dying Light
# - - 2. : Wallpaper Engine
# - - 3. : Senren＊Banka
# - - 4. : Left 4 Dead 2
# - - 5. : NEKOPARA Vol. 1
# - - 6. : NEKOPARA Vol. 0
# - - 7. : The NOexistenceN of you AND me
# - - 8. : NEKOPARA Extra
# - - 9. : NEEDY STREAMER OVERLOAD
# - - 10. : 星空列车与白的旅行
# - - 11. : NEKOPARA Vol. 3
# - - 12. : NEKOPARA Vol. 2
# - - 13. : Maitetsu:Pure Station
# - - 14. : NEKOPARA Vol. 4
# - - 15. : The Hungry Lamb: Traveling in the Late Ming Dynasty
# - - 16. : Tricolour Lovestory
# - - 17. : your wife
# - - 18. : Your Mother
# - - 19. : Your Daughter
# - - 20. : Aliya: Timelink
# - - 21. : Muse Dash
# - - 22. : Banner of the Maid
# - - 23. : Counter-Strike 2
# - - 24. : Fantasy Aquarium
# - - 25. : KamiYaba: Destiny on a Dicey Deadline
# - - 26. : Grand Theft Auto V Legacy
# - - 27. : Garry's Mod
# - - 28. : Counter-Strike: Source
# - - 29. : Titanfall® 2
# - 3번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199003463982 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Team Fortress Classic
# - - 2. : Day of Defeat
# - - 3. : Deathmatch Classic
# - - 4. : Half-Life: Opposing Force
# - - 5. : Ricochet
# - - 6. : Half-Life
# - - 7. : Counter-Strike: Condition Zero
# - - 8. : Counter-Strike: Condition Zero Deleted Scenes
# - - 9. : Half-Life: Blue Shift
# - - 10. : Half-Life 2
# - - 11. : Counter-Strike: Source
# - - 12. : Half-Life: Source
# - - 13. : Day of Defeat: Source
# - - 14. : Half-Life 2: Deathmatch
# - - 15. : Half-Life Deathmatch: Source
# - - 16. : Portal
# - - 17. : Left 4 Dead
# - - 18. : Left 4 Dead 2
# - - 19. : Portal 2
# - - 20. : Killing Floor
# - - 21. : Plants vs. Zombies: Game of the Year
# - - 22. : Evil Genius
# - - 23. : Garry's Mod
# - - 24. : Eets
# - - 25. : Ghost Master
# - - 26. : Battlestations: Midway
# - - 27. : Just Cause
# - - 28. : Deus Ex: Game of the Year Edition
# - - 29. : Deus Ex: Invisible War
# - 3번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Left 4 Dead 2
# - - 2. : Assetto Corsa Competizione
# - - 3. : BeamNG.drive
# - - 4. : Geometry Dash
# - - 5. : Wolfenstein II: The New Colossus
# - - 6. : Half-Life 2
# - - 7. : Grand Theft Auto V Legacy
# - - 8. : DOOM Eternal
# - - 9. : Dead Cells
# - - 10. : Cry of Fear
# - - 11. : Cyberpunk 2077
# - - 12. : POSTAL 2
# - - 13. : Buckshot Roulette
# - - 14. : Far Cry® 3
# - - 15. : Battlefield 3™
# - - 16. : Wallpaper Engine
# - - 17. : Fears to Fathom - Woodbury Getaway
# - - 18. : Banana
# - - 19. : Forza Horizon 4
# - - 20. : Rush Rally 3
# - - 21. : Post Void
# - - 22. : FlatOut: Ultimate Carnage Collector's Edition
# - - 23. : Portal 2
# - - 24. : Fears to Fathom - Episode 2
# - - 25. : Metro 2033 Redux
# - - 26. : Untitled Goose Game
# - - 27. : rFactor 2
# - - 28. : Phasmophobia
# - - 29. : FPV Kamikaze Drone
# - 3번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199085366031 최근 게임 없음
# - - 0. : Team Fortress Classic
# - - 1. : Half-Life 2
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Left 4 Dead 2
# - - 5. : Garry's Mod
# - - 6. : Serious Sam 3: BFE
# - - 7. : Metro: Last Light Complete Edition
# - - 8. : Syberia
# - - 9. : Syberia 2
# - - 10. : Terraria
# - - 11. : Project Zomboid
# - - 12. : Castle Crashers
# - - 13. : Call of Juarez Gunslinger
# - - 14. : PAYDAY 2
# - - 15. : Don't Starve
# - - 16. : Just Cause 3
# - - 17. : Euro Truck Simulator 2
# - - 18. : Getting Over It with Bennett Foddy
# - - 19. : The Forest
# - - 20. : The Binding of Isaac: Rebirth
# - - 21. : 7 Days to Die
# - - 22. : Rust
# - - 23. : Subnautica
# - - 24. : Cuphead
# - - 25. : American Truck Simulator
# - - 26. : Grand Theft Auto V Legacy
# - - 27. : This War of Mine
# - - 28. : BeamNG.drive
# - - 29. : Metro 2033 Redux
# - 3번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198402363447 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Counter-Strike: Condition Zero
# - - 2. : Counter-Strike: Condition Zero Deleted Scenes
# - - 3. : Half-Life 2
# - - 4. : Counter-Strike: Source
# - - 5. : Half-Life 2: Deathmatch
# - - 6. : Half-Life Deathmatch: Source
# - - 7. : Portal
# - - 8. : Team Fortress 2
# - - 9. : Left 4 Dead
# - - 10. : Left 4 Dead 2
# - - 11. : Portal 2
# - - 12. : Counter-Strike 2
# - - 13. : Killing Floor
# - - 14. : Garry's Mod
# - - 15. : Eets
# - - 16. : BioShock
# - - 17. : BioShock 2
# - - 18. : BioShock Infinite
# - - 19. : Borderlands GOTY
# - - 20. : DOOM 3
# - - 21. : DOOM 3: Resurrection of Evil
# - - 22. : Tom Clancy's Rainbow Six: Vegas 2
# - - 23. : Fallout: New Vegas
# - - 24. : SEGA Mega Drive & Genesis Classics
# - - 25. : Killing Floor Mod: Defence Alliance 2
# - - 26. : Fallout
# - - 27. : Borderlands 2
# - - 28. : Sonic Generations
# - - 29. : Terraria
# - 3번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Geometry Dash
# - - 1. : Counter-Strike 2
# - - 2. : Garry's Mod
# - - 3. : People Playground
# - - 4. : Rec Room
# - - 5. : skate.
# - - 6. : VRChat
# - - 7. : Human Fall Flat
# - - 8. : Hello Neighbor
# - - 9. : Brick Rigs
# - - 10. : Who's Your Daddy?!
# - - 11. : Party Animals
# - - 12. : GoreBox
# - - 13. : Plants vs. Zombies™ Garden Warfare 2: Deluxe Edition
# - - 14. : Grand Theft Auto V Enhanced
# - - 15. : Secret Neighbor
# - - 16. : Left 4 Dead 2
# - - 17. : Gang Beasts
# - - 18. : Team Fortress 2
# - - 19. : Halo Infinite
# - - 20. : Marvel Rivals
# - - 21. : BeamNG.drive
# - - 22. : Among Us
# - - 23. : Grand Theft Auto V Legacy
# - - 24. : StarSavior
# - - 25. : SCP: Secret Laboratory
# - - 26. : Cooking Simulator
# - - 27. : Mini World: Block Art
# - - 28. : The LEGO® Movie - Videogame
# - - 29. : Supermarket Together
# - 3번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Left 4 Dead 2
# - - 1. : Team Fortress 2
# - - 2. : Garry's Mod
# - - 3. : Party Animals
# - - 4. : Crosshair V2
# - - 5. : Counter-Strike: Source
# - - 6. : People Playground
# - - 7. : Crab Game
# - - 8. : Left 4 Dead
# - - 9. : The Sims™ 4
# - - 10. : Wallpaper Engine
# - - 11. : R.E.P.O.
# - - 12. : Rubber Bandits
# - - 13. : Worms Armageddon
# - - 14. : Terraria
# - - 15. : Grand Theft Auto IV: The Complete Edition
# - - 16. : Hatsune Miku: Project DIVA Mega Mix+
# - - 17. : Counter-Strike 2
# - - 18. : OneShot: World Machine Edition
# - - 19. : Duck Game
# - - 20. : Half-Life
# - - 21. : OneShot
# - - 22. : Half-Life Deathmatch: Source
# - - 23. : The Henry Stickmin Collection
# - - 24. : Day of Defeat: Source
# - - 25. : Half-Life 2: Deathmatch
# - - 26. : Stick Fight: The Game
# - - 27. : Half-Life 2
# - - 28. : Rivals of Aether
# - - 29. : Undertale
# - 3번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Garry's Mod
# - - 2. : Subnautica
# - - 3. : The Binding of Isaac: Rebirth
# - - 4. : Terraria
# - - 5. : Fallout: New Vegas PCR
# - - 6. : tModLoader
# - - 7. : Left 4 Dead 2
# - - 8. : Soundpad
# - - 9. : Don't Starve Together
# - - 10. : Counter-Strike:Global Offensive
# - - 11. : ULTRAKILL
# - - 12. : Half-Life 2
# - - 13. : Hearts of Iron IV
# - - 14. : SCP: Secret Laboratory
# - - 15. : Rust
# - - 16. : Resident Evil 2
# - - 17. : Black Mesa
# - - 18. : Geometry Dash
# - - 19. : Portal 2
# - - 20. : STALZONE
# - - 21. : Slime Rancher
# - - 22. : Baldi's Basics Plus
# - - 23. : Portal: Revolution
# - - 24. : PAYDAY 2
# - - 25. : Natural Selection 2
# - - 26. : Wallpaper Alive
# - - 27. : VRChat
# - - 28. : Metro 2033 Redux
# - - 29. : Counter-Strike 2
# - 3번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Grand Theft Auto V Legacy
# - - 2. : Human Fall Flat
# - - 3. : Wallpaper Engine
# - - 4. : Euro Truck Simulator 2
# - - 5. : Left 4 Dead 2
# - - 6. : Cities: Skylines
# - - 7. : Thief Simulator
# - - 8. : Terraria
# - - 9. : Hearts of Iron IV
# - - 10. : Portal 2
# - - 11. : Buckshot Roulette
# - - 12. : Blender
# - - 13. : WRC 7
# - - 14. : tModLoader
# - - 15. : Portal
# - - 16. : Battlefield™ 1
# - - 17. : Left 4 Dead
# - - 18. : Don't Starve Together
# - - 19. : Battlefield™ 2042
# - - 20. : The Forest
# - - 21. : Besiege
# - - 22. : Bongo Cat
# - - 23. : The Binding of Isaac: Rebirth
# - - 24. : Don't Starve
# - - 25. : Aimlabs
# - - 26. : Thief Simulator 2
# - - 27. : Kreedz Climbing
# - - 28. : Counter-Strike:Global Offensive
# - - 29. : MECCHA CHAMELEON
# - 3번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199349057212 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Counter-Strike: Source
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Team Fortress 2
# - - 5. : Left 4 Dead 2
# - - 6. : Portal 2
# - - 7. : Counter-Strike 2
# - - 8. : Garry's Mod
# - - 9. : Hitman: Blood Money
# - - 10. : Battlestations: Midway
# - - 11. : Grand Theft Auto IV: The Complete Edition
# - - 12. : Project Zomboid
# - - 13. : Alan Wake
# - - 14. : Hitman: Absolution
# - - 15. : Hitman: Sniper Challenge
# - - 16. : Air Conflicts: Pacific Carriers
# - - 17. : Hotline Miami
# - - 18. : METAL GEAR RISING: REVENGEANCE
# - - 19. : The Forest
# - - 20. : Assetto Corsa
# - - 21. : The Binding of Isaac: Rebirth
# - - 22. : Wreckfest Throw-A-Santa + Sneak Peek 2.0
# - - 23. : Hotline Miami 2: Wrong Number
# - - 24. : BeamNG.drive
# - - 25. : Metro 2033 Redux
# - - 26. : Five Nights at Freddy's
# - - 27. : Geometry Dash
# - - 28. : Hatred
# - - 29. : Black Mesa
# - 3번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : EA SPORTS FC™ 24
# - - 1. : Project Zomboid
# - - 2. : Tom Clancy's Rainbow Six Siege
# - - 3. : My Summer Car
# - - 4. : Counter-Strike 2
# - - 5. : Call of Duty®
# - - 6. : Lossless Scaling
# - - 7. : Sea of Thieves
# - - 8. : Sons Of The Forest
# - - 9. : Dead by Daylight
# - - 10. : EA SPORTS FC™ 26
# - - 11. : The Forest
# - - 12. : BeamNG.drive
# - - 13. : Ready or Not
# - - 14. : Forza Horizon 6
# - - 15. : Fallout 4
# - - 16. : Raft
# - - 17. : Grounded 2
# - - 18. : God of War
# - - 19. : Watch Dogs: Legion
# - - 20. : Far Cry® 3
# - - 21. : Subnautica: Below Zero
# - - 22. : Euro Truck Simulator 2
# - - 23. : DOOM: The Dark Ages
# - - 24. : ARC Raiders
# - - 25. : Dying Light
# - - 26. : Marvel Rivals
# - - 27. : Oxygen Not Included
# - - 28. : Resident Evil 4
# - - 29. : Subnautica
# - 3번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Arma 3
# - - 1. : Counter-Strike 2
# - - 2. : Ravenfield
# - - 3. : Battlefield™ 1
# - - 4. : Left 4 Dead 2
# - - 5. : KARDS - The WWII Card Game
# - - 6. : The Witcher 3: Wild Hunt
# - - 7. : Totally Accurate Battle Simulator
# - - 8. : Operation: Harsh Doorstop
# - - 9. : War Thunder
# - - 10. : Escape From Duckov
# - - 11. : Project Zomboid
# - - 12. : Terraria
# - - 13. : Paint the Town Red
# - - 14. : tModLoader
# - - 15. : Garry's Mod
# - - 16. : Total War: THREE KINGDOMS
# - - 17. : Wallpaper Engine
# - - 18. : Don't Starve Together
# - - 19. : Easy Red 2
# - - 20. : MiSide
# - - 21. : Thief Simulator
# - - 22. : Sifu
# - - 23. : Age of Empires III: Definitive Edition
# - - 24. : Plants vs. Zombies™ Garden Warfare 2: Deluxe Edition
# - - 25. : Unturned
# - - 26. : Rise of the Tomb Raider
# - - 27. : Company of Heroes 2
# - - 28. : Portal 2
# - - 29. : Green Hell
# - 3번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Terraria
# - - 2. : Persona 5 Royal
# - - 3. : Palworld
# - - 4. : tModLoader
# - - 5. : Red Dead Redemption 2
# - - 6. : Dying Light
# - - 7. : Persona 3 Reload
# - - 8. : Escape From Duckov
# - - 9. : NARAKA: BLADEPOINT
# - - 10. : Left 4 Dead 2
# - - 11. : Dead Cells
# - - 12. : Metro Exodus Enhanced Edition
# - - 13. : Castle Crashers
# - - 14. : Devil May Cry 5
# - - 15. : DAVE THE DIVER
# - - 16. : The Forest
# - - 17. : Slime Rancher
# - - 18. : Slime Rancher 2
# - - 19. : Persona 4 Golden
# - - 20. : Mortal Kombat 11
# - - 21. : 暖雪 Warm Snow
# - - 22. : ONE PIECE: PIRATE WARRIORS 4
# - - 23. : Broforce
# - - 24. : Titanfall® 2
# - - 25. : Unturned
# - - 26. : BlazBlue Entropy Effect
# - - 27. : MiSide
# - - 28. : Tinkerlands
# - - 29. : Neon Abyss
# - 4번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Warframe
# - - 1. : Counter-Strike 2
# - - 2. : Rust
# - - 3. : Team Fortress 2
# - - 4. : Space Engineers
# - - 5. : War Thunder
# - - 6. : EVE Online
# - - 7. : HELLDIVERS™ 2
# - - 8. : DayZ
# - - 9. : Sea of Thieves
# - - 10. : Garry's Mod
# - - 11. : Fallout 76
# - - 12. : Dota 2
# - - 13. : Hearts of Iron IV
# - - 14. : Rocket League
# - - 15. : Heroes & Generals
# - - 16. : ARC Raiders
# - - 17. : PlanetSide 2
# - - 18. : Stellaris
# - - 19. : The Elder Scrolls Online
# - - 20. : Destiny 2
# - - 21. : RimWorld
# - - 22. : Star Trek Online
# - - 23. : Unturned
# - - 24. : Mount & Blade: Warband
# - - 25. : Sid Meier's Civilization V
# - - 26. : Mortal Online 2
# - - 27. : No Man's Sky
# - - 28. : WorldBox - God Simulator
# - - 29. : The Elder Scrolls V: Skyrim
# - 4번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Arma 3
# - - 1. : HELLDIVERS™ 2
# - - 2. : War of the Roses
# - - 3. : Garry's Mod
# - - 4. : Arma 2: Operation Arrowhead
# - - 5. : The Elder Scrolls V: Skyrim
# - - 6. : Squad
# - - 7. : Arma 2
# - - 8. : Elite Dangerous
# - - 9. : Starbound
# - - 10. : Total War: ATTILA
# - - 11. : Mount & Blade: Warband
# - - 12. : Men of War: Assault Squad 2
# - - 13. : Arma Reforger
# - - 14. : Kingdom Come: Deliverance II
# - - 15. : Fallout 4
# - - 16. : Starfield
# - - 17. : War of Rights
# - - 18. : Stellaris
# - - 19. : Total War: THREE KINGDOMS
# - - 20. : The Elder Scrolls V: Skyrim Special Edition
