# %% [markdown]
# # 데이터 수집
# 사용법 : 1~9은 건들지 않고 항목 **10. 데이터 수집 실행**만 사용.

# %%
import pandas as pd
import numpy as np
import requests, time, re, os, random
from bs4 import BeautifulSoup

# %% [markdown]
# # 1-1. API 주소 및 요청 설정

# %%
API_KEY = "B1FC36C7D790B5F17DCD8E33F5C33DF2"

# TEST ID
TEST_APP_ID = 1245620 # 게임 엘든링
TEST_STEAM_ID = 76561199824606664

API_URL = {
    "OWNED_GAMES" : "https://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/", 
    "RECENT_GAMES" : " https://api.steampowered.com/IPlayerService/GetRecentlyPlayedGames/v0001/",
    "APP_DETAILS" : "https://store.steampowered.com/api/appdetails",
    "STORE_PAGE" : "https://store.steampowered.com/app/",
    "REVIEWS" : "https://store.steampowered.com/appreviews/"
}

session = requests.Session()

def change_user_agent() :
    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/151.0.0.0 Safari/537.36"
        )
    })

change_user_agent()

# %% [markdown]
# # 1-2. API 요청 지연 및 재시도

# %%
def rate_limited_request(url, params=None, timeout=15, max_retries=5, base_delay=0.3): 
    for attempt in range(max_retries):
        response = session.get(url, params=params)
        if response.status_code == 429:
            wait = base_delay * (2 ** attempt) + random.uniform(0, 0.5)
            print(f"429 발생으로 {wait:.1f}초 대기 후 재시도 ({attempt+1}/{max_retries})")
            time.sleep(wait)
            continue
        response.raise_for_status()
        time.sleep(base_delay) # 기본 딜레이
        return response
    raise RuntimeError(f"최대 재시도 초과: {url}")

# %% [markdown]
# # 2. 게임 정보 데이터 수집
# - 장르
# - 카테고리
# - (게임 페이지 기준) 추천 개수, 메타크리틱 점수, 출시일, 가격

# %%
game_info_cache = {}

def get_game_info(appid):
    if appid in game_info_cache:
        cache = game_info_cache[appid]
        return cache["genre"], cache["categories"], cache["info_tup"]

    params = {"appids": appid, "l": "english"}

    try:
        response = rate_limited_request(API_URL["APP_DETAILS"], params=params) #session.get(API_URL["APP_DETAILS"], params=params, timeout=15)
        response_status = response.status_code
        if response_status != 200: 
            print("failed", response_status)
            return [],[],(0, "Unknown","Unknown","Unknown")

        data = response.json()
        
        app_data = data.get(str(appid), {})
        if not app_data.get("success"): return [],[],(0, "Unknown","Unknown","Unknown")
        game_info = app_data.get("data", {})
        """
        print(game_info.keys())
        print("recommendations", game_info.get("recommendations"))
        print("release_date", game_info.get("release_date"))
        print("price_overview", game_info.get("price_overview"))
        print("metacritic", game_info.get("metacritic"))
        """

        # 장르 정보
        genres = game_info.get("genres", [])
        genre_list = [genre.get("description") for genre in genres]

        # 카테고리 정보
        categories = game_info.get("categories", [])
        category_list = [category.get("description") for category in categories]

        # 기타 정보 종합
        recommendations = game_info.get("recommendations", {}).get("total", 0)
        release_date = game_info.get("release_date", {}).get("date", "Unknown")
        metacritic = game_info.get("metacritic", {}).get("score", "Unknown")

        # 가격 정보
        if game_info.get("is_free"): price = 0 
        else: price = game_info.get("price_overview", {}).get("final", "Unknown")
        if price != "Unknown" : price /= 100
        info_tup = (recommendations, metacritic, release_date, price)

        #print(game_info.get("price_overview"))
        
        game_info_cache[appid] = {"genre":genre_list, "categories":category_list, "info_tup":info_tup}
        return genre_list, category_list, info_tup
        

    except Exception as e:
        print(f"AppID {appid} 상세정보오류:", e)
        return [],[],(0, "Unknown","Unknown","Unknown")

print(get_game_info(TEST_APP_ID))
# Out:
# (['Action', 'RPG'], ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'Co-op', 'Online Co-op', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Camera Comfort', 'Custom Volume Controls', 'Playable without Timed Input', 'Save Anytime', 'Stereo Sound', 'Surround Sound', 'Steam Cloud', 'Family Sharing'], (827611, 94, '24 Feb, 2022', 64800.0))

# %% [markdown]
# # 3. 게임 리뷰 데이터 수집
# - 전체 리뷰 수, 긍정 리뷰 수, 긍정 리뷰 수, 리뷰 수 비율 레이팅

# %%
game_review_info_cache = {}

def get_game_review_info(appid):
    if appid in game_review_info_cache:
        cache = game_review_info_cache[appid]
        return cache
        
    URL = API_URL["REVIEWS"] + str(appid)
    params = {"json":1, "language":"all", "filter":"all", "review_type":"all","purchase_type":"all"}
    try:
        response = rate_limited_request(URL, params=params) # session.get(URL, params=params, timeout=15)
        response.raise_for_status()
        data = response.json()
        
    except Exception as e:
        print(f"AppID {appid} 리뷰 오류:", e)
        game_review_info_cache[appid] = ("Unknown", "Unknown", "Unknown", "Unknown")
        return ("Unknown", "Unknown", "Unknown", "Unknown")
        
    summary = data.get("query_summary", {})
    total_reviews = summary.get("total_reviews", "Unknown")
    positive_reviews = summary.get("total_positive", "Unknown")
    negative_reviews = summary.get("total_negative", "Unknown")
    if positive_reviews == "Unknown" or negative_reviews == "Unknown" or positive_reviews == None or negative_reviews == None : 
        rating_by_reviews = "Unknown"
    if total_reviews == 0 : rating_by_reviews = 0
    else : rating_by_reviews = round(positive_reviews / (positive_reviews + negative_reviews) * 100, 2)

    game_review_info_cache[appid] = (total_reviews, positive_reviews, negative_reviews, rating_by_reviews)
    return (total_reviews, positive_reviews, negative_reviews, rating_by_reviews)

print(get_game_review_info(TEST_APP_ID))
# Out:
# (1149209, 1069685, 79524, 93.08)

# %% [markdown]
# # 4. Steam Store 사용자 태그 데이터 수집

# %%
TAG_PATTERNS = [r'class="app_tag"[^>]*>\s*([^<]+)',  \
                r'class="app_tag[^"]*"[^>]*>\s*([^<]+)', \
                r'data-tagid="[^"]+"[^>]*>\s*([^<]+)']

game_tags_cache = {}

def get_steam_tags(appid):
    if appid in game_tags_cache:
        return game_tags_cache[appid]
    
    URL = f"{API_URL['STORE_PAGE']}{appid}/"

    try:
        response = rate_limited_request(URL) # session.get(URL, timeout=15)

        response.raise_for_status()
        html = response.text

    except Exception as e:
        print(f"AppID {appid} 태그 오류:", e)
        game_tags_cache[appid] = []
        return []

    # 방법 1 : 태그가 들어어있는 요소들 우선 탐색
    soup = BeautifulSoup(html, "html.parser")
    tags = []
    tag_elements = soup.select(".app_tag")

    for element in tag_elements:
        tag = element.get_text(strip=True)
            
        if not tag: continue
        if tag == "+": continue

        if tag not in tags: tags.append(tag)

    # 방법 2 (방법 1 실패 시) : 보조 탐색
    if not tags:
        for pattern in TAG_PATTERNS:
            matches = re.findall(pattern, html, flags=re.IGNORECASE)
            
            for match in matches:
                tag = (match.replace("&amp;", "&").strip())
                if tag and tag != "+" and tag not in tags :
                    tags.append(tag)

    # 태그 정리
    cleaned_tags = []

    for tag in tags:
        tag = tag.replace("\n", "").replace("\r", "").strip()
        if tag and tag != "+" and tag not in cleaned_tags :
            cleaned_tags.append(tag)

    game_tags_cache[appid] = cleaned_tags
    return cleaned_tags

print(get_steam_tags(TEST_APP_ID))
# Out:
# ['Souls-like', 'Open World', 'Dark Fantasy', 'RPG', 'Difficult', 'Action RPG', 'Multiplayer', 'Third Person', 'Fantasy', 'Singleplayer', 'Online Co-Op', 'Action', 'Co-op', 'Atmospheric', 'Great Soundtrack', 'PvP', 'Violent', '3D', 'Character Customization', 'Family Friendly']

# %% [markdown]
# # 5. 사용자 보유 게임 데이터 수집

# %%
def get_owned_games_of_user(steam_id, max_games=False) :
    params = {"key":API_KEY, "steamid":steam_id, "include_appinfo":True, \
              "include_played_free_games":True, "format":"json"}

    try:
        response = rate_limited_request(API_URL["OWNED_GAMES"], params=params) # session.get(API_URL["OWNED_GAMES"], params=params, timeout=15)
        
        response.raise_for_status()
        data = response.json()

        games_count = data.get("response", {}).get("game_count", [])
        games = data.get("response", {}).get("games", [])
        # print(games[0].keys())

    except Exception as e:
        print(f"steam_id {steam_id} 보유 게임 오류:", e)
        return []

    if not games :
        print(f"steam_id {steam_id} 보유 게임 없음")
        return []

    # 상위 max_games 개 게임만 수집
    if max_games and games_count > max_games:
        games = sorted(games, key=lambda g: g.get("playtime_forever", 0), reverse=True)[:max_games]
    
    res = []
    for game in games :
        appid = game.get("appid")
        game_name = game.get("name", "Unknown")
        playtime_mins = game.get("playtime_forever", 0)
        res.append((appid, game_name, playtime_mins))
    return res

print(get_owned_games_of_user(TEST_STEAM_ID))
# Out:
# [(578080, 'PUBG: BATTLEGROUNDS', 139), (977950, 'A Dance of Fire and Ice', 459), (1245620, 'ELDEN RING', 575), (2250500, 'Rhythia', 378)]

# %% [markdown]
# # 6. 사용자 최근 2주 플레이 데이터 수집

# %%
def get_recent_games_of_user(steam_id) :
    params = {"key": API_KEY, "steamid":steam_id, "foramt":"json"}

    try :
        response = rate_limited_request(API_URL["RECENT_GAMES"], params=params) # session.get(API_URL["RECENT_GAMES"], params=params, timeout=15)

        response.raise_for_status()
        data = response.json()
        games = data.get("response", {}).get("games", [])

    except Exception as e:
        print(f"steam_id {steam_id} 최근 게임 오류:", e)
        return []

    if not games:
        print(f"steam_id {steam_id} 최근 게임 없음")
        return []

    res = []
    for game in games :
        appid = game.get("appid")
        game_name = game.get("name", "Unknown")
        playtime_mins = game.get("playtime_2weeks", 0)
        res.append((appid, game_name, playtime_mins))
    return res

print(get_recent_games_of_user(TEST_STEAM_ID))
# Out:
# [(1245620, 'ELDEN RING', 153), (977950, 'A Dance of Fire and Ice', 33)]

# %% [markdown]
# # 7. Steam Store 게임 리뷰에서 사용자 ID 데이터 수집

# %%
def get_reviews(appid, cursor="*", num_per_page=100, only_positive=True):
    URL = API_URL["REVIEWS"] + str(appid)
    review_type = "positive" if only_positive else "all"
    params = {"json":1, "filter":"updated", "language":"all", "cursor":cursor, "num_per_page":num_per_page, \
        "review_type":review_type, "purchase_type":"steam"}

    try:
        response = rate_limited_request(URL, params=params) # session.get(URL, params=params, timeout=15)
        response.raise_for_status()
        data = response.json()

    except Exception as e:
        print(f"AppId {appid} 리뷰 오류:", e)
        return []

    if not data :
        print(f"AppId {appid} 리뷰 없음")

    return data

def get_user_ids_from_app(appid, id_nums, only_positive=True, minimum_playtime_mins=0, minimum_games=0, max_games=False):
    id_set = set()
    cursor = "*"
    while len(id_set) < id_nums :
        # 리뷰 데이터 100개 수집
        data = get_reviews(appid, cursor=cursor, num_per_page=100, only_positive=only_positive)
        if not data :
            print("리뷰 로딩 중 오류")
            break
        
        reviews = data.get("reviews", [])
        if not reviews : break

        for review in reviews:
            if len(id_set) >= id_nums : break
            
            user = review.get("author", {})
            if user.get("playtime_forever", 0) < minimum_playtime_mins : continue
            elif user.get("num_games_owned", 0) < minimum_games : continue
            elif max_games and user.get("num_games_owned", 0) > max_games : continue

            id = user.get("steamid")
            if id : id_set.add(id)

        cursor = data.get("cursor")
        if not cursor: break

        time.sleep(3)
    return list(id_set)

print("return example : get_user_ids_from_app()")
TEST_APP_ID = 1245620 # 게임 엘든링
test_ids_list = get_user_ids_from_app(TEST_APP_ID, 15, minimum_playtime_mins=600, minimum_games=15)
print(test_ids_list)
# Out:
# return example : get_user_ids_from_app()
# ['76561199110612232', '76561198123681703', '76561199015330455', '76561198984355584', '76561198073067799', '76561199835282867', '76561198724802455', '76561198166226287', '76561199194402331', '76561198885046549', '76561198079488752', '76561198725405351', '76561199177732895', '76561198272738490', '76561198091122227']

# %% [markdown]
# # 8. 앱ID 리스트에서 DataFrame 생성

# %%
def create_df_from_appid_list(appid_list, ids_per_game, minimum_playtime_mins=600, minimum_games=15, max_search_games=False, max_filter_games=30) :

    data = [] # DataFrame으로 만들 데이터
    
    # 게임 목록 순회
    for app_idx, appid in enumerate(appid_list) :
        user_ids = get_user_ids_from_app(appid, ids_per_game, minimum_playtime_mins=minimum_playtime_mins, \
                                          minimum_games=minimum_games, max_games=max_search_games)
        # 게임에서 찾은 유저 순회
        for id_idx, user_id in enumerate(user_ids) :
            owned_games = get_owned_games_of_user(user_id, max_games=max_filter_games)
            print(f"- {app_idx}번 게임의 {id_idx}번 유저의 보유 게임 {len(owned_games)}개 데이터 수집")

            # 유저의 최근(2주) 게임 순회
            recent_games = get_recent_games_of_user(user_id)
            recent_games_dict = {game_id : playtime for game_id, game_name, playtime in recent_games}
            
            # 유저의 보유 게임 순회
            for game_idx, game_info in enumerate(owned_games):
                game_id, game_name, game_playtime_mins = game_info
                game_playtime_hours = round(game_playtime_mins / 60, 2)

                # 게임 장르, 카테고리, 기타 정보
                genre_list, category_list, info_tup = get_game_info(game_id)
                recommendations, metacritic, release_date, price = info_tup

                # 태그 정보 수집
                tag_list = get_steam_tags(game_id)

                # 리뷰 정보 수집
                tot_rev, pos_rev, neg_rev, rating_by_rev = get_game_review_info(game_id)

                # 해당 게임 최근 플레이 이력 확인
                recent_playtime_mins = recent_games_dict.get(game_id, 0)
                recent_playtime_hours = round(recent_playtime_mins / 60, 2)
                
                print(f"- - {game_idx}. : {game_name}")
                data.append({"steamid":user_id, "appid":game_id, "game_name":game_name, "playtime_hours":game_playtime_hours, \
                             "recent_playtime_hours":recent_playtime_hours, \
                            "genre":", ".join(genre_list) if genre_list else "Unknown", \
                            "tags":", ".join(tag_list) if tag_list else "Unknown", \
                            "steam_categories":", ".join(category_list) if category_list else "Unknown", \
                             "total_reviews":tot_rev, "positive_reviews":pos_rev, "negative_reviews":neg_rev, "rating_by_reviews":rating_by_rev, \
                           "recommendations":recommendations, "metacritic":metacritic, "release_date":release_date, "price(원)":price})
            
    data_df = pd.DataFrame(data)
    data_df.head(10)
    return data_df

TEST_APPID_LIST = ["1245620", "1091500"] # 게임 2개 : 엘든링, 사이버펑크
test_df = create_df_from_appid_list(TEST_APPID_LIST, 3, max_filter_games=5)
test_df.head(5)
# Out:
# - 0번 게임의 0번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Overwatch®
# - - 1. : Apex Legends
# - - 2. : ELDEN RING
# - - 3. : TEKKEN 7
# - - 4. : Aimlabs
# - 0번 게임의 1번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Path of Exile
# - - 1. : PUBG: BATTLEGROUNDS
# - - 2. : Tom Clancy's Rainbow Six Siege
# - - 3. : Counter-Strike 2
# - - 4. : Apex Legends
# - 0번 게임의 2번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Among Us
# - - 1. : Persona 3 Reload
# - - 2. : Stardew Valley
# - - 3. : Fields of Mistria
# - - 4. : DELTARUNE
# - 1번 게임의 0번 유저의 보유 게임 5개 데이터 수집
# steam_id 76561199588348201 최근 게임 없음
# - - 0. : Portal 2
# - - 1. : Dying Light
# - - 2. : The Forest
# - - 3. : Cities: Skylines
# - - 4. : Grand Theft Auto V Legacy
# - 1번 게임의 1번 유저의 보유 게임 5개 데이터 수집
# steam_id 76561199476865533 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Half-Life 2: Deathmatch
# - - 2. : Half-Life Deathmatch: Source
# - - 3. : Left 4 Dead 2
# - - 4. : Counter-Strike 2
# - 1번 게임의 2번 유저의 보유 게임 5개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : People Playground
# - - 2. : Geometry Dash
# - - 3. : BeamNG.drive
# - - 4. : War Thunder
#              steamid    appid     game_name  playtime_hours  \
# 0  76561199015330455  2357570    Overwatch®          350.70
# 1  76561199015330455  1172470  Apex Legends          232.67
# 2  76561199015330455  1245620    ELDEN RING          224.67
# 3  76561199015330455   389730      TEKKEN 7          144.52
# 4  76561199015330455   714010       Aimlabs          136.13
#
#    recent_playtime_hours                                              genre  \
# 0                  12.08                               Action, Free To Play
# 1                   0.00                    Action, Adventure, Free To Play
# 2                   0.00                                        Action, RPG
# 3                   0.00                                     Action, Sports
# 4                   0.00  Action, Adventure, Casual, Indie, Simulation, ...
#
#                                                 tags  \
# 0                                            Unknown
# 1  Free to Play, Multiplayer, Battle Royale, FPS,...
# 2  Souls-like, Open World, Dark Fantasy, RPG, Dif...
# 3  Fighting, Action, Multiplayer, Competitive, Ar...
# 4  FPS, Free to Play, Shooter, Simulation, Action...
#
#                                     steam_categories  total_reviews  \
# 0  Multi-player, PvP, Online PvP, Co-op, Online C...         418444
# 1  Multi-player, PvP, Online PvP, Co-op, Online C...        1064622
# 2  Single-player, Multi-player, PvP, Online PvP, ...        1149209
# 3  Single-player, Multi-player, PvP, Online PvP, ...          95313
# 4  Single-player, Steam Achievements, Full contro...         136884
#
#    positive_reviews  negative_reviews  rating_by_reviews  recommendations  \
# 0            131325            287119              31.38              275
# 1            721198            343424              67.74             1578
# 2           1069685             79524              93.08           827611
# 3             79656             15657              83.57            67915
# 4            124640             12244              91.06              264
#
#   metacritic  release_date price(원)
# 0    Unknown  Aug 10, 2023      0.0
# 1         88   4 Nov, 2020      0.0
# 2         94  24 Feb, 2022  64800.0
# 3         82   1 Jun, 2017  43800.0
# 4    Unknown  16 Jun, 2023      0.0

# %% [markdown]
# # 9. DataFrame을 CSV로 저장

# %%
FILE_NAME = "steam_user_games_"

def make_csv(data_df, file_num) :
    file_name = FILE_NAME + str(file_num) + ".csv"
    data_df.to_csv(file_name, index=False, encoding="utf-8-sig")

# %% [markdown]
# # 10. 데이터 수집 실행

# %%
# 사용자 정보를 수집할 게임의 id 목록 입력
# 예시) APPID_LIST = ["1245620", "1091500"] # 게임 2개 : 엘든링, 사이버펑크
APPID_LIST = ["1174180", "242760", "739630", "1966720", "1332010", "264710", "383870", "477160", "1426210", "648800"]

# 게임 하나 당 수집할 id 개수 입력
IDS_PER_GAME = 15

# CSV 파일 번호 입력
FILE_NUM = 1

# DataFrame 생성
data_df = create_df_from_appid_list(APPID_LIST, IDS_PER_GAME, minimum_playtime_mins=600, \
                                    minimum_games=50, max_search_games=False, max_filter_games=30)
# 파라미터
# minimum_playtime_mins : 어떤 게임에서 사용자 id를 수집할 때, 그 게임의 최소 플레이 시간(분)
# minimum_games : 사용자 id를 수집할 때, 최소 보유 게임 개수
# max_search_games : 사용자 id를 수집할 때, 최대 보유 게임 개수. False로 지정시 상한 지정 안 함
# max_filter_games : 어떤 사용자의 게임 정보를 수집할 때, 보유 게임 중 플레이타임 상위 n개의 데이터만 가져옴. 이때의 n을 지정.

make_csv(data_df, FILE_NUM)
# Out:
# - 0번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Fallout 4
# - - 1. : Red Dead Redemption 2
# - - 2. : Grand Theft Auto V Enhanced
# - - 3. : Resident Evil 4
# - - 4. : Days Gone
# - - 5. : Halo Infinite
# - - 6. : Far Cry 5
# - - 7. : Halo: The Master Chief Collection
# - - 8. : Grand Theft Auto: San Andreas - The Definitive Edition
# - - 9. : God of War Ragnarök
# - - 10. : God of War
# - - 11. : Half-Life 2
# - - 12. : Resident Evil 2
# - - 13. : The Last of Us™ Part I
# - - 14. : Resident Evil Village
# - - 15. : Call of Duty®
# - - 16. : Black Mesa
# - - 17. : Resident Evil Requiem
# - - 18. : Wolfenstein: Youngblood
# - - 19. : Grand Theft Auto IV: The Complete Edition
# - - 20. : Grand Theft Auto V Legacy
# - - 21. : Wolfenstein: The New Order
# - - 22. : Mortal Kombat 1
# - - 23. : Devil May Cry 5
# - - 24. : Far Cry New Dawn
# - - 25. : METAL GEAR RISING: REVENGEANCE
# - - 26. : Half-Life
# - - 27. : Plants vs. Zombies: Game of the Year
# - - 28. : Wallpaper Engine
# - - 29. : Wolfenstein II: The New Colossus
# - 0번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Tom Clancy's Rainbow Six Siege
# - - 1. : PUBG: BATTLEGROUNDS
# - - 2. : Football Manager 26
# - - 3. : Football Manager 2022
# - - 4. : Football Manager 2024
# - - 5. : Battlefield™ 1
# - - 6. : ELDEN RING
# - - 7. : The Witcher 3: Wild Hunt
# - - 8. : Red Dead Redemption 2
# - - 9. : Total War: THREE KINGDOMS
# - - 10. : Valheim
# - - 11. : Baldur's Gate 3
# - - 12. : Kingdom Come: Deliverance II
# - - 13. : Battlefield™ V
# - - 14. : DARK SOULS™ III
# - - 15. : Cyberpunk 2077
# - - 16. : My Time at Portia
# - - 17. : HELLDIVERS™ 2
# - - 18. : Kingdom Come: Deliverance
# - - 19. : Wallpaper Engine
# - - 20. : Black Myth: Wukong
# - - 21. : Counter-Strike 2
# - - 22. : Deep Rock Galactic
# - - 23. : Monster Hunter: World
# - - 24. : Batman™: Arkham Knight
# - - 25. : Battlefield™ 6
# - - 26. : Battlefield™ 2042
# - - 27. : NARUTO SHIPPUDEN: Ultimate Ninja STORM 4
# - - 28. : Sekiro™: Shadows Die Twice
# - - 29. : The Elder Scrolls V: Skyrim Special Edition
# - 0번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Dead by Daylight
# - - 1. : Tom Clancy's Rainbow Six Siege
# - - 2. : Counter-Strike 2
# - - 3. : Rocket League
# - - 4. : Baldur's Gate 3
# - - 5. : Trove
# - - 6. : ELDEN RING
# - - 7. : Geometry Dash
# - - 8. : Marvel Rivals
# - - 9. : Destiny 2
# - - 10. : Garry's Mod
# - - 11. : Risk of Rain 2
# - - 12. : KINGDOM HEARTS -HD 1.5+2.5 ReMIX-
# - - 13. : DRAGON BALL Z: KAKAROT
# - - 14. : Satisfactory
# - - 15. : Hades II
# - - 16. : Celeste
# - - 17. : ONE PIECE: PIRATE WARRIORS 4
# - - 18. : DRAGON BALL FighterZ
# - - 19. : DRAGON BALL: Sparking! ZERO
# - - 20. : Hollow Knight
# - - 21. : Call of Duty: Black Ops III
# - - 22. : The Seven Deadly Sins: Origin
# - - 23. : Hollow Knight: Silksong
# - - 24. : DRAGON BALL GEKISHIN SQUADRA
# - - 25. : Hogwarts Legacy
# - - 26. : Dying Light
# - - 27. : Red Dead Redemption 2
# - - 28. : Hades
# - - 29. : ONE PIECE ODYSSEY
# - 0번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : EA SPORTS FC™ 26
# - - 1. : Terraria
# - - 2. : Batman™: Arkham Origins
# - - 3. : Left 4 Dead 2
# - - 4. : Garry's Mod
# - - 5. : tModLoader
# - - 6. : Red Dead Redemption 2
# - - 7. : Doki Doki Literature Club
# - - 8. : Resident Evil 4 (2005)
# - - 9. : Wallpaper Engine
# - - 10. : LEGO® MARVEL Super Heroes
# - - 11. : Resident Evil
# - - 12. : LEGO® MARVEL's Avengers
# - - 13. : Pacify
# - - 14. : Half-Life
# - - 15. : Granny
# - - 16. : Brawlhalla
# - - 17. : Counter-Strike 2
# - - 18. : NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution
# - - 19. : VRChat
# - - 20. : Ultimate Custom Night
# - - 21. : Mortal Kombat X
# - - 22. : Stumble Guys
# - - 23. : POSTAL 2
# - - 24. : DRAGON BALL XENOVERSE
# - - 25. : Slender: The Arrival
# - - 26. : Batman™: Arkham Knight
# - - 27. : TBH: Task Bar Hero
# - - 28. : Resident Evil 0
# - - 29. : Call of Juarez Gunslinger
# - 0번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : ELDEN RING
# - - 1. : Grand Theft Auto V Legacy
# - - 2. : The Binding of Isaac: Rebirth
# - - 3. : Terraria
# - - 4. : Call of Duty®
# - - 5. : Counter-Strike 2
# - - 6. : DARK SOULS™ III
# - - 7. : Hollow Knight
# - - 8. : PUBG: BATTLEGROUNDS
# - - 9. : Tom Clancy's Rainbow Six Siege
# - - 10. : TEKKEN 8
# - - 11. : Hollow Knight: Silksong
# - - 12. : Mortal Kombat 11
# - - 13. : Red Dead Redemption 2
# - - 14. : DARK SOULS™: REMASTERED
# - - 15. : Grand Theft Auto V Enhanced
# - - 16. : PAYDAY 2
# - - 17. : Detroit: Become Human
# - - 18. : Lethal Company
# - - 19. : STAR WARS Jedi: Fallen Order™
# - - 20. : Resident Evil 2
# - - 21. : DELTARUNE (Chapter 1 & 2 DEMO)
# - - 22. : STAR WARS Jedi: Survivor™
# - - 23. : Battlefield™ V
# - - 24. : Assassin's Creed II
# - - 25. : Deep Rock Galactic
# - - 26. : Undertale
# - - 27. : Team Fortress 2
# - - 28. : Brawlhalla
# - - 29. : PAYDAY 3
# - 0번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : War Thunder
# - - 1. : Dota 2
# - - 2. : STALZONE
# - - 3. : Tom Clancy's Rainbow Six Siege
# - - 4. : Hearts of Iron IV
# - - 5. : Counter-Strike 2
# - - 6. : Dead by Daylight
# - - 7. : Red Dead Redemption 2
# - - 8. : Broken Arrow
# - - 9. : Team Fortress 2
# - - 10. : Fallout 76
# - - 11. : Stay Out
# - - 12. : Garry's Mod
# - - 13. : Warframe
# - - 14. : Battlefield™ 1
# - - 15. : HELLDIVERS™ 2
# - - 16. : Devil May Cry 5
# - - 17. : Terraria
# - - 18. : Battlefield 4™
# - - 19. : Project Zomboid
# - - 20. : PAYDAY 2
# - - 21. : Cyberpunk 2077
# - - 22. : Apex Legends
# - - 23. : Danganronpa V3: Killing Harmony
# - - 24. : Atomic Heart
# - - 25. : Persona 5 Royal
# - - 26. : Battlefield™ 6
# - - 27. : Battlefield™ 2042
# - - 28. : PUBG: BATTLEGROUNDS
# - - 29. : Call of Duty®: Black Ops Cold War
# - 0번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : ELDEN RING
# - - 1. : The First Berserker: Khazan
# - - 2. : Lies of P
# - - 3. : DARK SOULS™ II
# - - 4. : Kingdom Come: Deliverance II
# - - 5. : Red Dead Redemption 2
# - - 6. : OCTOPATH TRAVELER 0
# - - 7. : Metaphor: ReFantazio
# - - 8. : Baldur's Gate 3
# - - 9. : Warhammer 40,000: Rogue Trader
# - - 10. : Path of Exile 2
# - - 11. : Hades II
# - - 12. : Like a Dragon: Infinite Wealth
# - - 13. : Hollow Knight: Silksong
# - - 14. : Divinity: Original Sin 2
# - - 15. : SILENT HILL 2
# - - 16. : Crimson Desert
# - - 17. : FINAL FANTASY VII REMAKE INTERGRADE
# - - 18. : Like a Dragon: Ishin!
# - - 19. : Wallpaper Engine
# - - 20. : Black Myth: Wukong
# - - 21. : The Walking Dead
# - - 22. : Dragon's Dogma 2
# - - 23. : Death Must Die
# - - 24. : Nioh 3
# - - 25. : Resident Evil 4
# - - 26. : WUCHANG: Fallen Feathers
# - - 27. : Persona 5 Strikers
# - - 28. : The Walking Dead: Season Two
# - - 29. : Diablo® IV
# - 0번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Tom Clancy's Rainbow Six Siege
# - - 1. : Overwatch®
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : Wallpaper Engine
# - - 4. : Stardew Valley
# - - 5. : Call of Duty®
# - - 6. : Stellar Blade™
# - - 7. : Paladins
# - - 8. : Undertale
# - - 9. : Crush Crush
# - - 10. : SILENT HILL 2
# - - 11. : Red Dead Redemption 2
# - - 12. : Mewgenics
# - - 13. : Resident Evil 4
# - - 14. : NieR Replicant ver.1.22474487139...
# - - 15. : NieR:Automata™
# - - 16. : SILENT HILL f
# - - 17. : Until Then
# - - 18. : Battlefield™ 6
# - - 19. : The Elder Scrolls IV: Oblivion Remastered
# - - 20. : Summer Clover
# - - 21. : Hogwarts Legacy
# - - 22. : The Outlast Trials
# - - 23. : Made in Abyss: Binary Star Falling into Darkness
# - - 24. : Resident Evil Requiem
# - - 25. : Inscryption
# - - 26. : Left 4 Dead 2
# - - 27. : Fear & Hunger 2: Termina
# - - 28. : Resident Evil 2
# - - 29. : Catherine Classic
# - 0번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Crosshair X
# - - 1. : Battlefield™ 1
# - - 2. : Hunt: Showdown 1896
# - - 3. : Red Dead Redemption 2
# - - 4. : The Binding of Isaac: Rebirth
# - - 5. : Rust
# - - 6. : Deep Rock Galactic
# - - 7. : Oxygen Not Included
# - - 8. : Monster Hunter: World
# - - 9. : Baldur's Gate 3
# - - 10. : Sekiro™: Shadows Die Twice
# - - 11. : Mount & Blade II: Bannerlord
# - - 12. : Dyson Sphere Program
# - - 13. : Stardew Valley
# - - 14. : Project Zomboid
# - - 15. : Grim Dawn
# - - 16. : Cyberpunk 2077
# - - 17. : Plants vs. Zombies: Game of the Year
# - - 18. : Cuphead
# - - 19. : Factorio
# - - 20. : The Witcher 3: Wild Hunt
# - - 21. : RimWorld
# - - 22. : Nioh 2 – The Complete Edition
# - - 23. : ARK: Survival Evolved
# - - 24. : Warframe
# - - 25. : Terraria
# - - 26. : Hollow Knight
# - - 27. : Hollow Knight: Silksong
# - - 28. : Slay the Spire
# - - 29. : Brotato
# - 0번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199178978453 최근 게임 없음
# - - 0. : Portal 2
# - - 1. : Bully: Scholarship Edition
# - - 2. : Grand Theft Auto IV: The Complete Edition
# - - 3. : Terraria
# - - 4. : The Witness
# - - 5. : The Forest
# - - 6. : Watch_Dogs
# - - 7. : Subnautica
# - - 8. : Grand Theft Auto V Legacy
# - - 9. : The Witcher 3: Wild Hunt
# - - 10. : SpaceEngine
# - - 11. : Hollow Knight
# - - 12. : DARK SOULS™ III
# - - 13. : Fallout 4
# - - 14. : Firewatch
# - - 15. : Undertale
# - - 16. : Dishonored 2
# - - 17. : Metro Exodus
# - - 18. : STEINS;GATE
# - - 19. : Danganronpa: Trigger Happy Havoc
# - - 20. : Danganronpa 2: Goodbye Despair
# - - 21. : Outlast 2
# - - 22. : Resident Evil 7 Biohazard
# - - 23. : Wallpaper Engine
# - - 24. : Rusty Lake Hotel
# - - 25. : Watch_Dogs 2
# - - 26. : White Day: A Labyrinth Named School
# - - 27. : The Elder Scrolls V: Skyrim Special Edition
# - - 28. : What Remains of Edith Finch
# - - 29. : NieR:Automata™
# - 0번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Grand Theft Auto V Legacy
# - - 1. : Project Zomboid
# - - 2. : Red Dead Redemption 2
# - - 3. : Overwatch®
# - - 4. : Assassin's Creed II
# - - 5. : Assassin's Creed Syndicate
# - - 6. : Resident Evil 6
# - - 7. : Assassin's Creed Brotherhood
# - - 8. : Batman™: Arkham Knight
# - - 9. : Assassin's Creed Unity
# - - 10. : Resident Evil 5
# - - 11. : Beyond: Two Souls
# - - 12. : Heavy Rain
# - - 13. : Grand Theft Auto IV: The Complete Edition
# - - 14. : Grand Theft Auto V Enhanced
# - - 15. : Middle-earth™: Shadow of Mordor™
# - - 16. : THE FINALS
# - - 17. : MECCHA CHAMELEON
# - - 18. : Human Fall Flat
# - - 19. : VRChat
# - - 20. : PUBG: BATTLEGROUNDS
# - - 21. : A Way Out
# - - 22. : Watch_Dogs
# - - 23. : PEAK
# - - 24. : Dead by Daylight
# - - 25. : Battlefield™ 1
# - - 26. : Control Ultimate Edition
# - - 27. : Assassin's Creed Origins
# - - 28. : Left 4 Dead 2
# - - 29. : Ultimate Zombie Defense
# - 0번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Bongo Cat
# - - 1. : Escape from Tarkov
# - - 2. : Unturned
# - - 3. : Counter-Strike 2
# - - 4. : The Binding of Isaac: Rebirth
# - - 5. : Red Dead Redemption 2
# - - 6. : Apex Legends
# - - 7. : DayZ
# - - 8. : The Walking Dead: The Telltale Definitive Series
# - - 9. : Tom Clancy's Ghost Recon® Wildlands
# - - 10. : Escape From Duckov
# - - 11. : HITMAN World of Assassination
# - - 12. : Tomb Raider
# - - 13. : Slay the Spire 2
# - - 14. : Resident Evil Village
# - - 15. : Sons Of The Forest
# - - 16. : Left 4 Dead 2
# - - 17. : HELLDIVERS™ 2
# - - 18. : Shadow of the Tomb Raider
# - - 19. : Rise of the Tomb Raider
# - - 20. : Library Of Ruina
# - - 21. : Far Cry® 3
# - - 22. : Casualties: Unknown Demo
# - - 23. : Terraria
# - - 24. : tModLoader
# - - 25. : Dying Light 2: Reloaded Edition
# - - 26. : DARK SOULS™: REMASTERED
# - - 27. : Ready or Not
# - - 28. : PUBG: BATTLEGROUNDS
# - - 29. : Metro 2033
# - 0번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Summoners War
# - - 1. : Grand Theft Auto V Enhanced
# - - 2. : Project Zomboid
# - - 3. : Grand Theft Auto V Legacy
# - - 4. : Call of Duty®
# - - 5. : Left 4 Dead 2
# - - 6. : The Sims™ 4
# - - 7. : Red Dead Redemption 2
# - - 8. : Stumble Guys
# - - 9. : TBH: Task Bar Hero
# - - 10. : Just Cause 3
# - - 11. : Team Fortress 2
# - - 12. : World of Tanks Blitz
# - - 13. : Detroit: Become Human
# - - 14. : Teardown
# - - 15. : DARKEST DAYS
# - - 16. : Once Human
# - - 17. : The Forest
# - - 18. : Paint the Town Red
# - - 19. : HITMAN World of Assassination
# - - 20. : Muck
# - - 21. : Among Us
# - - 22. : Bodycam
# - - 23. : skate.
# - - 24. : Dying Light
# - - 25. : Garry's Mod
# - - 26. : NightClub Simulator
# - - 27. : Counter-Strike: Source
# - - 28. : BeamNG.drive
# - - 29. : Fallout Shelter
# - 0번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Black Desert (Retired)
# - - 1. : Black Desert
# - - 2. : Counter-Strike 2
# - - 3. : Call of Duty®
# - - 4. : Diablo® IV
# - - 5. : Riders of Icarus
# - - 6. : Grand Theft Auto V Legacy
# - - 7. : Red Dead Redemption 2
# - - 8. : The Witcher 3: Wild Hunt
# - - 9. : Counter-Strike
# - - 10. : American Truck Simulator
# - - 11. : Battlefield™ V
# - - 12. : Farming Simulator 22
# - - 13. : PUBG: BATTLEGROUNDS
# - - 14. : Grand Theft Auto: Vice City
# - - 15. : The Elder Scrolls Online
# - - 16. : Forza Horizon 4
# - - 17. : Call of Duty: Modern Warfare 2 (2009)
# - - 18. : Tomb Raider
# - - 19. : Need for Speed: SHIFT
# - - 20. : Left 4 Dead 2
# - - 21. : Splitgate
# - - 22. : Delta Force
# - - 23. : Sniper Ghost Warrior 2
# - - 24. : Call of Duty®: Modern Warfare® 3 (2011)
# - - 25. : Call of Duty: World at War
# - - 26. : The Forest
# - - 27. : Path of Exile
# - - 28. : Half-Life
# - - 29. : Half-Life 2
# - 0번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199062295989 최근 게임 없음
# - - 0. : Counter-Strike 2
# - - 1. : Garry's Mod
# - - 2. : Eets
# - - 3. : Resident Evil 5
# - - 4. : Borderlands 2
# - - 5. : Deponia
# - - 6. : Hotline Miami
# - - 7. : Far Cry® 3
# - - 8. : Resident Evil 6
# - - 9. : Getting Over It with Bennett Foddy
# - - 10. : Rust
# - - 11. : Resident Evil 4 (2005)
# - - 12. : Grand Theft Auto V Legacy
# - - 13. : Gang Beasts
# - - 14. : Resident Evil
# - - 15. : Geometry Dash
# - - 16. : Resident Evil 0
# - - 17. : Tom Clancy's Rainbow Six Siege
# - - 18. : The Isle
# - - 19. : Dead by Daylight
# - - 20. : Resident Evil 7 Biohazard
# - - 21. : Who's Your Daddy?!
# - - 22. : Golf With Your Friends
# - - 23. : Wallpaper Engine
# - - 24. : Watch_Dogs 2
# - - 25. : Warhammer 40,000: Gladius - Relics of War
# - - 26. : Along the Edge
# - - 27. : BIGFOOT
# - - 28. : My Summer Car
# - - 29. : theHunter: Call of the Wild™
# - 1번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Bongo Cat
# - - 1. : Counter-Strike 2
# - - 2. : STALZONE
# - - 3. : People Playground
# - - 4. : Terraria
# - - 5. : The Forest
# - - 6. : Don't Starve Together
# - - 7. : GIBZ
# - - 8. : Forager
# - - 9. : DELTARUNE
# - - 10. : Detroit: Become Human
# - - 11. : Portal Knights
# - - 12. : Garry's Mod
# - - 13. : SKYHILL
# - - 14. : tModLoader
# - - 15. : The Binding of Isaac: Rebirth
# - - 16. : 911 Operator
# - - 17. : Raft
# - - 18. : The Walking Dead: The Telltale Definitive Series
# - - 19. : Paint the Town Red
# - - 20. : Blood and Bacon
# - - 21. : Cult of the Lamb
# - - 22. : Gang Beasts
# - - 23. : Guns, Gore and Cannoli 2
# - - 24. : SOS OPS!
# - - 25. : Awaria
# - - 26. : R.E.P.O.
# - - 27. : Portal 2
# - - 28. : Counter-Strike:Global Offensive
# - - 29. : Totally Accurate Battle Simulator
# - 1번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Paladins
# - - 2. : The Witcher 3: Wild Hunt
# - - 3. : PUBG: BATTLEGROUNDS
# - - 4. : Path of Exile
# - - 5. : Neverwinter
# - - 6. : Tomb Raider
# - - 7. : The Forest
# - - 8. : BlackShot: Mercenary Warfare FPS
# - - 9. : Resident Evil 2
# - - 10. : CreativeDestruction
# - - 11. : Warframe
# - - 12. : Left 4 Dead 2
# - - 13. : Resident Evil 7 Biohazard
# - - 14. : SMITE
# - - 15. : Resident Evil Revelations
# - - 16. : Resident Evil 4 (2005)
# - - 17. : Wallpaper Engine
# - - 18. : Beyond: Two Souls
# - - 19. : Detroit: Become Human
# - - 20. : Hogwarts Legacy
# - - 21. : Marvel Rivals
# - - 22. : DayZ
# - - 23. : Tomb Raider: Anniversary
# - - 24. : Mortal Kombat X
# - - 25. : Project Zomboid
# - - 26. : Resident Evil 0
# - - 27. : The Sims™ 4
# - - 28. : Left 4 Dead
# - - 29. : NINJA GAIDEN Σ2 [NINJA GAIDEN: Master Collection]
# - 1번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Grand Theft Auto V Legacy
# - - 1. : Garry's Mod
# - - 2. : War Thunder
# - - 3. : R.E.P.O.
# - - 4. : Fishing Planet
# - - 5. : Counter-Strike 2
# - - 6. : PEAK
# - - 7. : Sons Of The Forest
# - - 8. : Transport Fever 2
# - - 9. : Geometry Dash
# - - 10. : Teardown
# - - 11. : PAYDAY 2
# - - 12. : Metro Exodus
# - - 13. : Descenders
# - - 14. : BeamNG.drive
# - - 15. : Half-Life 2
# - - 16. : Soundpad Demo
# - - 17. : Cities: Skylines
# - - 18. : Hotline Miami 2: Wrong Number
# - - 19. : The Forest
# - - 20. : POSTAL 2
# - - 21. : Buckshot Roulette
# - - 22. : YAPYAP
# - - 23. : Bongo Cat
# - - 24. : HITMAN World of Assassination
# - - 25. : Among Us
# - - 26. : Phasmophobia
# - - 27. : Jurassic World Evolution 2
# - - 28. : Ultimate Custom Night
# - - 29. : DOOM
# - 1번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Arena Breakout: Infinite
# - - 2. : Battlefield™ 2042
# - - 3. : Dead Frontier 2
# - - 4. : Fallout 4
# - - 5. : GeoGuessr Steam Edition
# - - 6. : Dead by Daylight
# - - 7. : Assassin's Creed Odyssey
# - - 8. : S.T.A.L.K.E.R. 2: Heart of Chornobyl
# - - 9. : Dying Light 2: Reloaded Edition
# - - 10. : Black Myth: Wukong
# - - 11. : STAR WARS™ Battlefront™ II
# - - 12. : Icarus
# - - 13. : Tom Clancy's The Division 2
# - - 14. : Cyberpunk 2077
# - - 15. : Atomic Heart
# - - 16. : Prey
# - - 17. : Detroit: Become Human
# - - 18. : Sons Of The Forest
# - - 19. : Resident Evil Requiem
# - - 20. : Dead Space
# - - 21. : Resident Evil 4
# - - 22. : Beyond: Two Souls
# - - 23. : Batman™: Arkham Knight
# - - 24. : SILENT HILL 2
# - - 25. : The Long Dark
# - - 26. : Rise of the Tomb Raider
# - - 27. : RoboCop: Rogue City
# - - 28. : METAL GEAR SOLID V: THE PHANTOM PAIN
# - - 29. : Battlefield™ V
# - 1번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Cyberpunk 2077
# - - 2. : Team Fortress 2
# - - 3. : Garry's Mod
# - - 4. : VRChat
# - - 5. : Dying Light 2: Reloaded Edition
# - - 6. : Unturned
# - - 7. : Sons Of The Forest
# - - 8. : THE FINALS
# - - 9. : Project Zomboid
# - - 10. : The Outlast Trials
# - - 11. : Left 4 Dead 2
# - - 12. : Subnautica
# - - 13. : BONELAB
# - - 14. : Terraria
# - - 15. : The Binding of Isaac: Rebirth
# - - 16. : PUBG: BATTLEGROUNDS
# - - 17. : Blade & Sorcery
# - - 18. : Grand Theft Auto V Enhanced
# - - 19. : Red Dead Redemption 2
# - - 20. : Marvel Rivals
# - - 21. : The Forest
# - - 22. : Cry of Fear
# - - 23. : Brawlhalla
# - - 24. : Far Cry® 3
# - - 25. : Rec Room
# - - 26. : The Planet Crafter: Prologue
# - - 27. : Half-Life 2
# - - 28. : Half-Life
# - - 29. : The Quarry
# - 1번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Garry's Mod
# - - 2. : Team Fortress 2
# - - 3. : Rust
# - - 4. : War Thunder
# - - 5. : Russian Fishing 4
# - - 6. : Geometry Dash
# - - 7. : People Playground
# - - 8. : Soundpad
# - - 9. : The Forest
# - - 10. : R.E.P.O.
# - - 11. : World of Tanks Blitz
# - - 12. : Euro Truck Simulator 2
# - - 13. : Terraria
# - - 14. : World of Tanks
# - - 15. : Squad
# - - 16. : Apex Legends
# - - 17. : Phasmophobia
# - - 18. : Dead by Daylight
# - - 19. : Crosshair X
# - - 20. : Five Nights at Freddy's: Security Breach
# - - 21. : Will To Live Online
# - - 22. : PAYDAY 2
# - - 23. : Cube Racer
# - - 24. : Lethal Company
# - - 25. : World War 3
# - - 26. : tModLoader
# - - 27. : BattleBit Remastered
# - - 28. : Men of War: Assault Squad
# - - 29. : Hotline Miami
# - 1번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199403272332 최근 게임 없음
# - - 0. : Garry's Mod
# - - 1. : Hitman: Blood Money
# - - 2. : Call of Juarez: Bound in Blood
# - - 3. : Syberia 2
# - - 4. : Project Zomboid
# - - 5. : POSTAL 2
# - - 6. : Remember Me
# - - 7. : Mad Max
# - - 8. : Getting Over It with Bennett Foddy
# - - 9. : The Forest
# - - 10. : Assetto Corsa
# - - 11. : Cook, Serve, Delicious!
# - - 12. : The Binding of Isaac: Rebirth
# - - 13. : Chroma Squad
# - - 14. : Rust
# - - 15. : Grand Theft Auto V Legacy
# - - 16. : BeamNG.drive
# - - 17. : RollerCoaster Tycoon: Deluxe
# - - 18. : FOR HONOR
# - - 19. : Geometry Dash
# - - 20. : The Hive
# - - 21. : Letter Quest: Grimm's Journey
# - - 22. : LEGO® Worlds
# - - 23. : Amazing Frog?
# - - 24. : Medieval Engineers
# - - 25. : Arizona Sunshine® VR Legacy
# - - 26. : Poppy Kart
# - - 27. : Tom Clancy's Rainbow Six Siege
# - - 28. : Dead Age
# - - 29. : Letter Quest: Grimm's Journey Remastered
# - 1번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199469292362 최근 게임 없음
# - - 0. : Half-Life
# - - 1. : Half-Life 2
# - - 2. : Half-Life 2: Deathmatch
# - - 3. : Half-Life Deathmatch: Source
# - - 4. : Portal
# - - 5. : Team Fortress 2
# - - 6. : Left 4 Dead 2
# - - 7. : Counter-Strike 2
# - - 8. : Garry's Mod
# - - 9. : Fallout: New Vegas
# - - 10. : Dark Sector
# - - 11. : Metro: Last Light Complete Edition
# - - 12. : Borderlands 2
# - - 13. : Project Zomboid
# - - 14. : Castle Crashers
# - - 15. : South Park™: The Stick of Truth™
# - - 16. : PAYDAY 2
# - - 17. : DayZ
# - - 18. : POSTAL 2
# - - 19. : POSTAL
# - - 20. : Dying Light
# - - 21. : The Forest
# - - 22. : Plague Inc: Evolved
# - - 23. : Grand Theft Auto V Legacy
# - - 24. : Hotline Miami 2: Wrong Number
# - - 25. : 100% Orange Juice
# - - 26. : Metro 2033 Redux
# - - 27. : Geometry Dash
# - - 28. : ARK: Survival Evolved
# - - 29. : Dead by Daylight
# - 1번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Warframe
# - - 1. : Dead by Daylight
# - - 2. : Terraria
# - - 3. : Deep Rock Galactic
# - - 4. : Killing Floor 2
# - - 5. : HELLDIVERS™ 2
# - - 6. : Killing Floor
# - - 7. : Team Fortress 2
# - - 8. : Phasmophobia
# - - 9. : Risk of Rain 2
# - - 10. : Bongo Cat
# - - 11. : DARK SOULS™: REMASTERED
# - - 12. : SAS: Zombie Assault 4
# - - 13. : Warhammer 40,000: Space Marine 2
# - - 14. : Dying Light
# - - 15. : Stardew Valley
# - - 16. : Left 4 Dead 2
# - - 17. : Killing Floor 3
# - - 18. : Clone Drone in the Danger Zone
# - - 19. : No More Room in Hell
# - - 20. : Grand Theft Auto V Legacy
# - - 21. : Warhammer: Vermintide 2
# - - 22. : Hogwarts Legacy
# - - 23. : Middle-earth™: Shadow of War™
# - - 24. : Styx: Master of Shadows
# - - 25. : Metro: Last Light Complete Edition
# - - 26. : Remnant: From the Ashes
# - - 27. : Counter-Strike 2
# - - 28. : Cuphead
# - - 29. : The Outlast Trials
# - 1번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Terraria
# - - 2. : tModLoader
# - - 3. : Geometry Dash
# - - 4. : Age of History II
# - - 5. : Sons Of The Forest
# - - 6. : The Forest
# - - 7. : Garry's Mod
# - - 8. : Hollow Knight
# - - 9. : Stumble Guys
# - - 10. : Hollow Knight: Silksong
# - - 11. : Five Nights at Freddy's: Security Breach
# - - 12. : Escape the Backrooms
# - - 13. : The Binding of Isaac: Rebirth
# - - 14. : Red Dead Redemption 2
# - - 15. : LEGO® Star Wars™: The Skywalker Saga
# - - 16. : Granny: Chapter Two
# - - 17. : Granny
# - - 18. : DOOM Eternal
# - - 19. : SpaceEngine
# - - 20. : LEGO® STAR WARS™: The Force Awakens
# - - 21. : Detroit: Become Human
# - - 22. : Counter-Strike:Global Offensive
# - - 23. : One-armed robber
# - - 24. : LEGO® The Hobbit™
# - - 25. : Granny 3
# - - 26. : Half-Life 2
# - - 27. : LEGO® MARVEL's Avengers
# - - 28. : The Henry Stickmin Collection
# - - 29. : Five Nights at Freddy's 3
# - 1번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Satisfactory
# - - 2. : Hearts of Iron IV
# - - 3. : Sons Of The Forest
# - - 4. : The Forest
# - - 5. : The Planet Crafter
# - - 6. : Cities: Skylines
# - - 7. : Assassin's Creed IV Black Flag
# - - 8. : Middle-earth™: Shadow of Mordor™
# - - 9. : Middle-earth™: Shadow of War™
# - - 10. : Conan Exiles Enhanced
# - - 11. : Farming Simulator 25
# - - 12. : Assassin's Creed Odyssey
# - - 13. : Icarus
# - - 14. : Medieval Dynasty
# - - 15. : Far Cry Primal
# - - 16. : It Takes Two
# - - 17. : Tom Clancy's Ghost Recon® Wildlands
# - - 18. : Spellbreak
# - - 19. : Farming Simulator 22
# - - 20. : Steep
# - - 21. : Cities: Skylines II
# - - 22. : Assassin's Creed II
# - - 23. : Grounded
# - - 24. : Assassin's Creed Unity
# - - 25. : Sid Meier's Civilization V
# - - 26. : Fallout 4
# - - 27. : Frostpunk
# - - 28. : Deep Rock Galactic: Survivor
# - - 29. : Stronghold: Definitive Edition
# - 1번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# - - 0. : STALZONE
# - - 1. : Terraria
# - - 2. : HudSight - crosshair overlay
# - - 3. : tModLoader
# - - 4. : Counter-Strike 2
# - - 5. : Hollow Knight: Silksong
# - - 6. : Euro Truck Simulator 2
# - - 7. : Don't Starve Together
# - - 8. : Scrap Mechanic
# - - 9. : Far Cry 5
# - - 10. : Soundpad Demo
# - - 11. : The Forest
# - - 12. : Sons Of The Forest
# - - 13. : Metro Exodus
# - - 14. : Half-Life 2
# - - 15. : Stardew Valley
# - - 16. : Detroit: Become Human
# - - 17. : DEATH STRANDING DIRECTOR'S CUT
# - - 18. : Metro 2033 Redux
# - - 19. : Slime Rancher
# - - 20. : Metro: Last Light Redux
# - - 21. : Frostpunk
# - - 22. : Grounded 2
# - - 23. : ASTRONEER
# - - 24. : Subnautica: Below Zero
# - - 25. : Amnesia: The Bunker
# - - 26. : Alan Wake
# - - 27. : Alone in the Dark
# - - 28. : Portal 2
# - - 29. : Far Cry® 3
# - 1번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : RimWorld
# - - 1. : Oxygen Not Included
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : The Forest
# - - 4. : Counter-Strike 2
# - - 5. : Project Zomboid
# - - 6. : Insurgency: Sandstorm
# - - 7. : Subnautica
# - - 8. : Aliens: Fireteam Elite
# - - 9. : Green Hell
# - - 10. : Subnautica: Below Zero
# - - 11. : Paint the Town Red
# - - 12. : The Long Dark
# - - 13. : Dying Light
# - - 14. : Ben and Ed
# - - 15. : World War Z
# - - 16. : Left 4 Dead 2
# - - 17. : Muck
# - - 18. : Mount & Blade II: Bannerlord
# - - 19. : Raft
# - - 20. : Don't Starve
# - - 21. : Stranded Deep
# - - 22. : PUBG: BATTLEGROUNDS
# - - 23. : Aliens vs. Predator
# - - 24. : Dead Space (2008)
# - - 25. : Internet Cafe Simulator 2
# - - 26. : DEVOUR
# - - 27. : Half-Life 2
# - - 28. : The Coffin of Andy and Leyley
# - - 29. : Breathedge
# - 1번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199480220778 최근 게임 없음
# - - 0. : Portal
# - - 1. : Left 4 Dead
# - - 2. : Left 4 Dead 2
# - - 3. : Portal 2
# - - 4. : Lara Croft and the Guardian of Light
# - - 5. : Metro: Last Light Complete Edition
# - - 6. : LIMBO
# - - 7. : Borderlands 2
# - - 8. : PAYDAY 2
# - - 9. : RPG Maker VX Ace
# - - 10. : Euro Truck Simulator 2
# - - 11. : Killing Floor 2
# - - 12. : Outlast
# - - 13. : The Forest
# - - 14. : No Man's Sky
# - - 15. : Lara Croft and the Temple of Osiris
# - - 16. : Sniper Elite 4
# - - 17. : Strange Brigade
# - - 18. : Don't Starve Together
# - - 19. : Tom Clancy's Rainbow Six Siege
# - - 20. : Poly Bridge
# - - 21. : The Isle
# - - 22. : Dead by Daylight
# - - 23. : Stardew Valley
# - - 24. : Stay Close
# - - 25. : Steep
# - - 26. : Warhammer 40,000: Gladius - Relics of War
# - - 27. : Deep Rock Galactic
# - - 28. : Black Desert
# - - 29. : Moonlighter
# - 1번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Rust
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : Soundpad
# - - 4. : Euro Truck Simulator 2
# - - 5. : Counter-Strike:Global Offensive
# - - 6. : Raft
# - - 7. : The Forest
# - - 8. : Drive Beyond Horizons
# - - 9. : Terraria
# - - 10. : tModLoader
# - - 11. : R.E.P.O.
# - - 12. : Wallpaper Engine
# - - 13. : Portal 2
# - - 14. : BeamNG.drive
# - - 15. : Phasmophobia
# - - 16. : One-armed robber
# - - 17. : Car Service Together
# - - 18. : Stardew Valley
# - - 19. : Styx: Shards of Darkness
# - - 20. : Escape the Backrooms
# - - 21. : Among Us
# - - 22. : My Summer Car
# - - 23. : Little Nightmares II
# - - 24. : Zort
# - - 25. : Grapples Galore
# - - 26. : Human Fall Flat
# - - 27. : Banana Shooter
# - - 28. : One-armed cook
# - - 29. : PANICORE
# - 2번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : The Elder Scrolls V: Skyrim Special Edition
# - - 1. : Sons Of The Forest
# - - 2. : Schedule I
# - - 3. : Geometry Dash
# - - 4. : Counter-Strike 2
# - - 5. : The Elder Scrolls IV: Oblivion Game of the Year Edition (2009)
# - - 6. : Phasmophobia
# - - 7. : One-armed robber
# - - 8. : Dead by Daylight
# - - 9. : Subnautica
# - - 10. : SCP: Secret Laboratory
# - - 11. : Delta Force
# - - 12. : Crosshair V2
# - - 13. : Supermarket Together
# - - 14. : Apex Legends
# - - 15. : Path of Exile
# - - 16. : Guild Wars 2®
# - - 17. : R.E.P.O.
# - - 18. : DayZ
# - - 19. : Green Hell
# - - 20. : Escape the Backrooms
# - - 21. : Wallpaper Engine
# - - 22. : MIMESIS
# - - 23. : Gamble With Your Friends
# - - 24. : Sneak Out
# - - 25. : Aimlabs
# - - 26. : Marvel Rivals
# - - 27. : Dark and Darker
# - - 28. : Chained Together
# - - 29. : Tom Clancy's Rainbow Six Siege
# - 2번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Terraria
# - - 2. : Persona 5 Royal
# - - 3. : Phasmophobia
# - - 4. : Fall Guys
# - - 5. : Grand Theft Auto V Legacy
# - - 6. : Among Us
# - - 7. : PEAK
# - - 8. : Deadlock
# - - 9. : VRChat
# - - 10. : tModLoader
# - - 11. : PAYDAY 2
# - - 12. : Half-Life
# - - 13. : Cuphead
# - - 14. : Undertale
# - - 15. : Garry's Mod
# - - 16. : LEGO® Batman™: The Videogame
# - - 17. : Megabonk
# - - 18. : Wallpaper Engine
# - - 19. : Killing Floor 2
# - - 20. : Overwatch®
# - - 21. : Don't Starve Together
# - - 22. : Ultimate Custom Night
# - - 23. : Half-Life 2
# - - 24. : Sven Co-op
# - - 25. : Left 4 Dead 2
# - - 26. : Apex Legends
# - - 27. : Unturned
# - - 28. : Enter the Gungeon
# - - 29. : Umamusume: Pretty Derby
# - 2번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Don't Starve Together
# - - 1. : Terraria
# - - 2. : The Binding of Isaac: Rebirth
# - - 3. : Dead by Daylight
# - - 4. : tModLoader
# - - 5. : Stardew Valley
# - - 6. : Hollow Knight
# - - 7. : Rust
# - - 8. : Frostpunk
# - - 9. : Team Fortress 2
# - - 10. : Bloons TD 6
# - - 11. : Sid Meier's Civilization VI
# - - 12. : Geometry Dash
# - - 13. : Raft
# - - 14. : OMORI
# - - 15. : My Singing Monsters
# - - 16. : Counter-Strike 2
# - - 17. : Left 4 Dead 2
# - - 18. : Portal 2
# - - 19. : Phasmophobia
# - - 20. : Cuphead
# - - 21. : STAR WARS™ Battlefront™ II
# - - 22. : Potion Craft: Alchemist Simulator
# - - 23. : Wallpaper Engine
# - - 24. : The Walking Dead
# - - 25. : Goose Goose Duck
# - - 26. : Hue
# - - 27. : Slime Rancher
# - - 28. : Blender
# - - 29. : Pixel Gun 3D: PC Edition
# - 2번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Garry's Mod
# - - 1. : People Playground
# - - 2. : HELLDIVERS™ 2
# - - 3. : Totally Accurate Battle Simulator
# - - 4. : STAR WARS™: The Old Republic™
# - - 5. : Left 4 Dead 2
# - - 6. : The Forest
# - - 7. : Fallout 4
# - - 8. : Unturned
# - - 9. : Stormworks: Build and Rescue
# - - 10. : Counter-Strike 2
# - - 11. : Kingdom Come: Deliverance II
# - - 12. : Learn to Fly 3
# - - 13. : Phasmophobia
# - - 14. : The Walking Dead: The Telltale Definitive Series
# - - 15. : Dying Light
# - - 16. : Cyberpunk 2077
# - - 17. : Project Zomboid
# - - 18. : Human Fall Flat
# - - 19. : Lethal Company
# - - 20. : FOR HONOR
# - - 21. : Half-Life 2
# - - 22. : Ancestors: The Humankind Odyssey
# - - 23. : Batman - The Telltale Series
# - - 24. : Sons Of The Forest
# - - 25. : Blender
# - - 26. : Amazing Frog?
# - - 27. : Raft
# - - 28. : Portal 2
# - - 29. : Grand Theft Auto V Legacy
# - 2번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198860104675 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Team Fortress Classic
# - - 2. : Day of Defeat
# - - 3. : Deathmatch Classic
# - - 4. : Half-Life: Opposing Force
# - - 5. : Ricochet
# - - 6. : Half-Life
# - - 7. : Counter-Strike: Condition Zero
# - - 8. : Counter-Strike: Condition Zero Deleted Scenes
# - - 9. : Half-Life: Blue Shift
# - - 10. : Half-Life 2
# - - 11. : Counter-Strike: Source
# - - 12. : Half-Life: Source
# - - 13. : Day of Defeat: Source
# - - 14. : Half-Life 2: Deathmatch
# - - 15. : Half-Life Deathmatch: Source
# - - 16. : Portal
# - - 17. : Left 4 Dead
# - - 18. : Left 4 Dead 2
# - - 19. : Portal 2
# - - 20. : Batman: Arkham Asylum GOTY Edition
# - - 21. : FINAL FANTASY XIV Online
# - - 22. : Borderlands 2
# - - 23. : Project Zomboid
# - - 24. : Batman: Arkham City GOTY
# - - 25. : Tomb Raider
# - - 26. : Castle Crashers
# - - 27. : The Walking Dead
# - - 28. : Batman™: Arkham Knight
# - - 29. : DayZ
# - 2번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Black Desert (Retired)
# - - 1. : Black Desert
# - - 2. : Transformice
# - - 3. : PUBG: BATTLEGROUNDS
# - - 4. : TBH: Task Bar Hero
# - - 5. : War Thunder
# - - 6. : Counter-Strike 2
# - - 7. : Game Migrated to Another Steam Page
# - - 8. : Mount & Blade II: Bannerlord
# - - 9. : Baldur's Gate 3
# - - 10. : Tom Clancy's Rainbow Six Siege
# - - 11. : Euro Truck Simulator 2
# - - 12. : The Witcher 3: Wild Hunt
# - - 13. : Knight Online
# - - 14. : V Rising
# - - 15. : Dune: Awakening
# - - 16. : Cyberpunk 2077
# - - 17. : Divinity: Original Sin 2
# - - 18. : Project Zomboid
# - - 19. : Lost Ark
# - - 20. : Crimson Desert
# - - 21. : Rust
# - - 22. : Battlerite
# - - 23. : SMITE
# - - 24. : Total War: ATTILA
# - - 25. : Among Us
# - - 26. : Valheim
# - - 27. : Assassin's Creed Odyssey
# - - 28. : Ranch Simulator
# - - 29. : Sid Meier's Civilization V
# - 2번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : ARC Raiders
# - - 1. : Marvel Rivals
# - - 2. : HELLDIVERS™ 2
# - - 3. : Marvel's Spider-Man 2
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : War Thunder
# - - 6. : Battlefield™ 6
# - - 7. : Phasmophobia
# - - 8. : Marvel’s Spider-Man Remastered
# - - 9. : Red Dead Redemption 2
# - - 10. : Just Cause 3
# - - 11. : BeamNG.drive
# - - 12. : Assetto Corsa
# - - 13. : American Truck Simulator
# - - 14. : Squad
# - - 15. : Overwatch®
# - - 16. : Valheim
# - - 17. : skate.
# - - 18. : Marvel's Spider-Man: Miles Morales
# - - 19. : Arma 3
# - - 20. : Kerbal Space Program
# - - 21. : Star Wars Outlaws
# - - 22. : Mortal Kombat X
# - - 23. : Tony Hawk's™ Pro Skater™ 1 + 2
# - - 24. : Ready or Not
# - - 25. : Escape from Tarkov
# - - 26. : MARVEL SNAP
# - - 27. : Aviassembly
# - - 28. : ROUNDS
# - - 29. : PEAK
# - 2번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : ShareX
# - - 1. : Rust
# - - 2. : Counter-Strike 2
# - - 3. : PUBG: BATTLEGROUNDS
# - - 4. : My Summer Car
# - - 5. : Brick Rigs
# - - 6. : The Forest
# - - 7. : The Binding of Isaac: Rebirth
# - - 8. : Muck
# - - 9. : Squad
# - - 10. : Half-Life
# - - 11. : Phasmophobia
# - - 12. : Cuphead
# - - 13. : Half-Life 2
# - - 14. : Slime Rancher
# - - 15. : Portal 2
# - - 16. : MiSide
# - - 17. : MudRunner
# - - 18. : Stormworks: Build and Rescue
# - - 19. : Half-Life: Opposing Force
# - - 20. : R.E.P.O.
# - - 21. : Metro 2033 Redux
# - - 22. : One-armed robber
# - - 23. : Forts
# - - 24. : Content Warning
# - - 25. : Sons Of The Forest
# - - 26. : Easy Delivery Co.
# - - 27. : Ocean World: Eden Crafters Prologue
# - - 28. : Buckshot Roulette
# - - 29. : Sea of Thieves
# - 2번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : STALZONE
# - - 1. : Wallpaper Engine
# - - 2. : Grand Theft Auto V Legacy
# - - 3. : Soundpad
# - - 4. : HudSight - crosshair overlay
# - - 5. : Sons Of The Forest
# - - 6. : 7 Days to Die
# - - 7. : Workers & Resources: Soviet Republic
# - - 8. : Lethal Company
# - - 9. : Euro Truck Simulator 2
# - - 10. : Minecraft Dungeons
# - - 11. : Escape the Backrooms
# - - 12. : Age of History II
# - - 13. : DOOM Eternal
# - - 14. : Phasmophobia
# - - 15. : Geometry Dash
# - - 16. : Garry's Mod
# - - 17. : Satisfactory
# - - 18. : DOOM: The Dark Ages
# - - 19. : The Forest
# - - 20. : Portal 2
# - - 21. : Casualties: Unknown Demo
# - - 22. : Subnautica
# - - 23. : BeamNG.drive
# - - 24. : Apex Legends
# - - 25. : Red Dead Redemption 2
# - - 26. : Rust
# - - 27. : Dead by Daylight
# - - 28. : R.E.P.O.
# - - 29. : Age of History 3
# - 2번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Rocket League
# - - 2. : Stardew Valley
# - - 3. : Euro Truck Simulator 2
# - - 4. : Kenshi
# - - 5. : Grand Theft Auto: San Andreas
# - - 6. : WorldBox - God Simulator
# - - 7. : Phasmophobia
# - - 8. : Terraria
# - - 9. : Godot Engine
# - - 10. : Red Dead Redemption 2
# - - 11. : BeamNG.drive
# - - 12. : TBH: Task Bar Hero
# - - 13. : Aseprite
# - - 14. : Forza Horizon 4
# - - 15. : Fall Guys
# - - 16. : Grand Theft Auto IV: The Complete Edition
# - - 17. : Tower Unite
# - - 18. : Pummel Party
# - - 19. : Ravenfield
# - - 20. : Project Zomboid
# - - 21. : Slime Rancher
# - - 22. : Batman™: Arkham Knight
# - - 23. : Totally Accurate Battle Simulator
# - - 24. : Muck
# - - 25. : POSTAL 2
# - - 26. : Black Mesa
# - - 27. : Vampire Survivors
# - - 28. : Ultimate Chicken Horse
# - - 29. : eFootball™
# - 2번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Wallpaper Engine
# - - 1. : Counter-Strike 2
# - - 2. : Limbus Company
# - - 3. : KARDS - The WWII Card Game
# - - 4. : Call of Duty®
# - - 5. : Grand Theft Auto V Legacy
# - - 6. : Battlefield™ V
# - - 7. : Lossless Scaling
# - - 8. : This War of Mine
# - - 9. : Apex Legends
# - - 10. : Battlefield™ 2042
# - - 11. : HELLDIVERS™ 2
# - - 12. : Lobotomy Corporation
# - - 13. : Slay the Spire
# - - 14. : Forza Horizon 4
# - - 15. : Red Dead Redemption 2
# - - 16. : Library Of Ruina
# - - 17. : Unturned
# - - 18. : Phasmophobia
# - - 19. : Tom Clancy's Ghost Recon® Wildlands
# - - 20. : Wuthering Waves
# - - 21. : Lost
# - - 22. : Forza Horizon 5
# - - 23. : Sons Of The Forest
# - - 24. : Seek Girl Ⅵ
# - - 25. : Danganronpa 2: Goodbye Despair
# - - 26. : Escape the Backrooms
# - - 27. : Seek Girl
# - - 28. : State of Decay 2
# - - 29. : Detroit: Become Human
# - 2번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# - - 0. : 7 Days to Die
# - - 1. : VRChat
# - - 2. : Team Fortress 2
# - - 3. : Project Zomboid
# - - 4. : Counter-Strike 2
# - - 5. : Lethal Company
# - - 6. : Terraria
# - - 7. : Inside the Backrooms
# - - 8. : Rust
# - - 9. : Far Cry 5
# - - 10. : Cookie Clicker
# - - 11. : EVE Online
# - - 12. : Phasmophobia
# - - 13. : Fallout 4
# - - 14. : My Summer Car
# - - 15. : Sea of Thieves
# - - 16. : Beat Saber
# - - 17. : No Man's Sky
# - - 18. : Counter-Strike: Source
# - - 19. : Among Us
# - - 20. : DOOM Eternal
# - - 21. : Sons Of The Forest
# - - 22. : Stardew Valley
# - - 23. : Unturned
# - - 24. : ULTRAKILL
# - - 25. : Grand Theft Auto V Legacy
# - - 26. : The Elder Scrolls V: Skyrim Special Edition
# - - 27. : Scrap Mechanic
# - - 28. : Starbound
# - - 29. : Super Hexagon
# - 2번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Escape from Tarkov
# - - 1. : Broken Arrow
# - - 2. : Counter-Strike 2
# - - 3. : 7 Days to Die
# - - 4. : Barotrauma
# - - 5. : Phasmophobia
# - - 6. : Overwatch®
# - - 7. : Terraria
# - - 8. : WARNO
# - - 9. : Hearts of Iron IV
# - - 10. : Europa Universalis V
# - - 11. : Cyberpunk 2077
# - - 12. : PAYDAY 2
# - - 13. : Cities: Skylines II
# - - 14. : Soundpad
# - - 15. : Victoria 3
# - - 16. : Delta Force
# - - 17. : Left 4 Dead 2
# - - 18. : Ready or Not
# - - 19. : Steel Division 2
# - - 20. : tModLoader
# - - 21. : Arma Reforger
# - - 22. : Goose Goose Duck
# - - 23. : Battlefield™ 2042
# - - 24. : Void Crew
# - - 25. : Guilty as Sock!
# - - 26. : Ghost Exile
# - - 27. : Tabletop Simulator
# - - 28. : Stick Fight: The Game
# - - 29. : The Jackbox Party Pack 4
# - 2번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Garry's Mod
# - - 2. : Phasmophobia
# - - 3. : Ready or Not
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : Terraria
# - - 6. : Among Us
# - - 7. : Halo: The Master Chief Collection
# - - 8. : The Coffin of Andy and Leyley
# - - 9. : Castle Crashers
# - - 10. : War Thunder
# - - 11. : Resident Evil 7 Biohazard
# - - 12. : FOR HONOR
# - - 13. : PUBG: BATTLEGROUNDS
# - - 14. : Resident Evil Village
# - - 15. : Resident Evil 3
# - - 16. : Red Dead Redemption 2
# - - 17. : Metro: Last Light Redux
# - - 18. : tModLoader
# - - 19. : DARK SOULS™ III
# - - 20. : The Forest
# - - 21. : The Sims™ 4
# - - 22. : Emily Wants To Play
# - - 23. : Far Cry 4
# - - 24. : Stumble Guys
# - - 25. : Subnautica
# - - 26. : SCP: Secret Laboratory
# - - 27. : My Singing Monsters
# - - 28. : Hollow Knight
# - - 29. : Comedy Night
# - 2번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Phasmophobia
# - - 1. : Tom Clancy's The Division 2
# - - 2. : Palworld
# - - 3. : Shattered Minds
# - - 4. : Mistfall Hunter
# - - 5. : Grand Theft Auto: Vice City - The Definitive Edition
# - - 6. : LOVE Hotel Simulator 🏩
# - - 7. : With Eyes Closed - Season 1
# - - 8. : Left 4 Dead 2
# - - 9. : PEAK
# - - 10. : Fahrenheit: Indigo Prophecy Remastered
# - - 11. : Counter-Strike 2
# - - 12. : Fates: Determination
# - - 13. : Demonologist
# - - 14. : With Eyes Closed - Season 2
# - - 15. : My Bimbo Dream
# - - 16. : Evil School
# - - 17. : Tom Clancy's Ghost Recon® Wildlands
# - - 18. : Grand Theft Auto: San Andreas - The Definitive Edition
# - - 19. : Zenless Zone Zero
# - - 20. : Grand Theft Auto IV: The Complete Edition
# - - 21. : RuneScape
# - - 22. : No More Room in Hell
# - - 23. : Vampyr
# - - 24. : The Division Resurgence
# - - 25. : Resident Evil 4
# - - 26. : Among Us
# - - 27. : My Sexy Neighbor 🔞
# - - 28. : My sexy Neighbour 2
# - - 29. : Mafia II (Classic)
# - 3번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : The Binding of Isaac: Rebirth
# - - 1. : Lethal Company
# - - 2. : Terraria
# - - 3. : Counter-Strike 2
# - - 4. : Cyberpunk 2077
# - - 5. : Age of History II
# - - 6. : Hollow Knight: Silksong
# - - 7. : Hollow Knight
# - - 8. : ELDEN RING
# - - 9. : Outer Wilds
# - - 10. : Balatro
# - - 11. : Disco Elysium
# - - 12. : Celeste
# - - 13. : Apex Legends
# - - 14. : Stardew Valley
# - - 15. : Risk of Rain 2
# - - 16. : Albion Online
# - - 17. : House Flipper
# - - 18. : PEAK
# - - 19. : Return of the Obra Dinn
# - - 20. : Hearts of Iron IV
# - - 21. : DELTARUNE (Chapter 1 & 2 DEMO)
# - - 22. : Spore
# - - 23. : Enter the Gungeon
# - - 24. : Game Dev Tycoon
# - - 25. : Euro Truck Simulator 2
# - - 26. : Lies of P
# - - 27. : Keep Talking and Nobody Explodes
# - - 28. : ULTRAKILL
# - - 29. : Esoteric Ebb
# - 3번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : PUBG: BATTLEGROUNDS
# - - 2. : Dredgers
# - - 3. : Risk of Rain 2
# - - 4. : Don't Starve Together
# - - 5. : Craft The World
# - - 6. : Aseprite
# - - 7. : Mount & Blade II: Bannerlord
# - - 8. : Goose Goose Duck
# - - 9. : Neon Beats
# - - 10. : Abiotic Factor
# - - 11. : Cyberpunk 2077
# - - 12. : Assassin's Creed IV Black Flag
# - - 13. : Lethal Company
# - - 14. : STEINS;GATE
# - - 15. : Detroit: Become Human
# - - 16. : NARAKA: BLADEPOINT
# - - 17. : FINAL FANTASY XV WINDOWS EDITION
# - - 18. : Overcooked! 2
# - - 19. : Left 4 Dead 2
# - - 20. : Escape the Backrooms
# - - 21. : Battlefield™ V
# - - 22. : STEINS;GATE 0
# - - 23. : Subnautica 2
# - - 24. : Lost Castle
# - - 25. : DAVE THE DIVER
# - - 26. : Party Hard
# - - 27. : Chained Together
# - - 28. : Red Dead Redemption 2
# - - 29. : Project Zomboid
# - 3번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Deadlock
# - - 2. : Terraria
# - - 3. : Dead Cells
# - - 4. : Baldur's Gate 3
# - - 5. : Squad
# - - 6. : Palworld
# - - 7. : Barotrauma
# - - 8. : Deep Rock Galactic
# - - 9. : Valheim
# - - 10. : Abiotic Factor
# - - 11. : Fallout 4
# - - 12. : Total War: WARHAMMER III
# - - 13. : Divinity: Original Sin Enhanced Edition
# - - 14. : Battlefield™ 2042
# - - 15. : Windrose
# - - 16. : 7 Days to Die
# - - 17. : PAYDAY 2
# - - 18. : Wallpaper Engine
# - - 19. : Don't Starve Together
# - - 20. : Blitzkrieg 2 Anthology
# - - 21. : The Forest
# - - 22. : Unturned
# - - 23. : DOOM
# - - 24. : Saints Row: The Third
# - - 25. : Graveyard Keeper
# - - 26. : Sons Of The Forest
# - - 27. : Battlefield: Bad Company™ 2
# - - 28. : Detroit: Become Human
# - - 29. : DARK SOULS™ III
# - 3번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Screen Cat
# - - 1. : Satisfactory
# - - 2. : Scrap Mechanic
# - - 3. : Counter-Strike 2
# - - 4. : Raft
# - - 5. : Rust
# - - 6. : Geometry Dash
# - - 7. : The Planet Crafter
# - - 8. : ASTRONEER
# - - 9. : People Playground
# - - 10. : Poppy Playtime
# - - 11. : Portal 2
# - - 12. : SCP: Secret Laboratory
# - - 13. : Space Engineers
# - - 14. : Project Playtime
# - - 15. : Lethal Company
# - - 16. : STALZONE
# - - 17. : Hi-Fi RUSH
# - - 18. : Mad Max
# - - 19. : Terraria
# - - 20. : Blender
# - - 21. : PUBG: BATTLEGROUNDS
# - - 22. : Sons Of The Forest
# - - 23. : METAL GEAR RISING: REVENGEANCE
# - - 24. : PEAK
# - - 25. : Cube Racer
# - - 26. : BeamNG.drive
# - - 27. : tModLoader
# - - 28. : Voidtrain
# - - 29. : Wall World
# - 3번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Lethal Company
# - - 1. : Dead by Daylight
# - - 2. : SCP: Secret Laboratory
# - - 3. : No Man's Sky
# - - 4. : Banana
# - - 5. : Casualties: Unknown Demo
# - - 6. : R.E.P.O.
# - - 7. : RimWorld
# - - 8. : Space Engineers
# - - 9. : Ready or Not
# - - 10. : Counter-Strike 2
# - - 11. : Once Human
# - - 12. : Dark and Darker
# - - 13. : Kingdom Come: Deliverance
# - - 14. : Among Us
# - - 15. : Resident Evil 2
# - - 16. : HITMAN World of Assassination
# - - 17. : PEAK
# - - 18. : PANICORE
# - - 19. : Phasmophobia
# - - 20. : Wolfenstein: The New Order
# - - 21. : Shadows of Doubt
# - - 22. : Left 4 Dead 2
# - - 23. : Balatro
# - - 24. : Terraria
# - - 25. : DayZ
# - - 26. : The Forest
# - - 27. : Backrooms: Escape Together
# - - 28. : A Way Out
# - - 29. : Fallout 4
# - 3번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Garry's Mod
# - - 1. : Planet Zoo
# - - 2. : SCP: Secret Laboratory
# - - 3. : Grand Theft Auto V Enhanced
# - - 4. : Hearts of Iron IV
# - - 5. : Project Zomboid
# - - 6. : Counter-Strike: Source
# - - 7. : Dota 2
# - - 8. : Workers & Resources: Soviet Republic
# - - 9. : Detroit: Become Human
# - - 10. : Teardown
# - - 11. : Dale & Dawson Stationery Supplies
# - - 12. : Counter-Strike
# - - 13. : Grand Theft Auto V Legacy
# - - 14. : Half-Life 2
# - - 15. : Enlisted
# - - 16. : Fallout Shelter
# - - 17. : R.E.P.O.
# - - 18. : Fallout 4
# - - 19. : Among Us
# - - 20. : Euro Truck Simulator 2
# - - 21. : Schedule I
# - - 22. : Content Warning
# - - 23. : Ancient Warfare 3
# - - 24. : Eco
# - - 25. : Day of Defeat
# - - 26. : Left 4 Dead
# - - 27. : Terraria
# - - 28. : Portal 2
# - - 29. : Supermarket Together
# - 3번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Marvel Rivals
# - - 1. : Kingdom Come: Deliverance II
# - - 2. : Phasmophobia
# - - 3. : Dead by Daylight
# - - 4. : The Outlast Trials
# - - 5. : Project Zomboid
# - - 6. : Apex Legends
# - - 7. : HELLDIVERS™ 2
# - - 8. : Dying Light: The Beast
# - - 9. : METAL GEAR SOLID Δ: SNAKE EATER
# - - 10. : Lethal Company
# - - 11. : Call of Duty®
# - - 12. : R.E.P.O.
# - - 13. : Schedule I
# - - 14. : Counter-Strike 2
# - - 15. : ELDEN RING
# - - 16. : Tom Clancy's Rainbow Six Siege
# - - 17. : Kingdom Come: Deliverance
# - - 18. : METAL GEAR SOLID V: THE PHANTOM PAIN
# - - 19. : Sons Of The Forest
# - - 20. : Assassin's Creed Valhalla
# - - 21. : 007 First Light
# - - 22. : Resident Evil Village
# - - 23. : STAR WARS Jedi: Survivor™
# - - 24. : STAR WARS™ Battlefront™ II
# - - 25. : SILENT HILL 2
# - - 26. : STAR WARS Jedi: Fallen Order™
# - - 27. : Dying Light
# - - 28. : Resident Evil 7 Biohazard
# - - 29. : Tom Clancy's Splinter Cell Blacklist
# - 3번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Halo: The Master Chief Collection
# - - 1. : Garry's Mod
# - - 2. : Destiny 2
# - - 3. : Lethal Company
# - - 4. : The Elder Scrolls V: Skyrim Special Edition
# - - 5. : The Jackbox Party Pack 3
# - - 6. : Portal 2
# - - 7. : Call of Duty: Black Ops III
# - - 8. : LEGO® Star Wars™: The Complete Saga
# - - 9. : Cubic Odyssey
# - - 10. : CastleMiner Z
# - - 11. : Half-Life: Source
# - - 12. : The Planet Crafter
# - - 13. : Half-Life
# - - 14. : Portal
# - - 15. : The Elder Scrolls V: Skyrim
# - - 16. : Undertale
# - - 17. : The Jackbox Party Pack
# - - 18. : Splitgate
# - - 19. : Half-Life 2
# - - 20. : Halo Infinite
# - - 21. : Audiosurf
# - - 22. : Amnesia: The Dark Descent
# - - 23. : Counter-Strike: Source
# - - 24. : Riven (1997)
# - - 25. : Half-Life: Alyx
# - - 26. : Quake
# - - 27. : Myst III: Exile
# - - 28. : Northgard: Definitive Edition
# - - 29. : Among Us
# - 3번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Left 4 Dead 2
# - - 1. : Counter-Strike 2
# - - 2. : Call of Duty®
# - - 3. : Shakes and Fidget
# - - 4. : Danganronpa V3: Killing Harmony
# - - 5. : Team Fortress 2
# - - 6. : Garry's Mod
# - - 7. : Back 4 Blood
# - - 8. : EA SPORTS FC™ 24
# - - 9. : Dead by Daylight
# - - 10. : OMORI
# - - 11. : Terraria
# - - 12. : The Hundred Line -Last Defense Academy-
# - - 13. : Doki Doki Literature Club
# - - 14. : Danganronpa 2: Goodbye Despair
# - - 15. : Call of Duty: Black Ops III
# - - 16. : Danganronpa: Trigger Happy Havoc
# - - 17. : Your Turn To Die -Death Game By Majority-
# - - 18. : Among Us
# - - 19. : Killing Floor 2
# - - 20. : Warframe
# - - 21. : Don't Starve
# - - 22. : Gang Beasts
# - - 23. : Cookie Clicker
# - - 24. : The Binding of Isaac: Rebirth
# - - 25. : Wallpaper Engine
# - - 26. : Just Cause 3
# - - 27. : Game Dev Tycoon
# - - 28. : Don't Starve Together
# - - 29. : RPG Maker MV
# - 3번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Rust
# - - 1. : Counter-Strike 2
# - - 2. : SCP: Secret Laboratory
# - - 3. : ARC Raiders
# - - 4. : Team Fortress 2
# - - 5. : Lethal Company
# - - 6. : Terraria
# - - 7. : Bongo Cat
# - - 8. : Fall Guys
# - - 9. : LOCKDOWN Protocol
# - - 10. : Geometry Dash
# - - 11. : Squad
# - - 12. : Satisfactory
# - - 13. : R.E.P.O.
# - - 14. : THE FINALS
# - - 15. : PEAK
# - - 16. : Hollow Knight
# - - 17. : Soundpad
# - - 18. : Dale & Dawson Stationery Supplies
# - - 19. : STALZONE
# - - 20. : Crab Game
# - - 21. : Content Warning
# - - 22. : Dead by Daylight
# - - 23. : Bopl Battle
# - - 24. : Cuphead
# - - 25. : Deceit
# - - 26. : War Thunder
# - - 27. : Wallpaper Engine
# - - 28. : Apex Legends
# - - 29. : Deadlock
# - 3번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Unturned
# - - 1. : Rust
# - - 2. : Tom Clancy's Rainbow Six Siege
# - - 3. : Garry's Mod
# - - 4. : Red Dead Redemption 2
# - - 5. : People Playground
# - - 6. : Project Zomboid
# - - 7. : HITMAN World of Assassination
# - - 8. : Grand Theft Auto V Legacy
# - - 9. : Terraria
# - - 10. : Rec Room
# - - 11. : Counter-Strike 2
# - - 12. : Human Fall Flat
# - - 13. : DayZ
# - - 14. : Far Cry 5
# - - 15. : Red Dead Online
# - - 16. : Stormworks: Build and Rescue
# - - 17. : Lethal Company
# - - 18. : No Man's Sky
# - - 19. : Pixel Strike 3D
# - - 20. : Sea of Thieves
# - - 21. : PEAK
# - - 22. : PAYDAY 2
# - - 23. : Left 4 Dead 2
# - - 24. : Fallout 4
# - - 25. : Among Us
# - - 26. : Raft
# - - 27. : BattleBlock Theater
# - - 28. : Phasmophobia
# - - 29. : Hunt: Showdown 1896
# - 3번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198137180760 최근 게임 없음
# - - 0. : Half-Life 2
# - - 1. : Half-Life 2: Deathmatch
# - - 2. : Half-Life Deathmatch: Source
# - - 3. : Portal
# - - 4. : Team Fortress 2
# - - 5. : Left 4 Dead
# - - 6. : Left 4 Dead 2
# - - 7. : Portal 2
# - - 8. : Call of Juarez
# - - 9. : Stronghold Crusader Extreme HD
# - - 10. : Watchmen: The End Is Nigh
# - - 11. : Watchmen: The End Is Nigh Part 2
# - - 12. : F.E.A.R.
# - - 13. : F.E.A.R.: Extraction Point
# - - 14. : F.E.A.R.: Perseus Mandate
# - - 15. : Call of Juarez: Bound in Blood
# - - 16. : Batman: Arkham Asylum GOTY Edition
# - - 17. : Stronghold HD
# - - 18. : Stronghold Crusader HD
# - - 19. : Batman: Arkham City GOTY
# - - 20. : Jurassic Park: The Game
# - - 21. : Call of Juarez Gunslinger
# - - 22. : Batman™: Arkham Knight
# - - 23. : Batman™: Arkham Origins
# - - 24. : Euro Truck Simulator 2
# ...
# - - 19. : Librarian: Tidy Up the Arcane Library!
# - - 20. : Devil May Cry 5
# - - 21. : Paper Dolls Original
# - - 22. : Sanfu
# - - 23. : Draw & Guess
# - - 24. : Buy a Croquette!
# - - 25. : MECCHA CHAMELEON
# - - 26. : 雀魂麻将(MahjongSoul)
# - - 27. : Monument Valley
# - - 28. : Little Nightmares II
# - - 29. : Chained Together
# - 8번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Bongo Cat
# - - 1. : ELDEN RING
# - - 2. : Phasmophobia
# - - 3. : Stardew Valley
# - - 4. : Borderlands 2
# - - 5. : Shakes and Fidget
# - - 6. : Apex Legends
# - - 7. : R.E.P.O.
# - - 8. : Sea of Thieves
# - - 9. : Palworld
# - - 10. : Lethal Company
# - - 11. : Dead by Daylight
# - - 12. : Slime Rancher
# - - 13. : Resident Evil 5
# - - 14. : Left 4 Dead 2
# - - 15. : Soulworker
# - - 16. : Garry's Mod
# - - 17. : Marvel Rivals
# - - 18. : Back 4 Blood
# - - 19. : Muse Dash
# - - 20. : It Takes Two
# - - 21. : WEBFISHING
# - - 22. : Hades
# - - 23. : Wallpaper Engine
# - - 24. : Resident Evil 4
# - - 25. : Resident Evil 2
# - - 26. : DOOM Eternal
# - - 27. : Among Us
# - - 28. : Wolfenstein: The New Order
# - - 29. : Remnant II
# - 8번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Battlefield™ 1
# - - 1. : HELLDIVERS™ 2
# - - 2. : Terraria
# - - 3. : tModLoader
# - - 4. : Tom Clancy's Rainbow Six Siege
# - - 5. : Phasmophobia
# - - 6. : Baldur's Gate 3
# - - 7. : No Man's Sky
# - - 8. : Slay the Spire 2
# - - 9. : Counter-Strike 2
# - - 10. : Risk of Rain 2
# - - 11. : Battlefield™ 2042
# - - 12. : Wallpaper Engine
# - - 13. : KARDS - The WWII Card Game
# - - 14. : Deep Rock Galactic
# - - 15. : Lost Castle 2
# - - 16. : Kingdom Come: Deliverance II
# - - 17. : Abiotic Factor
# - - 18. : For The King
# - - 19. : Monster Hunter Wilds
# - - 20. : Mindustry
# - - 21. : Sephiria
# - - 22. : DragonSword : Awakening
# - - 23. : Sons Of The Forest
# - - 24. : Return of the Obra Dinn
# - - 25. : Grounded
# - - 26. : Palworld
# - - 27. : Stardew Valley
# - - 28. : The Alters
# - - 29. : Battlefield™ V
# - 8번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Apex Legends
# - - 1. : Dead by Daylight
# - - 2. : Call of Duty®
# - - 3. : Marvel Rivals
# - - 4. : Wuthering Waves
# - - 5. : NBA 2K24
# - - 6. : Cyberpunk 2077
# - - 7. : Terraria
# - - 8. : NBA 2K26
# - - 9. : Lethal Company
# - - 10. : Back 4 Blood
# - - 11. : Warframe
# - - 12. : Dying Light 2: Reloaded Edition
# - - 13. : Supermarket Together
# - - 14. : NBA 2K23
# - - 15. : Wallpaper Engine
# - - 16. : The First Descendant
# - - 17. : Pixel Gun 3D: PC Edition
# - - 18. : THE FINALS
# - - 19. : Tower Unite
# - - 20. : Mortal Kombat 11
# - - 21. : Palworld
# - - 22. : Waterpark Simulator
# - - 23. : The Isle
# - - 24. : Mortal Kombat 1
# - - 25. : Resident Evil 4
# - - 26. : OUTRIDERS
# - - 27. : Resident Evil 2
# - - 28. : Vampire: The Masquerade - Bloodhunt
# - - 29. : Escape the Backrooms
# - 9번 게임의 0번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Age of Empires II: Definitive Edition
# - - 1. : Red Dead Redemption 2
# - - 2. : Plague Inc: Evolved
# - - 3. : Counter-Strike 2
# - - 4. : Jurassic World Evolution 2
# - - 5. : The Forest
# - - 6. : PUBG: BATTLEGROUNDS
# - - 7. : Raft
# - - 8. : Assassin's Creed Odyssey
# - - 9. : Ready or Not
# - - 10. : Teardown
# - - 11. : Home Sheep Home: Farmageddon Party Edition
# - - 12. : Plants vs. Zombies: Game of the Year
# - - 13. : Grand Theft Auto IV: The Complete Edition
# - - 14. : Grand Theft Auto: San Andreas - The Definitive Edition
# - - 15. : There Is No Game: Wrong Dimension
# - - 16. : Friday the 13th: The Game
# - - 17. : Police Stories
# - - 18. : Totally Accurate Battle Simulator
# - - 19. : Sons Of The Forest
# - - 20. : Assassin's Creed Valhalla
# - - 21. : Hello Neighbor
# - - 22. : Bridge Constructor
# - - 23. : Project Zomboid
# - - 24. : Stick Fight: The Game
# - - 25. : Return of the Obra Dinn
# - - 26. : Worms W.M.D
# - - 27. : Call of Duty®
# - - 28. : F1 2020
# - - 29. : Grand Theft Auto III - The Definitive Edition
# - 9번 게임의 1번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561198852349730 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Team Fortress Classic
# - - 2. : Day of Defeat
# - - 3. : Deathmatch Classic
# - - 4. : Half-Life: Opposing Force
# - - 5. : Ricochet
# - - 6. : Half-Life
# - - 7. : Counter-Strike: Condition Zero
# - - 8. : Counter-Strike: Condition Zero Deleted Scenes
# - - 9. : Half-Life: Blue Shift
# - - 10. : Half-Life 2
# - - 11. : Counter-Strike: Source
# - - 12. : Half-Life: Source
# - - 13. : Day of Defeat: Source
# - - 14. : Half-Life 2: Deathmatch
# - - 15. : Half-Life Deathmatch: Source
# - - 16. : Portal
# - - 17. : Team Fortress 2
# - - 18. : Left 4 Dead
# - - 19. : Left 4 Dead 2
# - - 20. : Portal 2
# - - 21. : Counter-Strike 2
# - - 22. : Peggle Deluxe
# - - 23. : Peggle Nights
# - - 24. : Plants vs. Zombies: Game of the Year
# - - 25. : Garry's Mod
# - - 26. : Grand Theft Auto: San Andreas
# - - 27. : Tales of Monkey Island: Chapter 1 - Launch of the Screaming Narwhal
# - - 28. : Tales of Monkey Island: Chapter 2 - The Siege of Spinner Cay
# - - 29. : Tales of Monkey Island: Chapter 3 - Lair of the Leviathan
# - 9번 게임의 2번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Tom Clancy's Rainbow Six Siege
# - - 2. : Call of Duty®
# - - 3. : ELDEN RING
# - - 4. : Apex Legends
# - - 5. : The Elder Scrolls V: Skyrim Special Edition
# - - 6. : Clair Obscur: Expedition 33
# - - 7. : Cyberpunk 2077
# - - 8. : EA SPORTS™ FIFA 23
# - - 9. : Palworld
# - - 10. : F1 2020
# - - 11. : Subnautica
# - - 12. : Hogwarts Legacy
# - - 13. : Session: Skate Sim
# - - 14. : Baldur's Gate 3
# - - 15. : F1 2021
# - - 16. : Subnautica: Below Zero
# - - 17. : Call of Duty®: Modern Warfare® II
# - - 18. : Wallpaper Engine
# - - 19. : Hitman: Absolution
# - - 20. : Among Us
# - - 21. : Jurassic World Evolution
# - - 22. : Sekiro™: Shadows Die Twice
# - - 23. : MONOPOLY Poker
# - - 24. : Hello Neighbor
# - - 25. : Inside the Backrooms
# - - 26. : Need for Speed™ Heat
# - - 27. : Raft
# - - 28. : Outer Wilds
# - - 29. : ELDEN RING NIGHTREIGN
# - 9번 게임의 3번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Sid Meier's Civilization VI
# - - 1. : Sid Meier's Civilization V
# - - 2. : Terraria
# - - 3. : tModLoader
# - - 4. : Spelunky 2
# - - 5. : ARC Raiders
# - - 6. : Project Zomboid
# - - 7. : Cookie Clicker
# - - 8. : HELLDIVERS™ 2
# - - 9. : THE FINALS
# - - 10. : Risk of Rain 2
# - - 11. : Abiotic Factor
# - - 12. : Mindustry
# - - 13. : Cyberpunk 2077
# - - 14. : Don't Starve Together
# - - 15. : Barotrauma
# - - 16. : Marvel Rivals
# - - 17. : PEAK
# - - 18. : Lethal Company
# - - 19. : Brawlhalla
# - - 20. : Fallout 4
# - - 21. : Apex Legends
# - - 22. : R.E.P.O.
# - - 23. : VRChat
# - - 24. : Garry's Mod
# - - 25. : Enter the Gungeon
# - - 26. : Space Engineers
# - - 27. : Raft
# - - 28. : Baldur's Gate 3
# - - 29. : Satisfactory
# - 9번 게임의 4번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Tap Ninja
# - - 1. : TBH: Task Bar Hero
# - - 2. : Monster Hunter: World
# - - 3. : Apex Legends
# - - 4. : MONSTER HUNTER RISE
# - - 5. : Forza Horizon 4
# - - 6. : ELDEN RING
# - - 7. : Forza Horizon 5
# - - 8. : Palworld
# - - 9. : Deep Rock Galactic
# - - 10. : Monster Hunter Wilds
# - - 11. : Counter-Strike 2
# - - 12. : Don't Starve Together
# - - 13. : Idle Hero TD - Tower Defense RPG
# - - 14. : Cities: Skylines
# - - 15. : HELLDIVERS™ 2
# - - 16. : Rusty's Retirement
# - - 17. : Brotato
# - - 18. : Raft
# - - 19. : Black Myth: Wukong
# - - 20. : House Flipper
# - - 21. : PUBG: BATTLEGROUNDS
# - - 22. : Terraria
# - - 23. : DAVE THE DIVER
# - - 24. : Assassin's Creed Origins
# - - 25. : Assassin's Creed Odyssey
# - - 26. : Risk of Rain 2
# - - 27. : Granblue Fantasy: Relink
# - - 28. : Escape From Duckov
# - - 29. : Kingdom Two Crowns
# - 9번 게임의 5번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Wallpaper Engine
# - - 1. : Bongo Cat
# - - 2. : The Sims™ 4
# - - 3. : Different Strokes
# - - 4. : The Forest
# - - 5. : PC Building Simulator
# - - 6. : The Binding of Isaac: Rebirth
# - - 7. : Raft
# - - 8. : R.E.P.O.
# - - 9. : UNO
# - - 10. : Fran Bow
# - - 11. : Trover Saves the Universe
# - - 12. : Split Fiction
# - - 13. : Muse Dash
# - - 14. : Fast Food Simulator
# - - 15. : Supermarket Together
# - - 16. : Sons Of The Forest
# - - 17. : Side Effects
# - - 18. : Die drei ??? - Ruf der Trolle
# - - 19. : VRoid Studio
# - - 20. : A Way Out
# - - 21. : The House of Da Vinci
# - - 22. : Rick and Morty: Virtual Rick-ality
# - - 23. : Lost in Random™
# - - 24. : Enter the Gungeon
# - - 25. : Stick Fight: The Game
# - - 26. : Stray
# - - 27. : UNBEATABLE [white label]
# - - 28. : Incremental Cubes
# - - 29. : Mini Ninjas
# - 9번 게임의 6번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199218355105 최근 게임 없음
# - - 0. : Counter-Strike
# - - 1. : Half-Life
# - - 2. : Counter-Strike: Condition Zero
# - - 3. : Counter-Strike: Condition Zero Deleted Scenes
# - - 4. : Half-Life 2
# - - 5. : Half-Life 2: Deathmatch
# - - 6. : Half-Life Deathmatch: Source
# - - 7. : Left 4 Dead
# - - 8. : Left 4 Dead 2
# - - 9. : Portal 2
# - - 10. : Killing Floor
# - - 11. : Safecracker: The Ultimate Puzzle Adventure
# - - 12. : Garry's Mod
# - - 13. : Eets
# - - 14. : RACE 07: Andy Priaulx Crowne Plaza Raceway
# - - 15. : Shadowgrounds: Survivor
# - - 16. : SlamIt Pinball: Big Score
# - - 17. : F.E.A.R.
# - - 18. : F.E.A.R.: Extraction Point
# - - 19. : F.E.A.R.: Perseus Mandate
# - - 20. : Resident Evil 5
# - - 21. : Train Simulator Classic
# - - 22. : Dark Sector
# - - 23. : Ziro
# - - 24. : Trine
# - - 25. : Mafia
# - - 26. : Metro: Last Light Complete Edition
# - - 27. : Borderlands 2
# - - 28. : Anomaly Warzone Earth
# - - 29. : Terraria
# - 9번 게임의 7번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Football Manager 2024
# - - 1. : EA SPORTS FC™ 25
# - - 2. : Cities: Skylines
# - - 3. : Grand Theft Auto V Legacy
# - - 4. : Counter-Strike 2
# - - 5. : The Forest
# - - 6. : F1® Manager 2023
# - - 7. : Raft
# - - 8. : Esports Manager 2026
# - - 9. : Left 4 Dead 2
# - - 10. : Teamfight Manager
# - - 11. : Teamfight Manager 2
# - - 12. : Escape the Backrooms
# - - 13. : The Bonerooms
# - - 14. : Delta Force
# - - 15. : Fast Food Simulator
# - - 16. : 7 Days to Die
# - - 17. : Upload Labs
# - - 18. : Gamble With Your Friends
# - - 19. : Wallpaper Engine
# - - 20. : theHunter: Call of the Wild™
# - - 21. : Ultimate Zombie Defense
# - - 22. : Strinova
# - - 23. : Supermarket Together
# - - 24. : Puck
# - - 25. : One-armed cook
# - - 26. : PUBG: BATTLEGROUNDS
# - - 27. : Dark Deception
# - - 28. : One-armed robber
# - - 29. : Assetto Corsa
# - 9번 게임의 8번 유저의 보유 게임 30개 데이터 수집
# - - 0. : The Binding of Isaac: Rebirth
# - - 1. : Terraria
# - - 2. : Counter-Strike 2
# - - 3. : Slay the Spire
# - - 4. : Hearts of Iron IV
# - - 5. : Marvel Rivals
# - - 6. : Paladins
# - - 7. : Batman: Arkham City GOTY
# - - 8. : The Forest
# - - 9. : DRAGON BALL Z: KAKAROT
# - - 10. : Project Zomboid
# - - 11. : Garry's Mod
# - - 12. : Batman™: Arkham Knight
# - - 13. : Sons Of The Forest
# - - 14. : POSTAL 2
# - - 15. : Left 4 Dead 2
# - - 16. : JoJo's Bizarre Adventure: All-Star Battle R
# - - 17. : Plants vs. Zombies: Game of the Year
# - - 18. : R.E.P.O.
# - - 19. : Valheim
# - - 20. : Deep Rock Galactic
# - - 21. : Dying Light
# - - 22. : Hades
# - - 23. : Batman: Arkham Asylum GOTY Edition
# - - 24. : Devil May Cry HD Collection
# - - 25. : PUBG: BATTLEGROUNDS
# - - 26. : Phasmophobia
# - - 27. : Mad Max
# - - 28. : Batman™: Arkham Origins
# - - 29. : The Walking Dead: The Telltale Definitive Series
# - 9번 게임의 9번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Raft
# - - 1. : Dying Light
# - - 2. : Terraria
# - - 3. : Resident Evil 2
# - - 4. : Sons Of The Forest
# - - 5. : Dead Space
# - - 6. : Darkwood
# - - 7. : Human Fall Flat
# - - 8. : Rise of the Tomb Raider
# - - 9. : Bongo Cat
# - - 10. : Ori and the Blind Forest
# - - 11. : Totally Accurate Battle Simulator
# - - 12. : Hollow Knight
# - - 13. : WorldBox - God Simulator
# - - 14. : Resident Evil 6
# - - 15. : Resident Evil 3
# - - 16. : It Takes Two
# - - 17. : WRC 7
# - - 18. : Escape the Backrooms
# - - 19. : Titanfall® 2
# - - 20. : Little Nightmares
# - - 21. : The Beast Inside
# - - 22. : Resident Evil 5
# - - 23. : Don't Starve Together
# - - 24. : The Coma 2: Vicious Sisters
# - - 25. : Electrician Simulator
# - - 26. : Little Nightmares II
# - - 27. : Poly Bridge
# - - 28. : The Bridge Curse 2: The Extrication
# - - 29. : Remothered: Tormented Fathers
# - 9번 게임의 10번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Call of Duty®
# - - 2. : EA SPORTS FC™ 24
# - - 3. : Tom Clancy's Rainbow Six Siege
# - - 4. : EA SPORTS FC™ 25
# - - 5. : ARC Raiders
# - - 6. : Palworld
# - - 7. : Battlefield™ 6
# - - 8. : Red Dead Redemption 2
# - - 9. : Windrose
# - - 10. : Stardew Valley
# - - 11. : Forza Horizon 6
# - - 12. : New World: Aeternum
# - - 13. : MultiVersus
# - - 14. : Schedule I
# - - 15. : Assassin's Creed Odyssey
# - - 16. : Raft
# - - 17. : Plants vs. Zombies: Game of the Year
# - - 18. : Valheim
# - - 19. : Core Keeper
# - - 20. : The Outlast Trials
# - - 21. : EA SPORTS FC™ 26
# - - 22. : THE FINALS
# - - 23. : EA SPORTS™ Madden NFL 26
# - - 24. : Sea of Thieves
# - - 25. : Abiotic Factor
# - - 26. : Dinkum
# - - 27. : Sons Of The Forest
# - - 28. : Street Fighter™ 6
# - - 29. : High On Life
# - 9번 게임의 11번 유저의 보유 게임 30개 데이터 수집
# steam_id 76561199241168041 최근 게임 없음
# - - 0. : Left 4 Dead 2
# - - 1. : F.E.A.R. 2: Project Origin
# - - 2. : F.E.A.R.
# - - 3. : F.E.A.R. 3
# - - 4. : F.E.A.R.: Extraction Point
# - - 5. : F.E.A.R.: Perseus Mandate
# - - 6. : Batman: Arkham Asylum GOTY Edition
# - - 7. : Machinarium
# - - 8. : Terraria
# - - 9. : Batman: Arkham City GOTY
# - - 10. : Hitman: Absolution
# - - 11. : Tomb Raider
# - - 12. : Dishonored
# - - 13. : Hitman: Sniper Challenge
# - - 14. : The Walking Dead
# - - 15. : Batman™: Arkham Knight
# - - 16. : Batman™: Arkham Origins
# - - 17. : Don't Starve
# - - 18. : Outlast
# - - 19. : Dying Light
# - - 20. : Injustice: Gods Among Us Ultimate Edition
# - - 21. : The Forest
# - - 22. : Watch_Dogs
# - - 23. : Kingdom Rush
# - - 24. : The Binding of Isaac: Rebirth
# - - 25. : 7 Days to Die
# - - 26. : Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™
# - - 27. : Darkest Dungeon®
# - - 28. : Darkwood
# - - 29. : This War of Mine
# - 9번 게임의 12번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Counter-Strike 2
# - - 1. : Grand Theft Auto V Legacy
# - - 2. : The Forest
# - - 3. : Left 4 Dead
# - - 4. : Dying Light
# - - 5. : Dead Island Definitive Edition
# - - 6. : Marvel's Spider-Man 2
# - - 7. : Don't Starve
# - - 8. : Half-Life 2
# - - 9. : Terraria
# - - 10. : Bendy and the Dark Revival
# - - 11. : Sons Of The Forest
# - - 12. : The Last of Us™ Part I
# - - 13. : Satisfactory
# - - 14. : Grand Theft Auto: San Andreas - The Definitive Edition
# - - 15. : Resident Evil 5
# - - 16. : Marvel’s Spider-Man Remastered
# - - 17. : High On Life
# - - 18. : Red Dead Redemption 2
# - - 19. : Black Mesa
# - - 20. : Dead Space™ 3
# - - 21. : Dead Island Riptide Definitive Edition
# - - 22. : R.E.P.O.
# - - 23. : Don't Starve Together
# - - 24. : Serious Sam HD: The First Encounter
# - - 25. : Resident Evil Requiem
# - - 26. : Wolfenstein: Youngblood
# - - 27. : Call of Duty®: Modern Warfare® II
# - - 28. : DOOM
# - - 29. : BioShock Remastered
# - 9번 게임의 13번 유저의 보유 게임 30개 데이터 수집
# - - 0. : HELLDIVERS™ 2
# - - 1. : The First Descendant
# - - 2. : Palworld
# - - 3. : No Man's Sky
# - - 4. : Forza Horizon 6
# - - 5. : SD GUNDAM G GENERATION CROSS RAYS
# - - 6. : Monster Hunter Wilds
# - - 7. : Coral Island
# - - 8. : ARMORED CORE™ VI FIRES OF RUBICON™
# - - 9. : Dinkum
# - - 10. : MONSTER HUNTER RISE
# - - 11. : Vampire Survivors
# - - 12. : Wallpaper Engine
# - - 13. : ACE COMBAT™7: SKIES UNKNOWN
# - - 14. : Escape From Duckov
# - - 15. : Umamusume: Pretty Derby
# - - 16. : GUNDAM BREAKER 4
# - - 17. : Digimon Story Time Stranger
# - - 18. : Monster Hunter: World
# - - 19. : BattleBit Remastered
# - - 20. : Raft
# - - 21. : Granblue Fantasy: Relink
# - - 22. : Mecha BREAK
# - - 23. : PUBG: BATTLEGROUNDS
# - - 24. : Elsword
# - - 25. : PC Building Simulator
# - - 26. : Lossless Scaling
# - - 27. : Need for Speed™ Heat
# - - 28. : Cyberpunk 2077
# - - 29. : GUNDAM EVOLUTION
# - 9번 게임의 14번 유저의 보유 게임 30개 데이터 수집
# - - 0. : Team Fortress 2
# - - 1. : Grand Theft Auto V Enhanced
# - - 2. : Counter-Strike 2
# - - 3. : Garry's Mod
# - - 4. : Brawlhalla
# - - 5. : Half-Life 2
# - - 6. : Assetto Corsa
# - - 7. : Left 4 Dead 2
# - - 8. : Rust
# - - 9. : Hearts of Iron IV
# - - 10. : 7 Days to Die
# - - 11. : Europa Universalis IV
# - - 12. : Unturned
# - - 13. : Euro Truck Simulator 2
# - - 14. : ULTRAKILL
# - - 15. : The Witcher 3: Wild Hunt
# - - 16. : Raft
# - - 17. : The Forest
# - - 18. : Dying Light 2: Reloaded Edition
# - - 19. : STRAFTAT
# - - 20. : Stardew Valley
# - - 21. : Age of History II Definitive Edition
# - - 22. : Redmatch 2
# - - 23. : Mount & Blade: Warband
# - - 24. : Terraria
# - - 25. : Ready or Not
# - - 26. : FOR HONOR
# - - 27. : Age of History II
# - - 28. : EA SPORTS FC™ 24
# - - 29. : The Witcher 2: Assassins of Kings Enhanced Edition
